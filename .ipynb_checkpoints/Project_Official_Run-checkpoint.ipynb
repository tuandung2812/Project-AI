# %% [markdown]
# <a href="https://colab.research.google.com/github/tuandung2812/Project-AI/blob/full/Project_Final_Run_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/tuandung2812/Project-AI/blob/full/All_model_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install underthesea
! pip install torch-summary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Import the necessary dependencies

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import random
import numpy as np
import pandas as pd
from torch.utils.tensorboard import SummaryWriter
import torch.optim as optim
from torch import nn
from tqdm.notebook import tqdm
from torch.autograd import Variable 
import matplotlib.pyplot as plt 
import torch.cuda
from sklearn.metrics import classification_report
import time
from underthesea import word_tokenize
from string import punctuation
import pickle
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# # Run the following cells if you intend to run on Google Colab

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd /gdrive/My\ Drive/Project-AI
# Out:
# /gdrive/My Drive/Project-AI

# %% [markdown]
# # Read our datasets

# %%
train_df = pd.read_csv("./Data/processed/train.csv", sep = "|")
val_df = pd.read_csv("./Data/processed/validation.csv", sep = "|")
test_df = pd.read_csv("./Data/processed/test.csv", sep = "|")

# %%
train_df
# Out:
#                                                sentences  sentiments
# 0                                slide giáo_trình đầy_đủ           2
# 1             nhiệt_tình giảng_dạy gần_gũi với sinh_viên           2
# 2                     đi học đầy_đủ full điểm chuyên cần           0
# 3      chưa áp_dụng công_nghệ_thông_tin và các thiết_...           0
# 4      thầy giảng bài hay có nhiều bài_tập ví_dụ ngay...           2
# ...                                                  ...         ...
# 11421  chỉ vì môn game mà em học hai lần mà không qua...           0
# 11422                                 em cảm_ơn cô nhiều           2
# 11423                             giao bài_tập quá nhiều           0
# 11424                   giáo_viên dạy dễ hiểu nhiệt_tình           2
# 11425  gói gọn doubledot hay tận_tình phù_hợp với mọi...           2
#
# [11426 rows x 2 columns]

# %% [markdown]
# # Dataset instropection

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec


train_df_viz = train_df.replace({0:'negative', 1:'neutral', 2:'positive'})
dev_df_viz = val_df.replace({0:'negative', 1:'neutral', 2:'positive'})
test_df_viz = test_df.replace({0:'negative', 1:'neutral', 2:'positive'})

all_df = pd.concat([train_df_viz, dev_df_viz, test_df_viz])


fig=plt.figure()
gs=GridSpec(2,3) # 2 rows, 3 columns
plt.subplots_adjust(hspace=0.5,  wspace=0.3)

# sns.set_style('ticks')
# fig, ax = plt.subplots(2,3)
# the size of A4 paper
fig.set_size_inches(50, 30)
fig.suptitle('The class distribution in each dataset', fontsize = 100, fontweight = 'bold', y = 1) # or plt.suptitle('Main title')

ax1=fig.add_subplot(gs[0,0]) # First row, first column
ax2=fig.add_subplot(gs[0,1]) # First row, second column
ax3=fig.add_subplot(gs[0,2]) # First row, third column
ax4=fig.add_subplot(gs[1,:]) # Second row, span all columns

# plt.title("The class distribution")
ax4 = sns.countplot(x = 'sentiments', data = all_df, ax =ax4, order = ['negative','neutral', 'positive']).set_title("Full dataset")
ax4.axes.set_title("Full dataset",fontsize=60, pad  = 50)
ax4.axes.set_xlabel("Sentiment",fontsize= 50, labelpad= 40)
ax4.axes.set_ylabel("Count",fontsize=55, labelpad = 40)
ax4.axes.tick_params(axis='both', which='major', labelsize=40, pad = 20)

ax1 = sns.countplot(x = 'sentiments', data = train_df_viz, ax =ax1, order = ['negative','neutral', 'positive']).set_title("Train set")
ax1.axes.set_title("Train set",fontsize = 60, pad  = 50)
ax1.axes.set_xlabel("Sentiment",fontsize= 50, labelpad= 40)
ax1.axes.set_ylabel("Count",fontsize=55, labelpad = 40)
ax1.axes.tick_params(axis='both', which='major', labelsize=40, pad = 20)

ax2 = sns.countplot(x = 'sentiments', data = dev_df_viz, ax =ax2, order = ['negative','neutral', 'positive']).set_title("Validationset")
ax2.axes.set_title("Validation set",fontsize=60, pad  = 50)
ax2.axes.set_xlabel("Sentiment",fontsize= 50, labelpad= 40)
ax2.axes.set_ylabel("Count",fontsize=55, labelpad = 40)
ax2.axes.tick_params(axis='both', which='major', labelsize=40, pad = 20)

ax3 = sns.countplot(x = 'sentiments', data = test_df_viz, ax =ax3, order = ['negative','neutral', 'positive']).set_title("Test set")
ax3.axes.set_title("Test set",fontsize=60, pad  = 50)
ax3.axes.set_xlabel("Sentiment",fontsize= 50, labelpad= 40)
ax3.axes.set_ylabel("Count",fontsize=55, labelpad = 40)
ax3.axes.tick_params(axis='both', which='major', labelsize=40, pad = 20)

plt.savefig("Class distribution.png", dpi = 50)

# %% [markdown]
# # SVM test and demo

# %% [markdown]
# ## Load pretrained SVM model and TF-IDF transformer

# %%
class SVM_Classifier():
    def __init__(self, model_path = "./model_checkpoint/svm/svm.pkl",vectorizer_path = './model_checkpoint/svm/vectorzier.pkl'):
        with open(model_path, 'rb') as model:
            self.model = pickle.load(model)
        
        with open(vectorizer_path, 'rb') as vectorizer:
            self.vectorizer = pickle.load(vectorizer)
    
    # This method is used to predict the class of sentences
    def predict(self, sentence_list, true_class_name = False):
        if isinstance(sentence_list, str):
            sentence_list = [sentence_list]
        vectorized =  self.vectorizer.transform(sentence_list)
        predictions = self.model.predict(vectorized)
        
        class_names = {0: 'Negative', 1:'Neutral', 2:'Positive'}
        
        if true_class_name:
            class_predictions = []
            for num in predictions:
                class_name = class_names[num]
                class_predictions.append(class_name)
            
            final_predictions = class_predictions
        else:
            final_predictions = predictions
        
        return final_predictions

    # This method is used to predict the class probabilities of sentences
    def predict_proba(self, sentence_list):
        if isinstance(sentence_list, str):
            sentence_list = [sentence_list]

        vectorized =  self.vectorizer.transform(sentence_list)
        probabilities = self.model.predict_proba(vectorized)
        return probabilities

        
#         print(vectorized)
#         labels = ['Negative','Netural','Positive']

# %% [markdown]
# ## Generate prediction on the test set

# %%
test_sentences = test_df['sentences']
svm_classifier = SVM_Classifier()
test_predictions = svm_classifier.predict(test_sentences, true_class_name = False)

# %% [markdown]
# ## Evaluate

# %%
y_test = test_df['sentiments'].values
print(classification_report(y_test, test_predictions, digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8991    0.9603    0.9287       705
#            1     0.5581    0.3288    0.4138        73
#            2     0.9530    0.9317    0.9422       805
#
#     accuracy                         0.9166      1583
#    macro avg     0.8034    0.7402    0.7616      1583
# weighted avg     0.9108    0.9166    0.9118      1583

# %% [markdown]
# ## Some demo sentences for svm

# %%
demo_sentences = ["các yêu cầu về đồ án môn học nên đươc đưa ra chính xác trước khi sinh viên bắt đầu thực hiện chia nhóm và làm đồ án", 
"dạy dễ hiểu dễ tiếp thu tập trung vài kiến thức trọng tâm", 
"cần cải cách lại nội dung các bài thực hành một số kiến nội dung trong bài thực hành đã trở nên lỗi thời", "thầy dạy hơi nhanh", 
"chúng ta không thuộc về nhau", 
"đề tài em chọn trong bài tập lớn là về phân phối chuẩn"]

# %%
svm_classifier.predict(demo_sentences, true_class_name = True)
# Out:
# ['Negative', 'Positive', 'Negative', 'Negative', 'Negative', 'Negative']

# %%
svm_classifier.predict_proba("dạy dễ hiểu dễ tiếp thu tập trung vài kiến thức trọng tâm")
# Out:
# array([[0.11142334, 0.07064503, 0.81793164]])

# %% [markdown]
# # Test and Demo for NN, LSTM, CNN

# %% [markdown]
# ## Build vocabulary from the training set

# %%
import collections
import os
import json
import datetime

class Vocabulary():
  '''Vocabulary class: extract all words from corpus, save all words that appears more than freq_threshold times'''
  def __init__(self, freq_threshold=3):
    self.itos = {0: "<PAD>", 1: "<SOS>", 2: "<EOS>", 3: "<UNK>"}
    self.stoi = {"<PAD>": 0, "<SOS>": 1, "<EOS>": 2, "<UNK>": 3}
    self.freq_threshold = freq_threshold

  def __len__(self):
    return len(self.itos)

  def build_vocab(self, sentence_list):
    # Build the vocab
    idx = 4
    word_counter = collections.Counter([word for sentence in sentence_list for word in sentence])

    for word, count in word_counter.items():
      if count >= self.freq_threshold:
        self.stoi[word] = idx
        self.itos[idx] = word
        idx += 1

  def numericalize(self, sent):
    # Turn a sentence into list of word ID
    return [
            self.stoi[token] if token in self.stoi else self.stoi["<UNK>"]
            for token in sent
        ]
  def save_vocab(self, vocab_path):
    with open(vocab_path, 'w') as f:
        vocab = {'itos': self.itos, 'stoi': self.stoi}
        json.dump(vocab, f)

  def load_vocab(self, vocab_path):
    with open(vocab_path, 'r') as f:
        vocab = json.load(f)
        self.itos = vocab['itos']
        self.stoi = vocab['stoi']

# %% [markdown]
# ### Demo vocabulary

# %%
train_sents = train_df['sentences'].values
train_sents = [sent.split(" ") for sent in train_sents]
train_sents[0:3]
# Out:
# [['slide', 'giáo_trình', 'đầy_đủ'],
#  ['nhiệt_tình', 'giảng_dạy', 'gần_gũi', 'với', 'sinh_viên'],
#  ['đi', 'học', 'đầy_đủ', 'full', 'điểm', 'chuyên', 'cần']]

# %%
vocab = Vocabulary(3)
vocab.build_vocab(train_sents)

# %%
vocab.itos #string to index
# Out:
# {0: '<PAD>',
#  1: '<SOS>',
#  2: '<EOS>',
#  3: '<UNK>',
#  4: 'slide',
#  5: 'giáo_trình',
#  6: 'đầy_đủ',
#  7: 'nhiệt_tình',
#  8: 'giảng_dạy',
#  9: 'gần_gũi',
#  10: 'với',
#  11: 'sinh_viên',
#  12: 'đi',
#  13: 'học',
#  14: 'điểm',
#  15: 'chuyên',
#  16: 'cần',
#  17: 'chưa',
#  18: 'áp_dụng',
#  19: 'công_nghệ_thông_tin',
#  20: 'và',
#  21: 'các',
#  22: 'thiết_bị',
#  23: 'hỗ_trợ',
#  24: 'cho',
#  25: 'việc',
#  26: 'thầy',
#  27: 'giảng',
#  28: 'bài',
#  29: 'hay',
#  30: 'có',
#  31: 'nhiều',
#  32: 'bài_tập',
#  33: 'ví_dụ',
#  34: 'ngay',
#  35: 'trên',
#  36: 'lớp',
#  37: 'giảng_viên',
#  38: 'đảm_bảo',
#  39: 'thời_gian',
#  40: 'lên',
#  41: 'tích_cực',
#  42: 'trả_lời',
#  43: 'câu_hỏi',
#  44: 'của',
#  45: 'thường_xuyên',
#  46: 'đặt',
#  47: 'câu',
#  48: 'hỏi',
#  49: 'em',
#  50: 'sẽ',
#  51: 'môn',
#  52: 'này',
#  53: 'nhưng',
#  54: 'học_lại',
#  55: 'ở',
#  56: 'học_kỳ',
#  57: 'thời_lượng',
#  58: 'quá',
#  59: 'dài',
#  60: 'không',
# ...

# %%
vocab.stoi #string to index
# Out:
# {'<PAD>': 0,
#  '<SOS>': 1,
#  '<EOS>': 2,
#  '<UNK>': 3,
#  'slide': 4,
#  'giáo_trình': 5,
#  'đầy_đủ': 6,
#  'nhiệt_tình': 7,
#  'giảng_dạy': 8,
#  'gần_gũi': 9,
#  'với': 10,
#  'sinh_viên': 11,
#  'đi': 12,
#  'học': 13,
#  'điểm': 14,
#  'chuyên': 15,
#  'cần': 16,
#  'chưa': 17,
#  'áp_dụng': 18,
#  'công_nghệ_thông_tin': 19,
#  'và': 20,
#  'các': 21,
#  'thiết_bị': 22,
#  'hỗ_trợ': 23,
#  'cho': 24,
#  'việc': 25,
#  'thầy': 26,
#  'giảng': 27,
#  'bài': 28,
#  'hay': 29,
#  'có': 30,
#  'nhiều': 31,
#  'bài_tập': 32,
#  'ví_dụ': 33,
#  'ngay': 34,
#  'trên': 35,
#  'lớp': 36,
#  'giảng_viên': 37,
#  'đảm_bảo': 38,
#  'thời_gian': 39,
#  'lên': 40,
#  'tích_cực': 41,
#  'trả_lời': 42,
#  'câu_hỏi': 43,
#  'của': 44,
#  'thường_xuyên': 45,
#  'đặt': 46,
#  'câu': 47,
#  'hỏi': 48,
#  'em': 49,
#  'sẽ': 50,
#  'môn': 51,
#  'này': 52,
#  'nhưng': 53,
#  'học_lại': 54,
#  'ở': 55,
#  'học_kỳ': 56,
#  'thời_lượng': 57,
#  'quá': 58,
#  'dài': 59,
#  'không': 60,
# ...

# %% [markdown]
# ## Declare PyTorch dataset and dataloader

# %%
import torch
import numpy as np
from torch.utils.data import DataLoader, Dataset
import random
import torch.nn.functional as F


seed  = 42
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

class SentimentDataset(Dataset):
  def __init__(self,df, vocab = None, max_sent_len = 120):
    self.train_sents = [sent.split(" ") for sent in df['sentences'].values]
    self.labels = df['sentiments'].values
    self.max_sent_len = max_sent_len
    if vocab == None:
        self.vocab = Vocabulary(3)
        self.vocab.build_vocab(self.train_sents)
    else:
        self.vocab = vocab
  def __len__(self):
    return len(self.train_sents)
      
  def __getitem__(self, index):
    sent_numericalized = [self.vocab.stoi["<SOS>"]]
    sent_numericalized += self.vocab.numericalize(self.train_sents[index])
    
    if len(sent_numericalized) > self.max_sent_len:
        sent_numericalized = sent_numericalized[:self.max_sent_len]

    sent_tensor = np.full(self.max_sent_len, self.vocab.stoi["<PAD>"])
    sent_tensor[(self.max_sent_len - len(sent_numericalized)):] = sent_numericalized
    x = torch.Tensor(sent_tensor).long()
    
    y = self.labels[index]
    return x,y

# %%
def get_loader(df, vocab = None, max_sent_len = 120,batch_size = 64, num_workers = 0, shuffle = True, pin_memory = True):
    dataset = SentimentDataset(df, vocab = vocab, max_sent_len = max_sent_len)
    vocab = dataset.vocab
    loader = DataLoader(
        dataset=dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        shuffle=shuffle,
        pin_memory=pin_memory
    )
    return loader, dataset, vocab

# %%
train_loader,_,_ = get_loader(train_df, vocab = vocab, max_sent_len = 100)
val_loader,_,_ = get_loader(val_df, vocab = vocab, max_sent_len = 100)
test_loader,_,_ = get_loader(test_df, vocab = vocab, max_sent_len = 100)
batch_size = 64

# %% [markdown]
# ## Declare our LSTM model class

# %%
class NetLSTM(nn.Module):
 
  def __init__(self, vocab_size, embedding_size, hidden_size, num_classes, num_layers, pad_idx, dropout, device, bidirectional):
    super(NetLSTM, self).__init__()
    self.vocab_size = vocab_size 
    self.embedding_size = embedding_size 
    self.hidden_size = hidden_size
    self.num_layers = num_layers
    self.device = device
    self.pad_idx = pad_idx
    self.num_classes = num_classes
    self.bidirectional = bidirectional

    self.dropout = nn.Dropout(dropout)
    
    #Embedding layer
    self.embedding = nn.Embedding(vocab_size, embedding_size, padding_idx = pad_idx).to(device)

    #LSTM layer
    self.lstm = nn.LSTM(
        input_size= self.embedding_size,
        hidden_size= self.hidden_size,
        batch_first=True,
        num_layers= self.num_layers
    ).to(device)

    #Linear, ReLU and Softmax layers
    self.fc = nn.Linear(in_features=self.hidden_size, out_features = self.num_classes).to(device)
    self.relu = nn.ReLU().to(device)
    self.softmax = nn.Softmax(dim = 1).to(device)

  def forward(self, x):
    h_0 = torch.zeros(self.num_layers, x.shape[0], self.hidden_size).to(self.device) #hidden state
    c_0 = torch.zeros(self.num_layers, x.shape[0], self.hidden_size).to(self.device) #internal state

    #perform dropout in embedding layer
    embedded = self.dropout(self.embedding(x))

    #LSTM layer
    output, (hn, cn) = self.lstm(embedded, (h_0, c_0)) 
   
    #reshaping the data for Dense layer
    hn = hn[-1].view(-1, self.hidden_size) 

    #fully connected layer and activation layers (ReLU and Softmax)
    out = self.fc(hn)  
    out = self.relu(out) 
    out = self.softmax(out) #Final Output

    return out

# %% [markdown]
# ## Declare our CNN model class

# %%
class NetCNN(nn.Module):
    def __init__(self, vocab_size, embed_size, kernel_sizes, num_channels, drop, pad_idx):
        super(NetCNN, self).__init__()
        self.pad_idx = pad_idx
        self.embedding = nn.Embedding(vocab_size, embed_size, padding_idx = pad_idx)
        
        # The embedding layer not to be trained
        self.constant_embedding = nn.Embedding(vocab_size, embed_size, padding_idx = pad_idx)
        self.dropout = nn.Dropout(drop)
        self.fc = nn.Linear(in_features = sum(num_channels), out_features = 3)

        # The max-over-time pooling layer has no parameters, so this instance
        # can be shared
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.relu = nn.ReLU()

        # Create multiple one-dimensional convolutional layers
        self.convs = nn.ModuleList()
        for c, k in zip(num_channels, kernel_sizes):
            self.convs.append(nn.Conv1d(2 * embed_size, c, k))

    def forward(self, inputs):
        # Concatenate two embedding layer outputs with shape (batch size, no.
        # of tokens, token vector dimension) along vectors
        embeddings = torch.cat((self.embedding(inputs), self.constant_embedding(inputs)), dim=2)

        # Per the input format of one-dimensional convolutional layers,
        # rearrange the tensor so that the second dimension stores channels
        embeddings = embeddings.permute(0, 2, 1)

        # For each one-dimensional convolutional layer, after max-over-time
        # pooling, a tensor of shape (batch size, no. of channels, 1) is
        # obtained. Remove the last dimension and concatenate along channels
        conv = torch.cat([
            torch.squeeze(self.relu(self.pool(conv(embeddings))), dim=-1)
            for conv in self.convs], dim=1)
        output = self.fc(self.dropout(conv))
        return output

# %% [markdown]
# ## Declare our NN model class

# %%
class NetLinear(nn.Module):
 
  def __init__(self, vocab_size, embedding_size, hidden_size, num_classes, num_layers, pad_idx, dropout, device):
    super(NetLinear, self).__init__()
    self.vocab_size = vocab_size 
    self.embedding_size = embedding_size 
    self.hidden_size = hidden_size
    self.num_layers = num_layers
    self.device = device
    self.pad_idx = pad_idx
    self.num_classes = num_classes

    self.dropout = nn.Dropout(dropout)
    
    #Embedding layer
    self.embedding = nn.Embedding(vocab_size, embedding_size, padding_idx = pad_idx).to(device)

    #Linear, ReLU and Softmax layers
    self.fc = nn.Linear(in_features=self.embedding_size * 100, out_features = self.num_classes).to(device)
    self.relu = nn.ReLU().to(device)
    self.softmax = nn.Softmax(dim = 1).to(device)

  def forward(self, x):
    embedded = self.embedding(x)
    embedded = embedded.view(-1, self.embedding_size*100)
    
    out = self.dropout(self.fc(embedded))
    out = self.relu(out) 
    out = self.softmax(out) #Final Output

    return out

# %% [markdown]
# ## Create LSTM model

# %%
vocab_size = len(vocab)
embedding_size = 256
hidden_size = 128
num_classes = 3
num_layers = 1
dropout = 0.5
bidirectional = False
pad_idx = vocab.stoi["<PAD>"]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # train on GPU if available


model_lstm = NetLSTM(vocab_size = vocab_size, embedding_size = embedding_size, hidden_size = hidden_size, num_classes = num_classes, num_layers = num_layers, dropout = dropout, pad_idx = pad_idx, device = device, bidirectional = bidirectional)

# %% [markdown]
# ## Create CNN model

# %%
PAD_IDX = vocab.stoi["<PAD>"]
INPUT_DIM = len(vocab)
EMBEDDING_DIM = 256
N_FILTERS = [100, 100, 100]
FILTER_SIZES = [3, 4, 5]
OUTPUT_DIM = 3
DROPOUT = 0.5

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_cnn = NetCNN(INPUT_DIM, EMBEDDING_DIM, FILTER_SIZES, N_FILTERS, DROPOUT, PAD_IDX).to(device)

# %% [markdown]
# ## Create Linear model

# %%
vocab_size = len(vocab)
embedding_size = 256
hidden_size = 128
num_classes = 3
num_layers = 2
dropout = 0.2
pad_idx = vocab.stoi["<PAD>"]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # train on GPU if available


model_linear = NetLinear(vocab_size = vocab_size, embedding_size = embedding_size, hidden_size = hidden_size, num_classes = num_classes, num_layers = num_layers, dropout = dropout, pad_idx = pad_idx, device = device)

# %% [markdown]
# ## Load the previously trained model weights

# %%
model_lstm.load_state_dict(torch.load("./model_checkpoint/model_LSTM.pth.tar"))
model_linear.load_state_dict(torch.load("./model_checkpoint/model_Linear.pth.tar"))
model_cnn.load_state_dict(torch.load("./model_checkpoint/model_CNN.pth.tar"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Test for 3 models: NN, LSTM, CNN

# %%
#initialization
test_losses = []
num_correct = 0

model_lstm.eval()
model_linear.eval()
model_cnn.eval()
pred_total_lstm = torch.tensor([]).to(device)
labels_total = torch.tensor([]).to(device)
pred_total_linear = torch.tensor([]).to(device)
pred_total_cnn = torch.tensor([]).to(device)

for inputs, labels in test_loader:

    #change device of labels and input to cuda, if available
    inputs = inputs.to(device)
    labels = labels.to(device)

    #get the output from the input
    output_lstm = model_lstm(inputs)
    output_linear = model_linear(inputs)
    output_cnn = model_cnn(inputs)
    
    
    #put predicted labels and true labels of each batch to the whole
    out = output_lstm.tolist()
    out = np.array(out)
    pred = torch.tensor(out.argmax(axis=1)).to(device)
    pred_total_lstm = torch.cat((pred_total_lstm, pred))
    labels_total = torch.cat((labels_total, labels))

    out = output_linear.tolist()
    out = np.array(out)
    pred = torch.tensor(out.argmax(axis=1)).to(device)
    pred_total_linear = torch.cat((pred_total_linear, pred))

    out = output_cnn.tolist()
    out = np.array(out)
    pred = torch.tensor(out.argmax(axis=1)).to(device)
    pred_total_cnn = torch.cat((pred_total_cnn, pred))

pred_total_lstm = pred_total_lstm.tolist() 
labels_total = labels_total.tolist()
pred_total_linear = pred_total_linear.tolist() 
pred_total_cnn = pred_total_cnn.tolist() 


#report generating
target_names = ['negative', 'neutral', 'positive']
print("LSTM result: ")
print(classification_report(labels_total, pred_total_lstm, target_names=target_names, digits = 4))
print("DNN result: ")
print(classification_report(labels_total, pred_total_linear, target_names=target_names, digits = 4))
print("CNN result: ")
print(classification_report(labels_total, pred_total_cnn, target_names=target_names, digits = 4))
# Out:
# LSTM result:
#               precision    recall  f1-score   support
#
#     negative     0.9156    0.9234    0.9195       705
#      neutral     0.4273    0.6438    0.5137        73
#     positive     0.9528    0.9019    0.9266       805
#
#     accuracy                         0.8996      1583
#    macro avg     0.7652    0.8230    0.7866      1583
# weighted avg     0.9120    0.8996    0.9044      1583
#
# DNN result:
#               precision    recall  f1-score   support
#
#     negative     0.8831    0.9106    0.8966       705
#      neutral     0.5224    0.4795    0.5000        73
#     positive     0.9176    0.8994    0.9084       805
#
#     accuracy                         0.8850      1583
#    macro avg     0.7744    0.7632    0.7684      1583
# weighted avg     0.8840    0.8850    0.8843      1583
#
# CNN result:
#               precision    recall  f1-score   support
#
#     negative     0.9227    0.9149    0.9188       705
# ...

# %% [markdown]
# ## Get the classification results from model

# %%
def get_predict(reviews, model):
  pred = []
  res = []
  set_encoded_review = []

  model.eval()

  #process the input
  for review in reviews:
    review = review.lower()
    review = [review[i] for i in range(len(review)) if review[i] not in punctuation]
    review = "".join(map(str, review))
    splited_review = word_tokenize(review, format = "text").split()
    encoded_review = vocab.numericalize(splited_review)
    temp = np.full(100, vocab.stoi["<PAD>"])
    temp[(100 - len(encoded_review)):] = encoded_review
    set_encoded_review.append(temp.tolist())
  input = torch.tensor(set_encoded_review).to(device)

  #get the output from the model
  output = model(input)

  #process the output to desired results
  pred_prob = np.squeeze(F.softmax(output, dim = 1)).tolist()
  pred = np.squeeze(np.array(output.tolist()).argmax(axis = 1)).tolist()
  
  if type(pred) == int :
    pred = [pred]

  for mem in pred:
    if mem == 0:
      res.append("tiêu cực")
    elif mem == 1:
      res.append("trung lập")
    else:
      res.append("tích cực")

  return res, pred_prob

# %% [markdown]
# ## Real sentences demo

# %%
reviews = ["các yêu cầu về đồ án môn học nên đươc đưa ra chính xác trước khi sinh viên bắt đầu thực hiện chia nhóm và làm đồ án", 
           "dạy dễ hiểu dễ tiếp thu tập trung vài kiến thức trọng tâm", 
           "cần cải cách lại nội dung các bài thực hành một số kiến nội dung trong bài thực hành đã trở nên lỗi thời", 
           "thầy dạy hơi nhanh", 
           "chúng ta không thuộc về nhau", 
           "đề tài em chọn trong bài tập lớn là phân phối chuẩn",
           "vshjhuajvjfhùbdjsfhdkhg98765464fjhghjkgjfjhkhngf"]
res_lstm = get_predict(reviews, model_lstm)
res_linear = get_predict(reviews, model_linear)
res_cnn = get_predict(reviews, model_cnn)

print(res_lstm[0])
print(res_linear[0])
print(res_cnn[0])
# Out:
# ['tiêu cực', 'tích cực', 'tiêu cực', 'tiêu cực', 'tiêu cực', 'tiêu cực', 'tiêu cực']
# ['tiêu cực', 'tích cực', 'tiêu cực', 'tiêu cực', 'tiêu cực', 'tích cực', 'tiêu cực']
# ['tiêu cực', 'tích cực', 'tiêu cực', 'tiêu cực', 'trung lập', 'tích cực', 'trung lập']
