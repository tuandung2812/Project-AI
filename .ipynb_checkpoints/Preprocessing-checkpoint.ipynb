# %%
import sklearn
import string
from underthesea import word_tokenize
import pandas as pd

# %% [markdown]
# # Read files

# %%
with open("./Data/train/sents.txt", "r", encoding = "utf8") as f:
    train_sents = [sent.strip() for sent in f.readlines()]
train_sents
# Out:
# ['slide giáo trình đầy đủ .',
#  'nhiệt tình giảng dạy , gần gũi với sinh viên .',
#  'đi học đầy đủ full điểm chuyên cần .',
#  'chưa áp dụng công nghệ thông tin và các thiết bị hỗ trợ cho việc giảng dạy .',
#  'thầy giảng bài hay , có nhiều bài tập ví dụ ngay trên lớp .',
#  'giảng viên đảm bảo thời gian lên lớp , tích cực trả lời câu hỏi của sinh viên , thường xuyên đặt câu hỏi cho sinh viên .',
#  'em sẽ nợ môn này , nhưng em sẽ học lại ở các học kỳ kế tiếp .',
#  'thời lượng học quá dài , không đảm bảo tiếp thu hiệu quả .',
#  'nội dung môn học có phần thiếu trọng tâm , hầu như là chung chung , khái quát khiến sinh viên rất khó nắm được nội dung môn học .',
#  'cần nói rõ hơn bằng cách trình bày lên bảng thay vì nhìn vào slide .',
#  'thầy rất tận tình và đi dạy rất đúng giờ .',
#  'dễ bị áp lực .',
#  'đang dạy thầy wzjwz208 đi qua nước ngoài giữa chừng , thầy wzjwz209 dạy thay .',
#  'môn học còn dễ cần nâng độ khó lên nữa .',
#  'có thể cho sinh viên đi thăm quan nhiều công ty xem quy mô và cách làm việc , để giúp hiểu rõ hơn vê ngành mình đang học .',
#  'hài lòng về tất cả .',
#  'nhiệt tình , vui vẻ .',
#  'thấy nhiệt tình trong việc trao đổi giúp đỡ về học tập .',
#  'phong cách giảng bài của thầy rất gần gũi với sinh viên !',
#  'giảng dạy kết hợp các hoạt động giải trí có hiệu quả .',
#  'cần tạo các buổi seminar để sinh viên có thể hiểu sâu thêm về các vấn đề trong chuyên ngành nhưng không có trong môn học .',
#  'tiết học thoải mái .',
#  'thầy nhiệt tình , quan tâm tới sinh viên .',
#  'giảng dạy nhiệt tình , hướng dẫn chi tiết đến lúc sinh viên hiểu !',
#  'chưa có nhiều tiết làm bài tập , chữa bài tập trên lớp .',
#  'tài liệu được bổ sung nhiều và đầy đủ trên moodle .',
#  'giảng viên phải nên cho ví dụ cụ thể những phần quan trọng nên nói kỹ có thể lấy ví dụ minh họa tránh việc lập đi lập lại nhiều lần sẽ tạo cảm giác chán cho sinh viên .',
#  'nên biên soạn một tài liệu của chính trường ta .',
#  'không giúp đỡ sinh viên trong những vấn đề xung quanh .',
#  'bài tập đa dạng , cụ thể .',
#  'nội dung giảng viên yêu câu seminar hầu như không có tài liệu tham khảo và rất ít ứng dụng trong thực tế , đề nghị có sự thay đổi trong những năm học tới .',
#  'slide up đầy đủ trước mỗi buổi học .',
#  'nội dung giảng dạy quá nhàm chán , khô khan .',
#  'lượng kiến thức quá nhiều trong một học kỳ .',
#  'thầy chép bảng nhiều .',
#  'thầy tận tình hướng dẫn cách làm , giải quyết những thắc mắc của sinh viên .',
#  'chúc các thầy cô , anh chị làm việc vui vẻ !',
#  'hay , nhiệt tình , dễ hiểu .',
#  'mặc dù nhiệt tình nhưng khi truyền đạt thì lại khó hiểu , sử dụng ngôn từ gây khó khăn cho việc hiểu bài .',
#  'thầy dạy khá hay , cung cấp nhiều thông tin liên quan đến môn học , đưa ra nhiều hướng giải quyết khi sinh viên gặp vấn đề khó khăn với đồ án !',
#  'hy vọng học kỳ sau có thể học được với cô .',
#  'nhiều khi em lên lớp học môn đặc tả hình thức giống như lên lớp học mà không biết mình học cái gì .',
#  'trong khi giảng nói nhỏ quá .',
#  'thực hành khó hiểu .',
#  'thầy rất tận tâm nhiệt tình , quan tâm đến sinh viên , giảng bài dễ hiểu , kiến thức sâu rộng am hiểu cao .',
#  'cô dạy với nhiệt huyết của mình , dù như thế nào , cô vẫn luôn mỉm cười và kiên trì giảng bài cho chúng em đến khi chúng em hiểu .',
#  'cô lên lớp đúng giờ , giảng bài rất dễ hiểu cho sinh viên .',
#  'những thông tin cần thiết như doubledot thời gian dealine , cách nộp bài thường không dặn lớp thực hành thứ hai .',
#  'thầy nhiệt tình , dễ chịu .',
#  'giảng viên chưa đi sâu vào bản chất của vấn đề , em chỉ học thôi mà không biết bản chất của nó là gì nó có ứng dụng gì sau này cho chuyên nghành của em .',
#  'đặc biệt hơn là thầy đã bỏ rất nhiều công sức trong việc ra bài tập và chấm điểm một cách rõ ràng và minh bạch .',
#  'cô rất nhiệt tình và tận dụng tốt thời gian .',
#  'giảng viên tận tâm , nhiệt huyết trong giảng dạy .',
#  'thầy nhiệt tình , gần gũi .',
#  'giảng viên tận tâm , giảng dễ hiểu , dễ tiếp thu .',
#  'tạo ra sự cạnh tranh trong mỗi buổi thực hành .',
#  'bài tập và có code tham khảo .',
#  'cần nâng cấp hệ thống wifi , vì khi vào phòng thực hành , sinh viên không thể truy cập internet , buộc phải xin phép ra ngoài để làm bài .',
#  'tài liệu không chi tiết lắm .',
#  'tận tâm , nhiệt tình , vui tính , dễ gần với sinh viên .',
#  'thầy dạy rất hay và nhiệt tình .',
#  'thầy dạy không đúng giờ , không hướng dẫn sinh viên thực hành .',
#  'giúp đỡ học sinh quá ít .',
#  'cô dạy buồn ngủ quá .',
#  'nên kinh mong nội dung môn học được giảm tải cho phù hợp hơn với đặc thù của một trường công nghệ thông tin .',
#  'thầy tận tình vui tính .',
#  'cô lại kiểu khó tính nữa .',
#  'tạo hứng thú cho sinh viên .',
#  'cô giảng hay cuốn hút và truyền đạt dễ hiểu .',
#  'có hứng thú học .',
#  'ôn tập đúng theo thầy nhưng không biết cuối kỳ được mấy điểm .',
#  'giảng viên hướng dẫn cụ thể , chi tiết .',
#  'giáo trình quá ít và nội dung không khác nhau là mấy .',
#  'giáo viên nghỉ dạy liên tục , cuối học kỳ lại tăng học bù , những tiết học bù đó đã ảnh hưởng đến những đồ án , và trễ deadline .',
#  'giáo viên lúc dạy lúc không , không dạy cũng không thông báo , sinh viên tốn thời gian , công sức , tiền bạc rồi ngồi đợi và đi về .',
#  'cần có một phòng máy tốt hơn , hiện đại hơn .',
#  'thầy nên cho làm bài tập tương tự nhau nhiều hơn một vài bài để tránh tình trạng quên hoặc các dạng tựa nhau nhưng hơi khác cách làm .',
#  'không ngờ môn này lại chán đến như vậy , không học được gì từ môn này , thầy dạy chán kinh khủng , hay đi trễ từ 30 - 45 phút , không nhiệt tình .',
#  'giảng viên đánh giá sai điểm và năng lực của học sinh .',
#  'không đáp ứng được đề cương môn học đề ra .',
#  'thầy nên hướng dẫn thực hành nhiều hơn .',
#  'giảng viên thân thiện , quan tâm tới sinh viên .',
#  'môn lập trình hướng đối tượng nên cập nhật thêm những nội dung mới , dễ hiểu và giảng giải cụ thể hơn .',
#  'giáo viên nhiệt tình , tâm huyết , khả năng truyền đạt tốt .',
#  'thầy dạy rất tốt và nhiệt tình .',
#  'cô nói hơi nhỏ , nếu lớp ồn sẽ khó nghe .',
#  'bài tập cô đưa ra nhiều , và khó tìm hiểu , với kiến thực hiện tại của sinh viên thì khó có thể tìm hiểu và làm tốt bài tập cô ra .',
#  'bài tập và hoạt động nhóm còn ít .',
#  'giảng viên rất nhiệt tình , phương pháp giảng dạy hay , sinh viên nắm bắt kiến thức ngay trên lớp .',
#  'cô hướng dẫn thực hành khá đầy đủ .',
#  'được học nhiều kinh nghiệm từ thầy wzjwz163 .',
#  'kiến thức của thầy rất tốt , bảo đảm giờ lên lớp .',
#  'hiện tại em chưa thấy tác dụng gì nhiều khi học môn này .',
#  'cải thiện lại cơ sở vật chất máy chiếu trong phòng học .',
#  'dạy không phù hợp với cách học của em .',
#  'giải thích nội dung mới rõ ràng .',
#  'lớp học quá đông !',
#  'môn căn bản mà thầy không dạy cho sinh viên kỹ , gây không hiểu , mất căn bản .',
#  'giảng viên chưa cho bài tập về nhà để sinh viên làm nên cho 5 bài mỗi chương , không cần chữa chỉ cần đáp án .',
#  'mà hiện tại trường ta chưa có , đây là thiệt thòi lớn đối với tụi em .',
#  'tôi cảm thấy giảng viên dạy rất tốt .',
#  'không biết thầy nào dạy chính thức , mà học thường nghỉ không thông báo trước để sinh viên đứng chờ sắp hết tiết rồi tự về nhiều lần .',
#  'cần có sự tương tác giữa giảng viên và sinh viên nhiều hơn .',
#  'giảng viên thân thiện nhiệt tình cởi mở .',
#  'giáo viên có mời các công ty về trình bày , giúp sinh viên cập nhật kiến thức thực tiễn .',
#  'coi lại thái độ giảng viên thực hành .',
#  'giảng viên nhiệt tình , giải nhiều bài tập .',
#  'bài giảng của thầy rất nhiệt tình .',
#  'môn học chưa thực tiễn , chưa thu hút sinh viên .',
#  'dạy hơi nhanh !',
#  'ít làm bài tập .',
#  'giảng bài kém thu hút , vị trí đứng giảng không hợp lý , ôn tập cuối kỳ còn chưa tập trung vào vấn đề .',
#  'giảng viên nhiệt tình , bài giảng thu hút .',
#  'nhờ thầy và giảng viên lý thuyết , em đã hiểu rõ về môn này rất nhiều !',
#  'môn này khá trừu tượng nên mong thầy có nhiều liên tưởng tới thực tiễn hơn để chúng em có thể hiểu .',
#  'cần thêm nhiều tài liệu cho sinh viên .',
#  'bài tập trên lớp .',
#  'tăng số tiết dạy lên để sinh viên có nhiều cơ hội hỏi đáp thắc mắc về môn học .',
#  'thầy nhiệt tình dễ hiểu .',
#  'thực hành và lý thuyết nên dạy song song .',
#  'giảng viên dạy nhanh .',
#  'bài tập trên lớp nên được giới thiệu ngay từ đầu tiết học để học sinh không tốn thời gian đọc đề cũng như có thể suy nghĩ cách giải cùng lúc với việc nghe giảng .',
#  'giảng viên cho bài tập hay .',
#  'cập nhật bài tập mới .',
#  'lên lớp ai làm việc người ấy , thầy không có giảng gì thêm .',
#  'tận tâm , nhiệt tình , quan tâm đến sinh viên .',
#  'phản hồi giải đáp thắc mắc cho sinh viên .',
#  'dạy quá nhanh .',
#  'mong ban thiết bị sớm khắc phục ạ !',
#  'môn này cần làm đề tài để áp dụng lý thuyết vào thực tiễn mà trên lớp chỉ học một đống lý thuyết và hiếm ai nhớ đa số khá buồn ngủ khi lên lớp .',
#  'giảng viên nên đổi mới phương pháp giảng dạy , tránh thô cứng , không hấp dẫn sinh viên .',
#  'nhiệt tình , tạo cách chủ động cho học sinh tiếp cận với môn học và tham gia các chương trình phong trào liên quan để nâng cao kỹ năng .',
#  'cô dạy rất tận tình , dễ hiểu .',
#  'không đáp ứng được nhu cầu của sinh viên .',
#  'thầy rất nhiệt tình với chúng em và điều này làm em rất hài lòng .',
#  'cách giảng dạy của thầy rất hay và có phần dễ hiễu .',
#  'nhiệt tình , dễ thương .',
#  'không hướng dẫn đồ án .',
#  'em xin đề nghị nhà trường nên bổ sung tài liệu về môn học và cập nhật nội dung .',
#  'chép bài rất nhiều , lãng phí thời gian nghe giảng .',
#  'em không học thầy wzjwz178 kỳ này , giáo viên thực hành có 2 người nên có lẽ daa nhầm .',
#  'đề thi môn dài sinh viên làm không đủ thời gian .',
#  'cho làm nhiều bài test .',
#  'theo em thì nên thi phòng máy nào có visual 2013 trở lên .',
#  'cần thêm nhiều tài liệu cho môn học .',
#  'thầy giảng dạy tốt .',
#  'mong thầy có thể hướng dẫn cách cụ thể nhất cho những bài khó .',
#  'thầy cần cho bài tập và hướng dẫn nhiều hơn .',
#  'giáo viên lên lớp đúng giờ , giảng bài sôi động .',
#  'em thấy thầy chỉ giảng cho có .',
#  'cần xác định rõ mục đích môn học và cho sinh viên đề cương chi tiết môn học trước khi bắt đầu .',
#  'thầy nói chuyện với sinh viên rất tự nhiên , chia sẻ kinh nghiệm thực tế .',
#  'dạy theo sát chương trình .',
#  'cung cấp thêm trang thiết bị phục vụ nhu cầu môn học .',
#  'đề nghị nâng cấp phòng lab khoa mạng .',
#  'thầy giảng hay và tâm huyết , bài giảng có tính thực tiễn cao .',
#  'đi dạy đúng giờ .',
#  'thầy cung cấp nhiều kiến thức mới , thầy dạy tận tâm và nhiệt tình !',
#  'có tăng thêm nhiều ví dụ để minh họa cho lý thuyết vì có nhiều phần lý thuyết rất trừu tượng .',
#  'các yêu cầu về đồ án môn học nên đươc đưa ra chính xác trước khi sinh viên bắt đầu thực hiện chia nhóm và làm đồ án .',
#  'dạy dễ hiểu dễ tiếp thu , tập trung vài kiến thức trọng tâm .',
#  'dạy chưa được kỹ lắm , điểm nên thoáng hơn .',
#  'chưa chuẩn bị kỹ bài giảng để có thể trả lời các thắc mắc của sinh viên trên lớp .',
#  'cô khá tận tâm cho học sinh .',
#  'cần cải cách lại nội dung các bài thực hành , một số kiến nội dung trong bài thực hành đã trở nên lỗi thời .',
#  'giảng viên có khả năng truyền đạt kiến thức tốt .',
#  'cho làm nhiều bài tập .',
#  'nghiên cứu khoa học .',
#  'giáo viên dạy rất tận tâm , nhiệt tình .',
#  'thầy cô hướng dẫn đồ án hệ thống thông tin cần có thêm một vài buổi gặp mặt với sinh viên và đưa ra lịch cố định trên trường để sinh viên thắc mắc có thể lên hỏi trực tiếp !',
#  'chỉ thông báo trên lớp sẽ khó tránh sai sót .',
#  'cô viết ở góc bảng gần chổ bụt giảng khiến nhiều khi khó quan sát được ạ .',
#  'đề nghị lắp thêm quạt .',
#  'dạy kỹ .',
#  'bài tập cần đa dạng hơn .',
#  'nói rất nhỏ .',
#  'có lúc làm bài sai giáo viên nói làm hơi tự ái .',
#  'không sửa các bài tập thực hành .',
#  'em chưa hiểu rõ cách thức chấm điểm bài kiểm tra thực hành .',
#  'làm bài tập nhiều mặc dù không hiểu lắm .',
#  'thi thoảng nghỉ học không thông báo trên daa .',
#  'thầy dạy dễ hiểu , tiết học dễ hiểu , sôi nổi .',
#  'thầy giảng dạy nhiệt tình , truyền cảm .',
#  'giảng dạy rất chi tiết , dễ hiểu và dễ tiếp thu .',
#  'truyền đạt những kiến thức tốt .',
#  'cô vui tính .',
#  'nếu có thì chỉ hướng dẫn bằng lý thuyết mà không làm bài tập mẫu cho sinh viên .',
#  'cô chưa có nhiều kênh bài tập cho sinh viên .',
#  'bạn nào khá thì có thể áp dụng công thức vào bài tập cả lớp chưa đến 30% còn thực sự hiểu môn học thì rất ít người hiểu .',
#  'thầy dạy hơi nhanh .',
#  'ít hướng dẫn sinh viên trong giờ thực hành .',
#  'không thực hành được buổi nào .',
#  'thầy dạy phần lý thuyết hay , nắm bắt được khả năng của sinh viên .',
#  'ví dụ đề tài của em là doubledot các nguyên lý cơ bản , bao gồm 7 nguyên tắc của bohm ( 1983 ) .',
#  'giáo viên nhiệt tình , dạy dễ hiểu , tận tình với sinh viên .',
#  'tân tâm , nhiệt tình trong lớp lẫn bên ngoài .',
#  'thầy giảng dạy tận tâm nhiệt tình .',
#  'thầy vui tính , giảng bài dễ hiểu , nhiệt tình .',
#  'thầy giáo dạy nhiệt tình .',
#  'dạy dễ hiểu , gần gũi sinh viên .',
#  'cô dạy rất nhiệt tình và tài liệu của cô rất cụ thể dễ hiểu , cô hướng dẫn rất tận tình .',
#  'mong thầy cố gắng trong các học kỳ sau .',
#  'cần đưa ra nhiều ví dụ minh họa hơn .',
#  'giảng viên hoà đồng , vui vẻ , chỉ giảng tận tình sinh viên ham học hỏi .',
#  'giảng viên không dạy một tiết thực hành nào .',
#  'không !',
#  'nên có sự thống nhất giữa các giảng viên bộ môn trong đề cương giảng dạy .',
#  'có những phần kiến thức chỉ một nửa lớp được học nhưng giảng viên nghĩ là cả lớp đã học rồi nên chỉ overview , những sinh viên còn lại khó nắm được .',
#  'máy tính cập nhật nhanh hơn .',
#  'vui , hòa đồng , nhiệt tình .',
#  'có giúp đỡ sinh viên học tập nghiên cứu .',
#  'giảng viên tận tâm , nhiệt tình , ham học hỏi .',
#  'tuy nhiên cô nên cân nhắc lại về số lượng yêu cầu đối với sinh viên để sinh viên không bị khớp vì quá nhiều dẫn đến làm qua loa cho có , như vậy thì kết quả lại không tốt .',
#  'cô rất tận tâm , rất ok , em rất thích cách dạy và học của cô ( mặc dù hơi nhanh tí ) .',
#  'mong thầy và nhà trường xem xét lại những điều em vừa nói .',
#  'thầy tận tâm , nhiệt tình , tạo động lực cho sinh viên .',
#  'thầy giáo tận tình , dạy kỹ , thường đưa ra câu hỏi để xem xét mức độ hiểu biết của sinh viên .',
#  'cần tăng cương trao đổi giữa sinh viên và giáo viên .',
#  'nói chung là nghe không bao giờ nghe rõ được .',
#  'cách truyền đạt của giáo viên chưa có sức hút đối với sinh viên nhiều cho lắm .',
#  'cô giáo thân thiện dễ gần , thực hành nhiều .',
#  'chưa tiếp thu trọn vẹn .',
#  'cần cải tiến trang thiết thực hành .',
#  'giảng kỹ hơn .',
#  'còn hơi kéo thời gian .',
#  'có nhiều bài tập về nhà cơ bản lẫn nâng cao và giảng viên sửa bài đủ .',
#  'thầy rất hiền và kiên trì giảng dạy cho lớp mặc dù môn học này đối với em không được hứng thú lắm .',
#  'đôi lúc giảng bài hơi nhanh .',
#  'có một số buổi không đi dạy .',
#  'thầy nhiệt tình và dạy dễ hiểu .',
#  'có kiến thức nền tảng này , sinh viên có thể học thêm bất kỳ công nghệ cụ thể nào đó dễ dàng , cũng như tiếp thu thay đổi công nghệ mới nhanh chóng .',
#  'cấu trúc đề cương của thầy chưa rõ ràng , lý thuyết chưa được trình bày rõ trong các buổi học .',
#  'tài liệu hỗ trợ toàn tiếng anh rất khó học .',
#  'chưa nhận được gì từ môn học này .',
#  'giảng viên không hề giảng dạy , chỉ đưa đề cương rồi thôi .',
#  'bài tập mỗi tuần đều có và đầy đủ .',
#  'em xin cảm ơn .',
#  'thầy cần phải cho sinh viên biết được học môn này có tác dụng gì và làm được gì khi học xong .',
#  'đề nghị tăng thời gian thưc hành .',
#  'không được làm những chuyện riêng trong lúc dạy thực hành .',
#  'hỗ trợ thêm giáo trình không phải slide cho sinh viên .',
#  'cô wzjwz259 rất vui và nhiệt tình .',
#  'giáo viện nhiệt tình , tận tâm .',
#  'kiến thức được giảng viên trình bày rõ ràng , dễ hiểu cho sinh viên .',
#  'cần thêm nhiều kit để thực hành .',
#  'dạy khó hiểu quá nhanh .',
#  'luôn gần gũi , tham khảo ý kiến sinh viên và thống nhất cũng sinh viên .',
#  'sắp xếp lịch học bù chưa hợp lý .',
#  'nhà trường nên đưa môn học này vào thời khóa biểu bắt buộc ở học kỳ 1 của các sinh viên năm nhất nhằm giúp các em nắm biết được mình nên học gì , mình có nên chuyển đổi ngành hay không .',
#  'thời gian thực hành cần nhiều hơn .',
#  'giảng viên rất nhiệt tình trong giảng dạy .',
#  'slide chuẩn bị chưa tốt .',
#  'thầy hay đòi hỏi sinh viên những điều hơi quá cao .',
#  'cô giảng hướng dẫn nhiệt tình .',
#  'chúng em đã gặp khó khắn với khổ giấy nhỏ , mô hình thì lớn và phức tạp .',
#  'giảng quá nhiều không đánh vào trọng tâm .',
#  'em không muốn nói gì nhưng mong thầy xem lại cách đánh giá sinh viên để công bằng hơn , cái sinh viên không biết không phải chỉ ở cúp tiết mà còn ở cách giảng dạy , truyền đạt ở giảng viên , ví dụ như cô wzjwz324 , rất dễ hiểu , tận tâm .',
#  'cô có nhiều hình thức giảng dạy hay .',
#  'hơi khó .',
#  'thầy đi trễ .',
#  'giảng tốt .',
#  'nói mở rộng nhiều vấn đề về môn học .',
#  'cần tăng cường nội dung nghe và nói để sinh viên giao tiếp tốt hơn bằng tiếng anh .',
#  'giảng viên tạo điều kiện làm nhiều bài tập .',
#  'hỗ trợ thêm về các thiết bị dạy và học .',
#  'ít giải bài tập trên lớp .',
#  'chia sẻ .',
#  'bám sát nội dung chính .',
#  'cần thêm các đoạn code cho các giải thuật bổ sung các phương pháp để giải quyết các bài toán liệt kê .',
#  'thông tin đầy đủ về bài tập và các nguồn tham khảo .',
#  'cô tận tâm , nhiệt tình , phương pháp dạy dễ hiểu .',
#  'thầy giảng rất dễ hiểu và thú vị , thu hút .',
#  'hướng dẫn chi tiết về cách thực hành .',
#  'giảng viên chỉ cho đồ án và giải đáp các yêu cầu đồ án , không cung cấp tài liệu hay hướng dẫn cơ bản , sinh viên tự tìm hiểu với lý do là hệ tài năng nên cần tự xoay sở .',
#  'môn học toàn kiến thức mới mẻ , giảng viên nên giảng chi tiết hơn .',
#  'đến khi cuối kỳ , chỉ cần sinh viên mắc một sai sót nhỏ thì sẽ rớt môn .',
#  'cần thay đổi cách dạy và nội dung học của phần thực hành , các bài thực hành hiện tại của môn mạng máy tính chưa đảm bảo hiệu quả .',
#  'thầy dạy hay , tận tình góp ý từng bài .',
#  'cơ sở vật chất , phỏng máy không đủ phích cắm cho dụng cụ thực hành và số lượng sinh viên , máy còn tiềm ẩn nhiều virus .',
#  'trên lớp lý thuyết giảng viên yêu cầu sinh viên phải thực hiện đồ án theo những gì mình hướng dẫn , những nhóm sinh viên bổ sung thêm những liên hệ thực tiễn đều bị cho là sai , không phù hợp với đồ án .',
#  'thầy giảng bài hay và hiệu quả !',
#  'giảng viên nhiệt tình vui vẻ .',
#  'phòng học nên có rèm che sáng để khi chiếu slide được nhìn rõ hơn .',
#  'chương trình dạy lý thuyết và thực hành nên khớp với nhau hơn , tránh tình trạng thực hành trước khi học lý thuyết .',
#  'thầy giảng dạy nhiệt tình , dễ hiểu .',
#  'mong giảng viên ngày càng chấn chỉnh việc dạy học để các khoá sau được hiểu tốt hơn .',
#  'thầy dạy rất có tâm , và giảng cho sinh viên rất nhiều thứ !',
#  'nội dung khảo sat quá dài , nhiều mục lặp đi lặp lại , nhiều bạn khảo sát mà không cần đọc , toàn tích chàn .',
#  'dạy tốt và rất nhiệt tình chỉ dạy hoc sinh .',
#  'nhiệt tình , tân tâm .',
#  'nhưng học mới thấy kiến thức thầy dạy rất hay , bám sát thực tế , thầy dạy rất nhiệt tình , vui vẻ , khác với mọi người nói .',
#  'bài tập rất hay .',
#  'thầy cô cần cho nhiều dạng bài tập sát với đề thi hơn .',
#  'thầy giảng hay nhưng nên tự tin hơn , nói to hơn để học sinh hiểu bài một cách rõ ràng hơn .',
#  'mong thầy vui tính , gần gũi với sinh viên hơn .',
#  'giáo viên vui tính , hòa đồng , nhiệt tình .',
#  'cung cấp kiến thức trọng tâm .',
#  'cố gắng truyền đạt một cách tốt nhất để sinh viên được hiểu .',
#  'giọng của giảng viên nhỏ dù đã sử dụng micro .',
#  'dù phương pháp học tập này khá hiệu quả nhưng vẫn có chút nào đó nghi ngờ từ phần thuyết trình của các bạn , liệu các kiến thức đó có chuẩn xác và cập nhật chưa .',
#  'giáo viên có phong cách giảng dạy nghiêm túc .',
#  'cô rất vui tính nà , không khí lớp lúc nào cũng vui hết , cô dạy rất hay , dễ hiểu !',
#  'giảng viên giảng dạy rất tốt , thường xuyên cung cấp thêm nhiều kiến thức .',
#  'thầy luôn nhiệt tình , có những chia sẻ rất gần gũi với sinh viên .',
#  'có khả năng truyền đạt tốt .',
#  'thậm chí còn không có bài nào khó bằng các bài trong nội dung của lớp chuyên tin ở các trường cấp 3 .',
#  'thầy dạy tận tụy và tâm huyết .',
#  'thầy nên có cách dạy mới cho môn học này để được kết quả tốt cho tất cả mọi người thay vì để rớt rất nhiều người !',
#  'lịch thi thực hành cần được thông báo sớm tới sinh viên và phù hợp với thời gian môn học .',
#  'cô nên giảng kỹ và chi tiết từng bài vì nhiều bài đa số các bạn chưa hiểu thì cô lại giảng nhanh để chuyển qua bài khác .',
#  'dạy tốt đúng trọng tâm những gì cần biết .',
#  'nhiệt tình , lên lớp đúng giờ , dạy dễ hiểu .',
#  'nếu em buồn ngủ , dù lên lớp em vẫn sẽ ngủ , mà ngủ ở trên lớp thì đau lưng và tê chân lắm .',
#  'cơ mà em học môn này em hiểu colonlove .',
#  'thiếu kinh nghiệm truyền đạt .',
#  'bài giảng thú vị .',
#  'em nghĩ nội dung thực hành nên gần với đồ án hơn .',
#  'thầy nhiệt huyết và giảng bao quát đề cập đến nhiều khía cạnh của bài học vấn đề .',
#  'giảng viên giảng bài kỹ .',
#  'hệ thống đồ án chấm điểm theo mức độ hoàn thành của sinh viên , tạo sự ganh đua không hề nhẹ với những nhóm làm chung đồ án , kích thích sáng tạo không ngừng tìm hiểu xây dựng thêm chức năng mới cho đồ án nếu muốn được điểm cao .',
#  'nhiệt tình , tâm huyết .',
#  'ít chú trọng phần ngữ pháp .',
#  'giảng viên còn chưa tận tâm , phong cách giảng dạy chưa thu hút được sinh viên .',
#  'giảng rất dễ hiểu , hướng dẫn làm thực hành tốt .',
#  'thầy dạy rất nhiệt tình , khi dạy thầy luôn đi tới từng sinh viên để hướng dẫn .',
#  'giảng viên nhiệt tình trong giảng dạy và chấm điểm .',
#  'cách truyền đạt kiến thức đối với em là rất hiệu quả , trao đổi bài với sinh viên , cô rất nhiệt tình !',
#  'giảng dạy hay , dễ hiểu , tận tình .',
#  'kiến thức rộng , kinh nghiệm thực tế nhiều , truyền cảm hứng cho sinh viên .',
#  'cách dạy sáng tạo .',
#  'giảng bài dễ tiếp thu .',
#  'em rất hài lòng với cô .',
#  'thầy dạy dễ hiểu , sinh động .',
#  'cô chưa nắm bắt được thực trạng học của sinh viên .',
#  'ảnh hưởng đến tiến độ học tập và quỹ thời gian của sinh viên ( do học bù ) .',
#  'cô giảng bài dễ hiểu .',
#  'điều em hài lòng nhất đó là thầy đi rất đúng giờ và không dạy quá nhanh .',
#  'nên có giáo trình thống nhất cho tất cả các lớp và học kỳ học .',
#  'em nghĩ cần có các bài tập lớn để nâng cao khả năng lập trình của các sinh viên .',
#  'rất nhiệt tình với sinh viên .',
#  'giảng viên có phương pháp giảng dạy hay , cập nhật , phù hợp với sinh viên .',
#  'giảng dạy tốt và có tâm .',
#  'dạy lý thuyết hơi nhiều .',
#  'giảng viên chấm bài quy chụp theo kết quả .',
#  'thời lượng môn học quá dài , sinh viên cảm thấy mệt mỏi .',
#  'giảng viên vui tính dễ tương tác với sinh viên .',
#  'nhiệt tình hay giúp đỡ sinh viên khi không biết , cho nhiều bài tập .',
#  'thầy cho điểm phần nào còn theo cảm tính , chưa được công bằng .',
#  'thầy giảng dạy rất nhiệt tình .',
#  'thầy nhiệt tình , bài giảng phong phú đa dạng .',
#  'không có gì đặc biệt .',
#  'mỗi tháng chỉ gặp giảng viên một lần rất khó cho việc học hỏi , hướng dẫn từ giáo viên .',
#  'thầy nên chuẩn bị riêng một slide cho mình để giảng dạy , không nên lấy slide của người khác rồi đến khi sơ sót , thầy lại lấy cái lý do " đây không là slide của tôi " , " cái này tôi cũng không rõ nữa " .',
#  'thầy cho làm các bài tập tại lớp trong khi sinh viên chưa biết gì về vấn đề đó .',
#  'đôi khi đi quá sâu vào một vấn đề bên lề .',
#  'giảng viên dạy tận tâm , nhiệt tình , dễ hiểu .',
#  'cô thật nhiệt tình .',
#  'phòng thực hành tốt .',
#  'nói chuyện lan man , không liên quan đến môn học quá nhiều .',
#  'giảng viên rất tận tâm .',
#  'phân bổ hợp lý thời gian học và nên cho xem nhiều video hơn là nghe .',
#  'thầy bận nhiều nên cũng nghỉ nhiều , hi vọng thầy có thể sắp xếp thời gian .',
#  'giáo viên sử dụng giờ trên lớp hiệu quả .',
#  'giáo viên tận tình , dạy truyền đạt tốt .',
#  'giảng viên dạy tốt , nhiệt tình .',
#  'giảng viên tạo cảm hứng cho sinh viên học tập .',
#  'chán .',
#  'thầy nhiệt tình , tận tâm giúp đỡ sinh viên .',
#  'dạy quá chậm , quá cặn kẽ .',
#  'thầy wzjwz174 ít cho bài tập về nhà .',
#  'thầy đôi khi nói hơi khó hiểu .',
#  'giảng viên tận tâm , nhiệt tình , hỗ trợ giải đáp thắc mắc môn học cho sinh viên .',
#  'nên đi sâu vào vấn đề , giúp sinh viên hiểu tốt môn học , và nên có những ứng dụng cụ thể mà môn học đem lại .',
#  'làm bài tập .',
#  'cứ ngỡ được 10 điểm là chắc chắn rồi .',
#  'thầy yêu cầu quá cao đối với một sinh viên có thể tiếp thu mọi kỹ năng cần truyền đạt vào một đồ án .',
#  'thêm phòng thiết bị để thực hành .',
#  'dễ hiểu đầy đủ .',
#  'điểm .',
#  'giáo viên tốt bụng , vui tính .',
#  'slide quá khó hiểu , nhiều chỗ không giải thích rõ ràng , đặc biệt là các bài hướng dẫn thực hành .',
#  'nói rõ mục tiêu cũng như các bước làm của lab , khối lượng bài tập vừa phải .',
#  'giải đáp kịp thời những thắc mắc cho sinh viên .',
#  'giảng viên nhiệt tình , phương pháp dạy dễ tiếp cận , dễ hiểu .',
#  'phòng học cần lắp thêm quạt và ổ cắm vì sinh viên phải sử dụng laptop để làm bài tập , cần có thêm màn che cửa sổ để có thể theo dõi bài giảng trên slide tốt hơn .',
#  'bài tập không cho ví dụ về nhà để xem lại .',
#  'giảng viên thiếu rất nhiều hoạt động để việc học bớt nhàm chán khi quá bám sát bài học .',
#  'thầy dạy dễ hiểu , rất hài lòng .',
#  'micro và các thiết bị âm thanh , máy chiếu cần nâng cấp .',
#  'cách giảng bài dễ hiểu , hay .',
#  'đầy đủ kiến thức .',
#  'chất lượng phòng máy rất tệ .',
#  'thầy giảng ngắn gọn , đầy đủ .',
#  'tốt giỏi chu đáo .',
#  'tuy có phần chém gió kinh điển nhưng kiến thức , hiểu biết rộng , đặc biệt về công nghệ .',
#  'chờ học sinh gửi email mới show được slide to lên , giảng cho qua loa không hỏi học sinh có hiểu gì hay không ?',
#  'tạo niềm vui cho bọn em tuy lý thuyết bọn em rất đuối sức .',
#  'nhiệt tình , truyền cảm hứng .',
#  'thầy hài hước , giọng truyền cảm .',
#  'thầy dạy rất nhiệt tình , tâm huyết , dễ hiểu .',
#  'không hiểu cách chấm bài thi của thầy .',
#  'tiết học chưa được thu hút .',
#  'giảng viên nên thay đổi phương pháp giảng dạy để tương tác nhiều hơn với sinh viên .',
#  'cần vào thẳng nội dung .',
#  'thầy đẹp trai , dạy dễ hiểu , hay trò chuyện thực tiễn với học sinh .',
#  'cô dạy trên lớp và thực hành tận tâm .',
#  'em rất hài lòng về thầy .',
#  'thầy quá bảo thủ , thầy luôn cho rằng ý kiến của thầy là đúng nhất , ngoài ra mọi ý kiến khác đều sai .',
#  'thầy wzjwz252 giảng bài rất thu hút , kiến thức thầy rất rộng , luôn giải đáp thắc mắc cho sinh viên .',
#  'giảng viên rất hòa đồng vui vẻ , nhiệt tình trong giảng dạy .',
#  'giảng viên tận tâm , tạo điều kiện cho học sinh làm bài tập .',
#  'cần giải bài tập nhiều hơn .',
#  'kiến thức thực tiễn của thầy rộng , giảng dạy vui vẻ .',
#  'cô cũng không cung cấp hay giải thích gì đáp án của bài thi .',
#  'thầy rất nhiệt tình , nói rất nhiều đến khản giọng mà sức truyền tải không bằng thầy wzjwz159 .',
#  'kiến thức giảng dạy môn tiếng anh hầu như không giúp ích nhiều cho sinh viên trong việc tìm hiểu các tài liệu chuyên ngành .',
#  'thấy rất hiền , rất chi là hơi trẻ con .',
#  'giảng dạy hay , dễ hiểu , cuốn hút sinh viên .',
#  'cách tìm kiếm chúng ở đâu , khai thác chúng ở đâu chứ không phải là phải nhớ mấy cái phương thức hay các hàm rồi viết lên giấy vào đề thi cuối kỳ .',
#  'giảng hơi nhanh , chưa kỹ lắm .',
#  'những phần trọng tâm bài tập thì cũng không nói được " đây là phần quan trọng có trong đề thi các em cần chú ý " .',
#  'nghe , nói luyện tập cao .',
#  'giáo viên giảng hay dễ hiểu .',
#  'sử dụng phần mềm crack .',
#  'nhiều khi dạy quá thời gian .',
#  'tuy dạy chậm giúp học sinh dễ hiêu tuy nhiên nhiều bài khó thì sẽ khiến sinh viên dễ chán .',
#  'thầy vui tính , thương sinh viên , dạy dễ hiểu .',
#  'thầy bằng nhiệt tình tận tụy với sinh viên trong việc hướng dẫn đồ án .',
#  'dạy dễ hiểu , thân thiện .',
#  'có các phần ôn tập không liên tới bài kiểm tra .',
#  'không nên tổ chức thực hành hình thức 2 .',
#  'sự thân thiện và tận tình đối với học viên .',
#  'thầy giảng bài nhiệt tình , gần gũi với sinh viên , nội dung không hiểu có thể hỏi ngay thầy tại lớp .',
#  'giảng viên cần nắm vững xem sinh viên có hiểu được bài hay không và đưa ra phương án để sinh viên nắm vững kiến thức .',
#  'thầy thiện nhiệt tình .',
#  'truyền đạt thực tiễn vấn đề .',
#  'giáo viên rất nhiệt tình và tâm huyết đối với sinh viên .',
#  'âm thanh thầy giảng hơi nhỏ , khó khăn trong việc nghe giảng .',
#  'nên thay đổi hình thức khảo sát với môn học này thì môn học này không có lên lớp và chỉ có đến hạn thì báo cáo với giảng viên .',
#  'sinh viên hỏi , nhận câu trả lời cũng như không hỏi .',
#  'thầy dạy khá nhiệt tình , vui tính .',
#  'em nghĩ chỉ nên bắt buộc các bài tập có dạng căn bản , còn bài tập tương tự thì chỉ khuyến khích sinh viên làm thêm .',
#  'thầy dạy rất hay ạ !',
#  'không thống nhất trước về hình thức thi và làm bài tập , đến những tuần cuối cùng mới công bố .',
#  'nhằm giảm thời lượng giảng dạy cũng như sự thú vị khi học môn toán .',
#  'giảng viên dạy nhiệt tình , dễ hiểu .',
#  'em mong cô cũng như toàn thể các giảng viên hãy xem xét lại việc điểm danh vì đại học dù sao cũng là tự học chứ không phải như là phổ thông nữa .',
#  'cô cực kỳ nhiệt huyết , cô rất dễ thương colonlove cô yêu học trò của mình , cô cực kỳ khách quan , phong cách làm việc của cô rất giống người nước ngoài , em thích cô .',
#  'giảng viên nhiệt tình , tận tâm với công việc , slide dễ hiểu , hoạt động học tập sôi nổi .',
#  'chú ý giữ sức khỏe , nhất là cổ họng colonsmile .',
#  'thầy tận tâm , nhiệt tình .',
#  'máy ở phòng thực hành quá tệ .',
#  'thầy rất dễ thương .',
#  'giảng viên nhiệt tình , thân thiện .',
#  'thầy truyền đạt rất tận tình , dễ hiểu lượng bài tập , nội dung thi hợp lý , vừa sức với sinh viên .',
#  'giảng viên nên đến đúng giờ hơn và cho nhiều bài tập hơn .',
#  'em thấy những nội dung như vậy rất mơ hồ , có tính áp đặt suy nghĩ cho người học .',
#  'cần nâng cấp máy tính trong phòng thực hành , nhiều kit de2 bị lỗi cần sửa chữa hoặc thay mới .',
#  'em thấy môn này nhiều lý thuyết không đáp ứng đủ trong việc làm đồ án .',
#  'tạo điều kiện cho sinh viên làm việc nhóm .',
#  'phương pháp dạy chưa hay .',
#  'hay bị về trễ colonsad .',
#  'cần dạy chi tiết hơn .',
#  'cô giảng rất nhiệt tình .',
#  'dạy rất chi tiết và đầy đủ những kiến thức quan trọng .',
#  'đề thi thực hành cần nêu yêu cầu cụ thể , rõ ràng hơn .',
#  'giọng của giảng viên rất khó nghe nên không thể nghe giảng hết những điều thầy nói .',
#  'giảng dạy hay , nhiệt tình .',
#  'giảng viên biết cách truyền đạt , giảng rất hay và dễ hiểu .',
#  'dạy hơi nhiều , và hơi nhanh .',
#  'nên tạo không khí thoải mái cho tiết học để sinh viên dễ hiểu bài và thêm yêu thích môn học của giảng viên .',
#  'giảng dạy tận tâm .',
#  'cả năm toàn học vòng lặp " if " " for " " while " đến bữa cuối mới lơ mơ học được struct với tạo file header mà ra đề 5 điểm trong phần đó .',
#  'gần gũi , thân thiện với sinh viên , khả năng truyền đạt kiến thức tốt .',
#  'quá dễ dẫn đến buồn ngủ .',
#  'giảng viên không có tính hài hước .',
#  'vui tính , nhiệt tình .',
#  'thầy vui tính , giảng bài hay , đưa nhiều thông tin thực tế vào bài giảng .',
#  'thẩy wzjwz311 rất vui và nhiệt tình .',
#  'giáo viên giảng dạy lôi cuốn .',
#  'nhiệt tình , dễ gần , truyền đạt tận tâm .',
#  'phương pháp truyền đạt của giảng viên chưa hiệu quả lắm .',
#  'giáo viên chưa tạo được không khí vui vẻ trong lớp học .',
#  'thầy giúp em biết mạch số là gì .',
#  'có lúc thầy lạc đề .',
#  'thầy dạy hơi chậm .',
#  'lần được học thầy , thấm nhiều thứ quá .',
#  'nhiều phần trong slide bài giảng của giảng viên không chính xác .',
#  'môn học cần phân chia hợp lý giữa các phần , phần nào khó cần nhiều thời gian để học nó , phần nào đã học thì chỉ ra những điểm đặc biệt cũng như thời gian học phần đó rút ngắn lại để các phần chưa học khác sẽ có thời gian nhiều hơn .',
#  'thực hành đúng tiêu chí môn học , đi từ dễ đến khó cho sinh viên học tập từng bước dễ hiểu , giảng viên tích cực giải đáp thắc mắc và hỗ trợ sinh viên trong giờ thực hành .',
#  'dạy dễ hiểu , sâu rộng .',
#  'thầy dạy nhiệt tình , vui vẻ .',
#  'thầy cực kỳ tâm lý , vui tính , dạy nhiệt tình và tận tụy với học trò .',
#  'thầy luôn chủ động tạo tranh luận và kiểm tra bài tập đầu giờ để sinh viên dễ dàng nắm bắt kiến thức .',
#  'nội dung tiết học còn lan man , cảm tưởng như thầy đang dạy về tiếng anh chuyên ngành , chứ không đào sâu về kỹ thuật .',
#  'nên tự tin hơn trong việc giảng dạy .',
#  'giảng viên có cập nhật thông tin mới nhất về tình hình thực tế .',
#  'giáo viên rất nhiệt tình đối với sinh viên .',
#  'cảm thấy hứng thú khi lên lớp .',
#  'cùng một kiến thức nhưng cách truyền đạt của thầy dễ hiểu hơn , phù hợp với đại đa số sinh viên và tất nhiên là hữu dụng cho các môn khác chứ không hề lan man , thiếu trọng tâm như các giảng viên toán khác .',
#  'giảng viên chưa bám sát được sinh viên .',
#  'nhiều lúc thầy vẫn nói lý thuyết nhiều gây nhàm chán .',
#  'phần kiểm tra , thi cử đối với môn này nên đề cao tính tư duy logic của người học cũng như khả năng áp dụng kiến thức đã học vào thực tế thực nghiệm bằng cách chủ yếu đánh giá cao phần thực hành , viết code , làm project .',
#  'do môn còn mới nên nhiều vấn đề trục trặc trong quá trình thực hành thầy vẫn chưa giải quyết được , nhưng vẫn rất ủng hộ thầy .',
#  'luôn đảm bảo giờ giấc trong tiết học .',
#  'phòng lab chán lắm , hư hỏng hết cả .',
#  'nội dung môn học còn khô , cứng !',
#  'cô nói hơi nhỏ nên hơi buồn ngủ .',
#  'có lúc dạy khó hiểu .',
#  'thầy cho bài tập lạ , đa dạng .',
#  'sau khi đã học xong môn nhập môn điện tử , em thiết nghĩ môn học này cần có thêm những phần học về thực tế , để sinh viên chúng em có thêm động lực khi học những phần lý thuyết đôi khi " khô khan " và " xa lạ " đồng thời sẽ tạo được sự đam mê với bộ môn điện tử nói chung ngay từ những ngày đầu học " nhập môn " .',
#  'giáo viên vui tính , tích cực .',
#  'thầy dạy nghiêm túc .',
#  'cơ sở dữ liệu năm nay đã kết hợp với thiết kế cơ sở dữ liệu rồi , kiến thức nhiều mà thi có phần trắc nghiệm nữa thì đánh giá kiến thức học được chưa đảm bảo cho lắm ạ .',
#  'nội dung có liên hệ nhiều với thực tế .',
#  'nhiệt tình , luôn luôn giúp học sinh hiểu vấn đề cặn kẽ .',
#  'ra đề thì phải có đáp án , để sinh viên tập dần thói quen đọc code .',
#  'em nghĩ là cần thêm bài tập trên lớp và giải ngay trên lớp .',
#  'môn học chỉ nên thuyết trình tìm hiểu về egov không làm đồ án .',
#  'giảng viên có nhiều phương pháp giảng hay .',
#  'thực hành hình thức 2 khó có thể tham gia học thường xuyên lắm ạ !',
#  'cô giảng rất hay , rất nhiệt tình khi giảng dạy , rất vui tính .',
#  'giáo viên luôn chia sẻ những ứng dụng của kiến thức đã học với thực tiễn , chia sẻ khá nhiều kinh nghiệm thực tế vô cùng bổ ích với sinh viên .',
#  'thầy dạy nhiệt tình , rất chu đáo .',
#  'thầy dạy rất nhiệt tình với sinh viên .',
#  'em thấy rất hài lòng về môn học này , nên em không có ý kiến gì khác cả .',
#  'bàn ghế còn bụi .',
#  'cô vui tính , dạy tốt .',
#  'nhiệt tình , giỏi hay giúp đỡ sinh viên và cho nhiều bài tập .',
#  'kể chuyện hay .',
#  'tôi đã thấy giảng viên chỉ nhìn qua chưa đầy 30 giây và cho điểm 9 ngay lập tức .',
#  'phòng thực hành nên nâng cấp máy tính .',
#  'thầy ít khi nhắc lại về phần đã dạy hôm trước .',
#  'thầy nên tham gia thực hành cùng sinh viên , không phải là chỉ ngồi một chỗ , tụi em tự mày mò làm xong rồi thầy mới xuống chấm điểm .',
#  'mong muốn giảng viên nào cũng áp dụng như vậy thì quá tốt .',
#  'giảng viên cần chuẩn bị giáo án trước khi đến lớp , giảng viên diễn đạt không tốt cần phải học cách diễn đạt cho sinh viên dễ hiểu .',
#  'cần học môn lập trình trực quan trước .',
#  'cách truyền đạt kiến thức kém hiệu quả , cô dạy giống như là không dạy , chỉ đọc chữ trong slide rồi cho sinh viên làm bài tập .',
#  'làm tốn thời gian truyền đạt , dẫn đến hứng thú lên lớp nghe giảng bị hạn chế .',
#  'thầy luôn tạo cơ hội để sinh viên có thể được thực hành .',
#  'thêm phần anh văn chuyên ngành vào nội dung học .',
#  'cảm ơn cô và chúc cô nghỉ đẻ vui vẻ , mẹ tròn con vuông !',
#  'thầy dạy tốt , giảng dễ hiểu .',
#  'mở rộng kiến thức nâng cao cho sinh viên .',
#  'chưa có thời gian cho sinh viên ngẫm nghĩ điều mình mới học mà đã qua nội dung khác để theo kịp chương trình .',
#  'dạy dễ hiểu .',
#  'thầy vui vẻ , thoải mái .',
#  'thầy tận tâm , dạy dễ hiểu , vui tính , lớp học thoải mái dễ tiếp thu .',
#  'em thích học môn này với cô wzjwz157 .',
#  'cô tận tình hướng dẫn chỉ bảo .',
#  'cập nhật điểm thi giữa kỳ chậm , nên sinh viên không biết mức độ phấn đấu như thế nào !',
#  'giảng dạy tận tâm , nhiệt tình , dễ hiểu .',
#  'đôi khi trong giờ học kể vài chuyện về đời để đỡ chán =) .',
#  'thầy không vui tính .',
#  'giảng nhiều phần nâng cao làm sinh viên bối rối .',
#  'thầy dạy vui vẻ .',
#  'cô dạy dễ hiểu , hỗ trợ tốt cho các bạn .',
#  'thời gian nộp bài tại lớp hơi ngắn .',
#  'cần có sách học hay , chi tiết , hiệu quả colonsmilesmile .',
#  'phương pháp giảng dạy còn khó hiểu .',
#  'tận tình chu đáo .',
#  'nội dung lý thuyết và thực hành của môn học không có bất kỳ liên hệ gì với nhau nội dung lý thuyết không phù hợp với môn học và không tạo được sự quan tâm và mong muốn của sinh viên về kiến thức quản trị mạng như mong đợi .',
#  'cần có khả năng truyền đạt tốt hơn !',
#  'giảng viên dạy có hiệu quả cao , mang tính thực tiễn .',
#  'giáo viên truyền đạt kiến thức đầy đủ , dễ hiểu , nhiệt tình giảng dạy .',
#  'em xin lỗi nhưng đó là sự thật !',
#  'cô tận tâm , hỗ trợ nhiệt tình .',
#  'không có giáo trình .',
#  'phương pháp tư duy cho sinh viên , để sinh viên tự giải quyết các vấn đề .',
#  'giảng dạy dễ hiểu , linh động trong nhiều bài tập .',
#  'giảng viên giảng dạy tận tình , vui vẻ giúp học viên nhận thức được nhiều kiến thức .',
#  'cải thiện chất lượng phòng máy thực hành .',
#  'nếu được chọn , cô luôn là lựa chọn hàng đầu cho các môn kinh tế .',
#  'cần thêm bài tập và rèn luyện kỹ năng giao tiếp .',
#  'nhiệt tình giảng dạy .',
#  'thoải mái về thời gian .',
#  'em còn chưa thấy mặt thầy nữa , hoặc có nhưng quên rồi colondoublesurprise .',
#  'các nội dung môn học thầy triển khai không đúng theo khung , mới vào mà thầy dạy servlet thì rất khó hiểu , sinh viên có góp ý qua thầy chủ nhiệm nhưng vẫn không thay đổi .',
#  'mọi việc điều được sinh viên tự học , tự tìm hiểu thông qua các trang mạng , thông qua việc email trực tiếp với giảng viên .',
#  'slide bài giảng còn lẫn lộn anh việt , phần tiếng việt thì giảng viên lại dùng google dịch nên đọc không hiểu .',
#  'cách truyền đạt tốt , tận tâm .',
#  'cô rất nhiệt tình và thân thiện với sinh viên .',
#  'giảng viên tận tâm với việc dạy học , tạo cảm hứng học tập cho sinh viên .',
#  'cần cho nhiều thời gian để sinh viên có đủ thời gian hoàn thành đồ án môn học .',
#  'thầy rất vui tính , truyền tải thông tin tuyệt vời .',
#  'đôi lúc hỏi một số câu hỏi rất mơ hồ khiến sinh viên không biết đang được hỏi về khía cạnh nào , cũ hay mới ( chương trước hay chương hiện tại ) .',
#  'hy vọng thầy sẽ cải tiến làm cho hoạt động sôi nổi hơn .',
#  'quá nhàm chán , không nâng cao được kiến thức .',
#  'thầy dạy khá nhiệt tình vui tính .',
#  'thầy khá nhiệt huyết và gần gủi với sinh viên .',
#  'bài tập khắt khe .',
#  'theo thời khóa biểu hiện nay thì học thực hành trước nên sinh viên lúc thực hành chưa hiểu vấn đề nên khó khăn trong việc làm bài .',
#  'cô nên tăng tốc độ giải bài hơn .',
#  'tài liệu tiếng anh gây khó khăn cho ôn thi .',
#  'giảng dạy tận tình , vui vẻ .',
#  'giảng viên dạy có tâm huyết , kỹ càng với sinh viên , nhiệt tình giúp đỡ .',
#  'khả năng truyền đạt kiến thức không cao .',
#  'cần nâng cao chất lượng trang thiết bị .',
#  'giảng viên vui tính , thân thiện .',
#  'đầu tư các thiết bị cho sinh viên mượn , như điện thoại android , windows phone .',
#  'thầy dạy tốt và tâm huyết .',
#  'việc phân chia nhóm không hợp lý dẫn tới chất lượng học tập không tốt .',
#  'thầy nhiệt tình , vui vẻ .',
#  'tận tâm nhiệt tình , giảng giải cho sinh viên chưa hiểu tỉ mỉ .',
#  'phần máy tính không hỗ trợ cho việc học nhiều , chỉ làm sinh viên phân tán .',
#  'sự nhiệt tình , tâm huyết .',
#  'đó là tiền của họ , họ muốn dùng thì tùy họ , người khác nghèo không phải lỗi của họ , chưa kể tiền thuế họ đóng góp cho nước cũng đủ để gọi là xây dựng rồi .',
#  'các dạng bài tập rõ ràng , tài liệu cung cấp đầy đủ .',
#  'giảng viên dạy tận tình , cung cấp đầy đủ kiến thức cho sinh viên .',
#  'cần tăng thời gian học .',
#  'nên tổ chức thêm những buổi hội thảo liên quan đến nội dung môn học .',
#  'dạy đúng trọng tâm .',
#  'đề nghị thầy share slide giảng dạy trên lớp .',
#  'nên trang bị trang thiết bị cho phòng thực hành và phòng lab để sinh viên có thể thực hành và học trực tiếp trên thiết bị thật .',
#  'thầy giảng dạy rất nhiệt tình và vui tính .',
#  'nên cải tiến hệ thống chấm điểm online , update bài tập cho tất cả học sinh làm rồi có bảng xếp hạng , như bên codefun của miền bắc .',
#  'bài giảng thực tế .',
#  'kiến thức thầy dạy rất hay và bổ ích .',
#  'hạn chế dạy bằng slide .',
#  'nói sâu về vấn đề khó .',
#  'thầy lên lớp không đúng giờ giấc , thường xuyên đi trễ .',
#  'chất lượng phòng máy kém .',
#  'phong cách giảng dạy rất hay .',
#  'giáo viên giảng dạy sử dụng nhiều ví dụ thực tiễn .',
#  'cần tuân thủ đúng và đủ giờ .',
#  'thầy rất nhiệt tình và năng động , học thầy có thêm nhiều kiến thức mới không chỉ gói gọn trong nội dung môn học .',
#  'thầy giảng bài kỹ , dễ hiểu !',
#  'nhiệt tình giảng dạy , giải đáp thắc mắc rất chi tiết , cung cấp đầy đủ kiến thức cần thiết để kiểm tra .',
#  'thầy giảng nhanh và cách truyền đạt hơi khó hiểu , đưa ra khá ít ví dụ để sinh viên có thể hiểu bài rõ hơn .',
#  'các giảng dạy của giảng viên còn khó hiểu , rối rắm .',
#  'điện thoại không liên lạc được .',
#  'chưa học nhiều với thầy nên chưa có ý kiến gì về thầy .',
#  'nội dung thực hành nên thay đổi doubledot mỗi tuần thực hành các phần lý thuyết trên lớp và giảng viên hướng dẫn làm đồ án cuối kỳ .',
#  'giảng viên tăng cường giải đề của các năm .',
#  'thiếu thiết bị thật để thực hành .',
#  'nhiệt tình giúp đỡ sinh viên .',
#  'giảng bài rất dễ hiểu .',
#  'thực sự em vẫn chưa hiểu ngoài việc để làm bài tập thì wireshark được dùng để làm việc gì khác .',
#  'em nghĩ cơ sở vật chất vẫn còn yếu kém , ngồi xa không thể nhìn rõ được slide bài giảng của cô giáo , phòng học rất nóng .',
#  'thầy giải nhiều bài tập cho sinh viên giúp sinh viên củng cố kiến thức sau khi học lý thuyết .',
#  'cô rất vui vẻ , nhiệt tình , tâm huyết .',
#  'cần có các thiết bị di động thật để sinh viên thực hành khi cần thiết , vì các chương trình mô phỏng trên máy tính là không đầy đủ .',
#  'thầy dạy dễ hiểu , code mẫu đầy đủ .',
#  'điều em hài lòng nhất đó là thầy với tốc độ phù hợp và rất dễ hiễu .',
#  'nên thống nhất lại nội dung môn học so với cách thi của phòng đào tạo .',
#  'thầy dạy hay , nhiệt tình , không bao chê bai sinh viên dù mặc dù không tốt mà hướng sinh viên đến suy nghĩ tích cực hơn , cố gắng hơn .',
#  'giảng dạy nhiệt tình , quan tâm tới sinh viên .',
#  'cần tăng chú ý về kỹ năng cần thiết trong toeic như nghe , đọc .',
#  'kính mong giảng viên có thể cho thêm nhiều bài tập nhằm giúp sinh viên luyện tập , nắm bắt nội dung môn học và vận dụng nó hiệu quả hơn , giúp ích cho việc học các môn sau này .',
#  'cần chú trọng hơn vấn đề học thực hành phòng máy không đáp ứng yêu cầu doubledot không có trình biên dịch giáo viên thực hành không sử dụng hiệu quả giờ thực hành .',
#  'thầy wzjwz239 nói chuyện cọc lốc , không hiểu vấn đề gì hỏi thầy thì thầy lại như quát vào mặt , tạt nước lạnh , … nói chuyện xưng hô mày - tao ( có lúc thì xưng tớ - cậu nhưng lời nói đầy ẩn ý ) , hay nói móc và tìm cách bắt bẻ sinh viên .',
#  'thầy có hướng dẫn đồ án rất tận tình , luôn giải đáp các câu hỏi và thắc mắc của sinh viên về đồ án rất nhanh .',
#  'giúp sinh viên cảm thấy thoải mái trong giờ học .',
#  'cô giảng dạy tận tình .',
#  'hơi khó tính ạ .',
#  'kiến thức nhiều , khó tiếp thu , phân loại chưa rõ .',
#  'thầy nên cho thêm bài tập về nhà .',
#  'những điều này nghe tưởng chừng không liên quan đến môn học , nhưng lại giúp cho sinh viên phần nào có định hướng được công việc tương lai của mình .',
#  'em học ở phòng mà bên cạnh là công trình đang thi công , khá là ồn ào , vì thế khi học đến phần nghe , em không thể nghe được gì , và bài nghe bị gián đoạn .',
#  'thầy không sửa bài tập , trên lớp thầy chỉ giảng lý thuyết theo em như thế là ít có hiệu quả .',
#  'thầy ít quan tâm .',
#  'giảng dạy tích cực , dễ hiểu .',
#  'không dùng điểm để đánh giá , nó làm sinh viên không dám thực hiện .',
#  'dạy hay , dễ hiểu , tận tình .',
#  'không khí lớp học thì không được sôi nổi .',
#  'bài tập thực hành mỗi tuần hơi khó , mong rằng ở mỗi bài tập giảng viên có thể cung cấp bài giải kỹ càng để sinh viên có thể nghiên cứu và hiểu được cách làm .',
#  'thầy rất thoáng và thoải mái .',
#  'thầy cần có tương tác với sinh viên qua mail hay moodle vì có đôi lúc có thắc mắc nhưng thầy không phản hồi .',
#  'kiến thức đơn giản .',
#  'phần lý thuyết lặp lại nên chán , không thu hút .',
#  'thầy dạy rất hay và rất nhiệt tình .',
#  'giảng viên giảng dạy theo đúng thời gian môn học .',
#  'thầy rất dễ gần .',
#  'khi sinh viên hỏi phải có câu trả lời chính xác không được bỏ qua những câu hỏi của sinh viên .',
#  'chấm điểm dựa trên mức độ thấu hiểu bài , hay đưa ra lời khuyên hữu ích .',
#  'luôn nhiệt tình trong giảng dạy .',
#  'thầy vui vẻ .',
#  'giảng bài kỹ càng , dễ hiểu .',
#  'cần tăng thời gian thực hành nói lên .',
#  'cô giảng dạy rất nhiệt tình và dễ hiểu .',
#  'giảng dạy tốt .',
#  'nhiệt tình , cô dễ thương =) .',
#  'giảng viên dạy truyền cảm hứng , sử dụng thời gian hợp lý .',
#  'giảng viên dạy tận tâm nhiệt tình .',
#  'thì có thể lướt nhanh hơn vì phần này khá dễ .',
#  'giảng viên có chuyên môn rất tốt , kiến thức rộng , giải đáp được mọi thắc mắc của sinh viên .',
#  'giảng viên hiền lành , nhiệt tình giúp đỡ khá nhiều cho sinh viên khi sinh viên không hiểu bài .',
#  'giảng viên rất tận tình !',
#  'thầy rất nhiệt tình , năng nổ .',
#  'truyền đạt có cảm hứng , hướng dẫn sinh viên học tập thế nào sau khi ra trường để xin việc .',
#  'học thoải mái , ít áp lực .',
#  'cô dễ thương và giảng bài tận tình .',
#  'cô dạy rất tốt , nhiều bài tập .',
#  'thầy giảng dạy nhiệt tình dễ hiểu , sửa bài tập cẩn thận .',
#  'giảng viên rất đảm bảo giờ lên lớp .',
#  'thầy là giảng viên dạy toán hay nhất trường .',
#  'môn học này thật sự rất khó và chương trình học hơi nặng , lúc trước môn này dược chia ra làm 2 môn là cấu trúc dữ liệu 1 và cấu trúc dữ liệu 2 , năm nay lại gộp thành một nên sinh viên khó tải nổi kiến thức .',
#  'cần kết nối được mạng trong phòng lab .',
#  'nhiệt tình , phương pháp giảng dạy rất hiệu quả cách truyền đạt rất dễ hiểu và dễ tiếp thu biết cách truyền cảm hứng và tạo động lực học tập cho sinh viên .',
#  'luyện nghe nhiều hơn .',
#  'giảng viên giảng dạy rất truyền cảm , tạo cảm giác ham học và hệ thống bài tập dồi dào phong phú .',
#  'thầy có cách giảng bài rất hay và dễ hiểu .',
#  'thầy dạy bằng slide bài giảng hơi nhanh .',
#  'cách dạy của cô hay , thú vị , tạo động lực .',
#  'thầy dạy vui vẻ , không có áp lực quá khắt khe .',
#  'giải thích cặn kẽ đi sâu hơn nữa .',
#  'cho bài tập nhiều em rất thích colonsmile .',
#  'giảng viên vui vẻ nhiệt tình .',
#  'giảng viên nhiệt tình , phương pháp giảng dạy dễ hiểu .',
#  'giảng viên rất tâm huyết và nhiệt tình , giảng bài dễ hiểu .',
#  'thầy wzjwz127 dạy rất nhiệt tình .',
#  'cô nhiệt tình và đưa ra bài giảng hợp lý , dễ hiểu , có thể vận dụng làm bài .',
#  'giảng viên dạy nhiệt tình , truyền đạt kiến dễ hiểu .',
#  'thời gian học tập luôn thiếu sót , giảng viên chưa nhiệt tình giảng dạy .',
#  'rất thích được học cô .',
#  'tiếp cận với sinh viên một cách thân thiện , phương pháp dạy khoa học , dễ tiếp thu , dễ hiểu .',
#  'chữ viết nhỏ .',
#  'thường xuyên cho nghỉ mà không thông báo .',
#  'dạy hơi cao so với năng lực .',
#  'giáo viên nhiệt tình , tận tâm giúp đỡ sinh viên .',
#  'thích thầy chia sẻ kinh nghiệm .',
#  'quá khó tính , giờ cao su , giảng dạy lan man không hiệu quả .',
#  'giảng viên giảng không hay , đã vậy còn không nhiệt tình , không vui vẻ , không tạo cơ hội cho sinh viên hỏi về bài giảng .',
#  'thầy dạy không có sức hút , nhàm chán , gây buồn ngủ cho sinh viên .',
#  'thầy thật sự là một giảng viên dạy học rất có tâm .',
#  'thầy dạy nhiệt tình , rất hăng hái .',
#  'giọng cô êm êm , dễ buồn ngủ .',
#  'truyền đạt nhiều kinh nghiệm tốt cho sinh viên .',
#  'khi phản ánh kết quả bài tập không đúng thì cô lại lơ , cười rồi bỏ đi , không có một đáp án cụ thể .',
#  'thầy khá hài hước , nói những việc thực tế về ngành it , rất thiết thực .',
#  'thầy wzjwz177 rất gần gũi với sinh viên , thầy phát âm tiếng anh cũng rất dễ nghe .',
#  'phòng học ồn do cạnh khu xây dựng .',
#  'giảng bài dễ tiếp thu nhiệt tình .',
#  'lớp đã nghỉ 4 tuần liên tiếp chưa tính một vài ngày nghỉ khác .',
#  'em mong phần thực hành được hỗ trợ nhiều hơn nữa từ phía giảng viên .',
#  'giảng bài khó hiểu .',
#  'cô dạy rất nhiệt tình , cung cấp thông tin đầy đủ nhưng vẫn tạo điều kiện cho sinh viên tìm hiểu thêm .',
#  'thầy rất nhiệt tình với học sinh .',
#  'dễ học dễ hiểu .',
#  'hình như em đăng ký thầy dạy mà thầy dạy mấy buổi người khác dạy mấy buổi thì phải .',
#  'chưa giảng dạy nhiều về bài tập , cũng như hướng dẫn sinh viên hướng giải quyết nó .',
#  'thầy rất tận tình , luôn luôn giúp đỡ , hỗ trợ sinh viên .',
#  'thầy giảng rất hay và dễ hiểu , phong cách dạy độc đáo .',
#  'thầy wzjwz237 rất vui và nhiệt tình .',
#  'nên đưa môn wzjwz129 vào giảng dạy ngay sau môn wzjwz130 và trước khi học các môn chuyên ngành .',
#  'chất lượng tốt giáo viên nhiệt tình .',
#  'giảng viên dạy rất nhiệt tình .',
#  'thầy dạy sát theo slide nhưng một số kiến thức bài tập lại khó hơn nhiều .',
#  'trao dồi thêm về kỹ năng speaking và listening .',
#  'ít bài tập .',
#  'cô dạy có tâm huyết với học sinh , truyền đạt tốt , dễ hiểu .',
#  'đảm bảo giời lên lớp .',
#  'ngiêm túc , cứng rắn về vấn đề tự học .',
#  'em mail bổ sung bài thực hành giáo viên không hồi đáp , mail xin sửa điểm giảng viên không reply đồng ý xem xét hay không đồng ý .',
#  'thời gian cô up slide lên module còn chậm .',
#  'thầy đưa ra những demo thực tế , giúp sinh viên dễ hiểu .',
#  'nope .',
#  'thầy cho khá nhiều bài tập đa dạng .',
#  'các phần tiếng việt trong slide được ghi một cách khó hiểu và không rõ ràng , nhiều chỗ trong slide bài giảng có vẻ như được dịch bằng google dịch từ năm 2009 .',
#  'cô quan tâm đến sinh viên và truyền đạt kiến thức rất bổ ích .',
#  'không thực tế .',
#  'tiết học của thầy rất vui .',
#  'học trong phòng chất lượng cao hơn , phòng học hiện tại không có máy lạnh .',
#  'giảng viên chưa truyền đạt tốt , dạy còn chán , không có sự thu hút trong cách dạy lắm .',
#  'hướng dẫn rất tận tình , trình bày hướng dẫn rất đẹp , có phong cách , thể hiện một thái độ rất nghiêm túc trong công việc giảng dạy .',
#  'giảng bài dễ hiểu , dễ vận dụng .',
#  'thầy vui tính dạy dễ hiểu và cung cấp nhiều thông tin hữu ích cho sinh viên .',
#  'thầy quá chuyên nghiệp .',
#  'cô giảng có hơi khó hiểu .',
#  'tạo bầu không khí thoải mái cho sinh viên .',
#  'em rất hài lòng về phương pháp giảng dạy của thầy .',
#  'dạy nhiệt tình , theo sát môn học .',
#  'vì tính cô kỹ nên đôi lúc nói quá nhiều về một vấn đề ( lặp đi lặp lại ) làm mất thời gian trên lớp và sử dụng giờ học không hiệu quả .',
#  'mong giáo viên có thể giải đáp nhiều bài tập cho sinh viên hơn trên lớp .',
#  'đầu tư thêm nhiều công cụ dạy học .',
#  'giảng viên rất đúng giờ .',
#  'cách giảng dễ hiểu .',
#  'thang điểm đưa ra đầu khóa học không rõ ràng , nhất quán so với thang điểm cuối khóa .',
#  'thầy hứa sẽ up điểm giữa kỳ sớm mà điểm giữa kỳ thì tới giờ này vẫn chưa có ?',
#  'thực hành nhiều .',
#  'nhiệt tình với sinh viên , tư tưởng thoải mái .',
#  'cho sinh viên chép bài để nhớ kiến thức hơn , rèn luyện nhiều bài tập , dạy nhiệt tình .',
#  'nhiều hoạt động .',
#  'giảng viên áp dụng mô hình scrum để làm project là tốt nhưng không thành công .',
#  'hay kể các chuyện liên quan đến thực tiễn giúp bọn em tiếp thu nhanh hơn và cũng có hứng thú trong quá trình học .',
#  'đây là điều gây bức xúc với sinh viên .',
#  'khó hiểu ạ .',
#  'ân cần , tận tụy .',
#  'máy chiếu chưa rõ nét cho toàn thẻ sinh viên trong phòng .',
#  'cô nhiệt tình , sẵn sàng giảng lại các kiến thức mà sinh viên chưa nắm được khi học lý thuyết .',
#  'nâng cao trang thiết bị phòng học .',
#  'giảng viên nhiệt tình , hết mình truyền đạt kiến thức .',
#  'cô có thể giảng phần lý thuyết kỹ hơn được không ạ .',
#  'thầy nên share lại slide cho sinh viên !',
#  'nhiều tâm huyết với nghề .',
#  'dạy tốt , tận tình .',
#  'thầy rất nhiệt tình trong việc trả lời các câu hỏi phụ của sinh viên .',
#  'hiện tại em không nhớ nổi mặt của thầy fraction cô như nào nữa colondoublesurprise .',
#  'phòng thực hành cần nâng cấp và bổ sung thêm thiết bị để mọi người đều có điều kiện thực hành thực tế nhiều hơn .',
#  'giảng viên nên trao đổi với sinh viên nhiều hơn , giao bài tập và giải thích những thắc mắc của sinh viên về môn học .',
#  'cô thân thiện với học sinh , truyền cảm hứng , động lực tốt .',
#  'thầy kiểm tra quá nhiều .',
#  'thầy rất khắt khe trong việc dùng từ chuyên ngành .',
#  'thầy dạy rất tốt .',
#  'những gì được học nó nhằm mục đích gì ?',
#  'cần cung cấp thêm tài liệu học tập môn học này .',
#  'cách dạy của thầy rất nhàm chán , không có nhiều hoạt động thực tế , bài tập thầy cho chỉ áp sát lý thuyết mà chưa thực tế .',
#  'nên dành nhiều thời gian cho bài tập và hướng dẫn cụ thể phương pháp giải hơn .',
#  'đôi khi học sinh nào bận muốn về trước thầy vẫn cho .',
#  'nhiều lúc lớp chỉ có hai người đi học .',
#  'có thể chia nhóm ra làm thực hành !',
#  'thầy wzjwz83 rất nhiệt huyết trong việc giảng dạy .',
#  'thầy vui quá đi hi hi .',
#  'giảng viên nhiệt tình , chắt lọc nội dung cũng như mở rộng nhiều kiến thức về bộ môn .',
#  'thầy giảng rất hay , rất tận tâm với sinh viên .',
#  'em mong có sự thống nhất giữa thầy cô trong quá trình giảng dạy môn này .',
#  'chưa ổn .',
#  'giảng viên tận tâm , dạy tốt .',
#  'sử dụng giờ học hiệu quả .',
#  'cách nói chưa lôi cuốn .',
#  'thầy không đảm bảo giờ lên lớp , nếu có nghỉ thầy cũng không thông báo trước rất vô lý .',
#  'nhiệt tình truyền đạt kiến thức cho sinh viên .',
#  'lý thuyết và thực hành nên đi đôi với nhau .',
#  'thân .',
#  'thầy dạy quá tệ .',
#  'không có nhiều bài tập để làm thêm .',
#  'phòng học quá sáng , màn chiếu bị mờ rất khó nhìn , xin ban quản lý lắp rèm để sinh viên và giảng viên thuận tiện trong việc học tập và giảng dạy .',
#  'giáo viên quá tốt .',
#  'cần cân bằng việc giảng dạy giữa sinh viên yếu và khá trở lên .',
#  'nhiệt tình , giảng dễ hiểu , dễ thương .',
#  'giảng viên dạy rất dễ hiểu .',
#  'tài liệu cung cấp thiếu .',
#  'thầy nên đánh giá kỹ hoạt động trên lớp của từng thành viên trong nhóm , ai đóng góp nhiều , nghiêm túc .',
#  'giáo viên lên lớp muộn , nghe điện thoại trong lúc lên lớp thường xuyên , nghỉ dạy không thông báo .',
#  'đề nghị nên cho bài tập về nhà .',
#  'mong thầy giảng giải và cho bài tập từng bước nhiều hơn .',
#  'thầy cho đề thực hành cũng khá hay , nhưng mà thật thì em toàn code mấy bài đó trên notepad rồi nộp , không test gì cả , nhưng được cái là đồ án 10 thì điểm thực hành cũng 10 luôn .',
#  'khó hiểu , không sinh động .',
#  'chỉ dạy nhiệt tình .',
#  'giáo viên truyền đạt những vẫn đê sâu .',
#  'chưa cung cấp cách nhìn sâu hơn về môn học vào thực tế hiện nay , chỉ mới mang tính trừu tượng .',
#  'giảng viên dạy dễ hiểu , và đầy đủ nội dung .',
#  'không hướng dẫn kỹ .',
#  'nhiệt tình , chi tiết .',
#  'thầy cho chép bài ít thôi , tập trung sửa bài được không ạ .',
#  'khả năng truyền đạt chưa đi vào lòng người cho lắm !',
#  'thầy rất nhiệt tình , dạy rất kỹ , thầy cũng rất vui tính .',
#  'giảng viên nhiệt tình , vui vẻ , giờ học vui .',
#  'cô dạy không hấp dẫn , tuy hay nhưng không kích thích được sinh viên hoạt động .',
#  'thưa , không có ạ .',
#  'kiến thức môn học mang lại tương đối đầy đủ và thực tế giúp sinh viên nắm rõ phương pháp và cách thức để học tập các môn chuyên ngành sau này .',
#  'cách giảng dạy , tạo không khí sôi nổi trong lớp .',
#  'trình bày bài giảng một cách khoa học và hợp lý .',
#  'tuy nhiên , giờ trên lớp thầy chưa thực sự sử dụng hiệu quả lắm khi thiếu tương tác với sinh viên trong lớp để nắm tình hình học viên của mình .',
#  'thầy dễ thương , nhiệt tình , dạy dễ hiểu .',
#  'nên cho thời gian học nhiều hơn 2 tiết .',
#  'cô vui tính , hiền , khá nhiệt tình và gần gũi với sinh viên colonsmilesmile .',
#  'những gì quan trọng cần nắm bắt và tìm hiểu thêm .',
#  'cá nhân em thấy đôi khi nhìn thầy em cảm thấy hơi sợ sợ .',
#  'rèn luyện được kỹ năng giao tiếp , mạnh dạng đứng trước lớp nói tiếng anh .',
#  'thầy hướng dẫn thực hành hay .',
#  'cập nhật kiến thức thực tế .',
#  'giảng viên nhiệt tình , luôn luôn đến lớp đúng giờ .',
#  'chỉ có vấn đề thầy dạy hơi nhanh .',
#  'giảng viên truyền đạt còn chưa tốt .',
#  'tình trạng nghỉ không thông báo cho sinh viên để sinh viên đứng đợi giảng viên gần hết giờ rồi ra về nhiều lần .',
#  'cô giảng dạy chi tiết trong quá trình học .',
#  'kiến thức chưa có trọng tâm .',
#  'tiết học vui vẻ , thoải mái .',
#  'chưa tương tác nhiều với sinh viên .',
#  'thân thiện , nhiệt tình .',
#  'yêu cầu quá cao đối với một sinh viên , mặc dù chỉ là một đồ án nhưng không nhất thiết phải quá chi tiết về mọi khía cạnh cụ thể .',
#  'cô hướng dẫn phương pháp học tập hiệu quả .',
#  'thầy cần hoạt động trao đổi nhiều hơn với sinh viên .',
#  'thầy dạy rất dễ hiểu , đúng trọng tâm bài học .',
#  'cho quá nhiều bài tập , chỉ nên cho bài tập ví dụ điển hình .',
#  'giúp em hiểu ra được nhiều cái hay .',
#  'thầy giảng rất hay , dễ hiểu .',
#  'giảng viên giảng bài hơi nhàm chán , gây cảm giác buồn ngủ , có nhiều chỗ hơi lan man .',
#  'giáo viên giạy theo cách quá thụ động , tạo sự nhàm chán cho sinh viên !',
#  'thầy rất tận tâm nhưng không có kỹ năng sư phạm .',
#  'nội dung hơi nhiều nên giảm bớt lại .',
#  'thầy chỉ dạy rất tận tình , luôn hỏi học sinh phần nào chưa hiểu và giảng lại rất kỹ , những bài giảng của thầy rất hay .',
#  'mong thầy giải bài tập trên lớp .',
#  'do thời gian mỗi buổi học khá ngắn nên giảng viên cần tập trung vào những chủ đề quan trọng , phần còn lại nên để sinh viên tự tìm hiểu .',
#  'giáo viên rất tận tâm nhiệt tình .',
#  'mong rằng những môn có thực hành , giáo viên nên mở chat box và forum cho sinh viên dễ trao đổi với nhau , cũng như nhanh chóng nhận được lời giải đáp thắc mắc từ giáo viên .',
#  'cô dạy quá hay rồi .',
#  'thêm hệ thống ổ điện ngầm dưới nền nhà để tiện cho việc sinh viên có thể cắm laptop phục vụ học tập .',
#  'chất lượng môn học phù hợp .',
#  'cô dạy rất nhiệt tình và rất kiên nhẫn với sinh viên .',
#  'có sai nhận sai và sửa đổi khắc phục .',
#  'thầy dễ tính , dạy dễ hiểu , thầy dạy hay .',
#  'giáo viên dễ gần , tận tâm .',
#  'thầy rất vui tính dạy dễ hiểu .',
#  'không có hoạt động giảng dạy nào không hài lòng .',
#  'lên vừa cho học lý thuyết vừa cho thực hành .',
#  'môn học với kiến thức không quá nặng .',
#  'nội dung thực hành đã cũ , không được đổi mới và không sát với thực tế .',
#  'các code ví dụ không được chiếu hết trên slide .',
#  'chỉ dạy tận tâm .',
#  'thầy dạy nhiệt tình , chia sẻ những kiến thức bổ ích .',
#  'thầy dạy rất nhiệt tình , dễ hiểu , tận tâm .',
#  'giảng hơi ít .',
#  'em mong môn này có thể áp dụng nhiều hơn trong những đồ án .',
#  'giải ví dụ , bài tập nhiều hơn .',
#  'thành thật mà nói thì sau khi học buổi đầu xong thì em không muốn học thêm buổi thứ hai .',
#  'đề nghị thầy xem lại việc chấm chéo đồ án và báo cáo chéo đồ án .',
#  'bài dạy phụ thuộc nhiều vào slide , cách truyền đạt chưa thực sự phù hợp với cá nhân .',
#  'có slide bài giảng tiếng anh giúp nâng cao trình độ đọc hiểu tài liệu chuyên ngành và nâng cao kiến thức cho sinh viên .',
#  'học đúng giờ nhưng ra về thì sớm hơn quy định .',
#  'chuyên nghiệp .',
#  'giảng viên thoải mái , hòa đồng .',
#  'thầy dạy rất tốt !',
#  'cách truyền đạt kiến thức của thầy đối với em thì em cảm thấy không phù hợp lắm , em cần phải rất rất tập trung và hỏi đi hỏi lại nhiều lần mới có thể nắm bắt kiến thức .',
#  'thầy cho nghỉ hơi nhiều .',
#  'giảng viên nên cung cấp tài liệu học tập cho sinh viên !',
#  'thầy dạy nhiêt tình , kỹ càng !',
#  'thầy dạy hay , nhiều kiến thức mở rộng , được học trên slide tiếng anh .',
#  'thầy dạy tốt không phụ thuộc nặng vào chương trình .',
#  'slide bao nhiêu thầy đọc lại bấy nhiêu , cực kỳ khó hiểu và buồn ngủ .',
#  'cải tiến trang thiết bị phòng thực hành .',
#  'giảng viên nên dạy đúng giờ hơn hạn chế cho sinh viên về sớm .',
#  'em hi vọng trong các tiết học thầy có thể đi sâu vào kiến thức chuyên môn và giảm bớt thời lượng của hoạt động liên hệ thực tế .',
#  'chân thành cảm ơn thầy .',
#  'không có ý kiến nhiều .',
#  'không có .',
#  'cách chấm điểm của giảng viên không đánh giá đúng năng lực của sinh viên .',
#  'em không có ý kiến về mục này ạ .',
#  'thời gian và cách thức thầy dạy .',
#  'giảng quá khó hiểu .',
#  'các thiết bị âm thanh cần được đảm bảo hơn .',
#  'nên phát hành giáo trình chuẩn cho môn học .',
#  'dưới đây là hình thầy cung cấp toàn bộ tài liệu trong quá trình học .',
#  'lịch thực hành không được thông báo .',
#  'thầy dạy rất tốt , nhiệt tình và rất dễ hiểu .',
#  'lắp quạt phù hợp vì phòng có 2 dãy quạt 2 bên nhưng ngồi ở dãy giữa vẫn nóng , cần có màn che cửa sổ và có ổ cắm điện .',
#  'lên lớp toàn cho làm paper .',
#  'kiến thức được đưa vào ứng dụng nhiều bài toán .',
#  'giảng viên làm rất tốt trong việc giảng dạy bộ môn thực hành .',
#  'cô wzjwz253 nhiệt tình , giảng bài kỹ .',
#  'thầy wzjwz199 rất nhiệt tình trong quá trình giảng dạy .',
#  'sau kỳ thi giữa kỳ cấu trúc dữ liệu lý thuyết ( chủ yếu là thi về thuật toán sắp xếp ) thì thầy mới cho làm bài tập về các thuật toán sắp xếp .',
#  'giảng viên nhiệt tình , gần gũi với sinh viên .',
#  'có nghĩ 2 buổi không hề báo trước .',
#  'them nhiều tài liệu và video hướng dẫn .',
#  'giảng viên nên cho số lượng bài tập vừa phải , giải chậm và sâu ở mỗi dạng toán đặc biệt là những dạng toán khó .',
#  'cần có nhiều buổi thực hành trên thiết bị thật hoặc giảng viên nên đem thiết bị thật làm vài bày mẫu trên lớp .',
#  'môn học nên tập trung vào chuyên sâu các mục , nên có biên soạn giáo trình mới , chuyên sâu hơn .',
#  'thầy dạy dễ hiểu , rất hay .',
#  'thời khóa biểu phân chia không hợp lý , chưa học lý thuyết đã phải học thực hành .',
#  'cung cấp nhiều bài tập cho sinh viên tham khảo .',
#  'thầy cô dạy chưa sâu vào bài học .',
#  'nói nhỏ , rất khó nghe .',
#  'thầy hầu như không giải đáp thắc mắc của sinh viên khi bài tập mắc lỗi hoặc có nhưng rất hời hợt .',
#  'chưa thực sự tận dụng tốt thời gian và chưa mở rộng vấn đề .',
#  'công bằng .',
#  'thầy giảng rất kỹ và dễ hiểu , cho rất nhiều bài tập giúp sinh viên ứng dụng và nhớ được những gì đã học .',
#  'cô dạy dễ hiểu , vui vẻ với sinh viên , cung cấp đầy đủ kiến thức cần thiết .',
#  'bài giảng hơi khó hiểu .',
#  'nên muốn nhà trường tăng thêm thời gian học lý thuyết của môn này .',
#  'thường xuyên tổ chức thảo luận , thực hành nói .',
#  'giảng viên dạy có phần hơi nhanh .',
#  'giúp chúng em học tập tốt hơn .',
#  'thầy dạy hay tận tình .',
#  'thầy dạy rất hay , chi tiết .',
#  'tận tụy với sinh viên .',
#  'thầy rất nhiệt tình và có kiến thức sâu rộng , cung cấp nhiều kiến thức hay .',
#  'hầu như trong cả năm học , giảng viên chỉ đi dạy đúng thời khoá biểu chỉ từ 2 đến 3 ngày , còn lại giảng viên lại tự ý dời lịch học sang ngày thứ 7 mà không hỏi ý kiến của sinh viên , vì vào ngày thứ 7 có rất nhiều sinh viên có lịch học môn khác .',
#  'cần thêm nhiêu bài tập thực tế .',
#  'không tập trung vào giảng kiến thức cho học sinh hiểu .',
#  'thật sự rất thất vọng về việc dạy thực hành của thầy !',
#  'góp ý doubledot thầy nên có cách tiếp cận khác để cân bằng giữa vấn đề ngoại ngữ và kiến thức chuyên ngành .',
#  'thầy dạy lý thuyết được .',
#  'thầy dạy nhanh , hay !',
#  'nên cho nhiều bài tập hơn .',
#  'giảng viên nhiệt tình , quan tâm đến học sinh .',
#  'môn học có 5 lab mà chỉ học 2 lab là thi cuối kỳ , thầy nên lên lớp đủ số buổi quy định .',
#  'slide hơi khó hiểu .',
#  'giáo viên thực hành cần quan tâm , chỉ dẫn sinh viên tận tình hơn .',
#  'giảng viên lên lớp đầy đủ .',
#  'giảng viên nhiệt tình , hỗ trợ sinh viên tốt .',
#  'giảng viên hay cho nghỉ học mà không báo trước .',
#  'trang thiết bị còn hỏng hóc nhiều , thường xuyên trục trặc trong giờ học .',
#  'hiểu tâm lý học sinh nên mọi người trong lớp đều chú ý giảng bài .',
#  'phòng wzjwz325 thiết bị âm thanh hay xảy ra trục trặc làm gián đoạn buổi học .',
#  'vui tính , thân thiện .',
#  'nhiệt tình , năng nổ .',
#  'không có sự thoải mái khi học tập .',
#  'giảng viên dạy tận tâm , nhiệt tình , lên lớp đúng giờ .',
#  'mong cô cung cấp nhiều tài liệu có hướng dẫn giải cụ thể các dạng toán để đáp ứng nhu cầu tự học .',
#  'giảng viên nhiệt tình , vui vẻ , hoà đồng , gần gũi giúp sinh viên khá nhiều trong việc tiếp thu kiến thức .',
#  'mong nhà trường xem xét lại để có sự nhất quán trong công tác dạy và chấm thi .',
#  'truyền đật kiến thức tốt , dễ hiểu .',
#  'tài liệu thực hành nên nêu rõ mục tiêu cũng như kiến thức cần đạt được sau bài thực hành .',
#  'và giảng dạy khó hiểu .',
#  'ít quan sát sinh viên thực hành .',
#  'có một bạn trong phòng của em học thầy ở học kỳ trước hâm mộ thầy !',
#  'bài tập cuối kỳ làm quá nhiều .',
#  'cô dạy có tâm , post tài liệu và bài tập lên moodle rất đầy đủ .',
#  ...]

# %%
def punctuation_removal(sentences):
    processed_sentences = []
    for sent in sentences:
        processed = "".join([i for i in sent if i not in string.punctuation])
        processed = processed.strip()
        processed_sentences.append(processed)
    return processed_sentences

# %%
train_sents = punctuation_removal(train_sents)
train_sents
# Out:
# ['slide giáo trình đầy đủ',
#  'nhiệt tình giảng dạy  gần gũi với sinh viên',
#  'đi học đầy đủ full điểm chuyên cần',
#  'chưa áp dụng công nghệ thông tin và các thiết bị hỗ trợ cho việc giảng dạy',
#  'thầy giảng bài hay  có nhiều bài tập ví dụ ngay trên lớp',
#  'giảng viên đảm bảo thời gian lên lớp  tích cực trả lời câu hỏi của sinh viên  thường xuyên đặt câu hỏi cho sinh viên',
#  'em sẽ nợ môn này  nhưng em sẽ học lại ở các học kỳ kế tiếp',
#  'thời lượng học quá dài  không đảm bảo tiếp thu hiệu quả',
#  'nội dung môn học có phần thiếu trọng tâm  hầu như là chung chung  khái quát khiến sinh viên rất khó nắm được nội dung môn học',
#  'cần nói rõ hơn bằng cách trình bày lên bảng thay vì nhìn vào slide',
#  'thầy rất tận tình và đi dạy rất đúng giờ',
#  'dễ bị áp lực',
#  'đang dạy thầy wzjwz208 đi qua nước ngoài giữa chừng  thầy wzjwz209 dạy thay',
#  'môn học còn dễ cần nâng độ khó lên nữa',
#  'có thể cho sinh viên đi thăm quan nhiều công ty xem quy mô và cách làm việc  để giúp hiểu rõ hơn vê ngành mình đang học',
#  'hài lòng về tất cả',
#  'nhiệt tình  vui vẻ',
#  'thấy nhiệt tình trong việc trao đổi giúp đỡ về học tập',
#  'phong cách giảng bài của thầy rất gần gũi với sinh viên',
#  'giảng dạy kết hợp các hoạt động giải trí có hiệu quả',
#  'cần tạo các buổi seminar để sinh viên có thể hiểu sâu thêm về các vấn đề trong chuyên ngành nhưng không có trong môn học',
#  'tiết học thoải mái',
#  'thầy nhiệt tình  quan tâm tới sinh viên',
#  'giảng dạy nhiệt tình  hướng dẫn chi tiết đến lúc sinh viên hiểu',
#  'chưa có nhiều tiết làm bài tập  chữa bài tập trên lớp',
#  'tài liệu được bổ sung nhiều và đầy đủ trên moodle',
#  'giảng viên phải nên cho ví dụ cụ thể những phần quan trọng nên nói kỹ có thể lấy ví dụ minh họa tránh việc lập đi lập lại nhiều lần sẽ tạo cảm giác chán cho sinh viên',
#  'nên biên soạn một tài liệu của chính trường ta',
#  'không giúp đỡ sinh viên trong những vấn đề xung quanh',
#  'bài tập đa dạng  cụ thể',
#  'nội dung giảng viên yêu câu seminar hầu như không có tài liệu tham khảo và rất ít ứng dụng trong thực tế  đề nghị có sự thay đổi trong những năm học tới',
#  'slide up đầy đủ trước mỗi buổi học',
#  'nội dung giảng dạy quá nhàm chán  khô khan',
#  'lượng kiến thức quá nhiều trong một học kỳ',
#  'thầy chép bảng nhiều',
#  'thầy tận tình hướng dẫn cách làm  giải quyết những thắc mắc của sinh viên',
#  'chúc các thầy cô  anh chị làm việc vui vẻ',
#  'hay  nhiệt tình  dễ hiểu',
#  'mặc dù nhiệt tình nhưng khi truyền đạt thì lại khó hiểu  sử dụng ngôn từ gây khó khăn cho việc hiểu bài',
#  'thầy dạy khá hay  cung cấp nhiều thông tin liên quan đến môn học  đưa ra nhiều hướng giải quyết khi sinh viên gặp vấn đề khó khăn với đồ án',
#  'hy vọng học kỳ sau có thể học được với cô',
#  'nhiều khi em lên lớp học môn đặc tả hình thức giống như lên lớp học mà không biết mình học cái gì',
#  'trong khi giảng nói nhỏ quá',
#  'thực hành khó hiểu',
#  'thầy rất tận tâm nhiệt tình  quan tâm đến sinh viên  giảng bài dễ hiểu  kiến thức sâu rộng am hiểu cao',
#  'cô dạy với nhiệt huyết của mình  dù như thế nào  cô vẫn luôn mỉm cười và kiên trì giảng bài cho chúng em đến khi chúng em hiểu',
#  'cô lên lớp đúng giờ  giảng bài rất dễ hiểu cho sinh viên',
#  'những thông tin cần thiết như doubledot thời gian dealine  cách nộp bài thường không dặn lớp thực hành thứ hai',
#  'thầy nhiệt tình  dễ chịu',
#  'giảng viên chưa đi sâu vào bản chất của vấn đề  em chỉ học thôi mà không biết bản chất của nó là gì nó có ứng dụng gì sau này cho chuyên nghành của em',
#  'đặc biệt hơn là thầy đã bỏ rất nhiều công sức trong việc ra bài tập và chấm điểm một cách rõ ràng và minh bạch',
#  'cô rất nhiệt tình và tận dụng tốt thời gian',
#  'giảng viên tận tâm  nhiệt huyết trong giảng dạy',
#  'thầy nhiệt tình  gần gũi',
#  'giảng viên tận tâm  giảng dễ hiểu  dễ tiếp thu',
#  'tạo ra sự cạnh tranh trong mỗi buổi thực hành',
#  'bài tập và có code tham khảo',
#  'cần nâng cấp hệ thống wifi  vì khi vào phòng thực hành  sinh viên không thể truy cập internet  buộc phải xin phép ra ngoài để làm bài',
#  'tài liệu không chi tiết lắm',
#  'tận tâm  nhiệt tình  vui tính  dễ gần với sinh viên',
#  'thầy dạy rất hay và nhiệt tình',
#  'thầy dạy không đúng giờ  không hướng dẫn sinh viên thực hành',
#  'giúp đỡ học sinh quá ít',
#  'cô dạy buồn ngủ quá',
#  'nên kinh mong nội dung môn học được giảm tải cho phù hợp hơn với đặc thù của một trường công nghệ thông tin',
#  'thầy tận tình vui tính',
#  'cô lại kiểu khó tính nữa',
#  'tạo hứng thú cho sinh viên',
#  'cô giảng hay cuốn hút và truyền đạt dễ hiểu',
#  'có hứng thú học',
#  'ôn tập đúng theo thầy nhưng không biết cuối kỳ được mấy điểm',
#  'giảng viên hướng dẫn cụ thể  chi tiết',
#  'giáo trình quá ít và nội dung không khác nhau là mấy',
#  'giáo viên nghỉ dạy liên tục  cuối học kỳ lại tăng học bù  những tiết học bù đó đã ảnh hưởng đến những đồ án  và trễ deadline',
#  'giáo viên lúc dạy lúc không  không dạy cũng không thông báo  sinh viên tốn thời gian  công sức  tiền bạc rồi ngồi đợi và đi về',
#  'cần có một phòng máy tốt hơn  hiện đại hơn',
#  'thầy nên cho làm bài tập tương tự nhau nhiều hơn một vài bài để tránh tình trạng quên hoặc các dạng tựa nhau nhưng hơi khác cách làm',
#  'không ngờ môn này lại chán đến như vậy  không học được gì từ môn này  thầy dạy chán kinh khủng  hay đi trễ từ 30  45 phút  không nhiệt tình',
#  'giảng viên đánh giá sai điểm và năng lực của học sinh',
#  'không đáp ứng được đề cương môn học đề ra',
#  'thầy nên hướng dẫn thực hành nhiều hơn',
#  'giảng viên thân thiện  quan tâm tới sinh viên',
#  'môn lập trình hướng đối tượng nên cập nhật thêm những nội dung mới  dễ hiểu và giảng giải cụ thể hơn',
#  'giáo viên nhiệt tình  tâm huyết  khả năng truyền đạt tốt',
#  'thầy dạy rất tốt và nhiệt tình',
#  'cô nói hơi nhỏ  nếu lớp ồn sẽ khó nghe',
#  'bài tập cô đưa ra nhiều  và khó tìm hiểu  với kiến thực hiện tại của sinh viên thì khó có thể tìm hiểu và làm tốt bài tập cô ra',
#  'bài tập và hoạt động nhóm còn ít',
#  'giảng viên rất nhiệt tình  phương pháp giảng dạy hay  sinh viên nắm bắt kiến thức ngay trên lớp',
#  'cô hướng dẫn thực hành khá đầy đủ',
#  'được học nhiều kinh nghiệm từ thầy wzjwz163',
#  'kiến thức của thầy rất tốt  bảo đảm giờ lên lớp',
#  'hiện tại em chưa thấy tác dụng gì nhiều khi học môn này',
#  'cải thiện lại cơ sở vật chất máy chiếu trong phòng học',
#  'dạy không phù hợp với cách học của em',
#  'giải thích nội dung mới rõ ràng',
#  'lớp học quá đông',
#  'môn căn bản mà thầy không dạy cho sinh viên kỹ  gây không hiểu  mất căn bản',
#  'giảng viên chưa cho bài tập về nhà để sinh viên làm nên cho 5 bài mỗi chương  không cần chữa chỉ cần đáp án',
#  'mà hiện tại trường ta chưa có  đây là thiệt thòi lớn đối với tụi em',
#  'tôi cảm thấy giảng viên dạy rất tốt',
#  'không biết thầy nào dạy chính thức  mà học thường nghỉ không thông báo trước để sinh viên đứng chờ sắp hết tiết rồi tự về nhiều lần',
#  'cần có sự tương tác giữa giảng viên và sinh viên nhiều hơn',
#  'giảng viên thân thiện nhiệt tình cởi mở',
#  'giáo viên có mời các công ty về trình bày  giúp sinh viên cập nhật kiến thức thực tiễn',
#  'coi lại thái độ giảng viên thực hành',
#  'giảng viên nhiệt tình  giải nhiều bài tập',
#  'bài giảng của thầy rất nhiệt tình',
#  'môn học chưa thực tiễn  chưa thu hút sinh viên',
#  'dạy hơi nhanh',
#  'ít làm bài tập',
#  'giảng bài kém thu hút  vị trí đứng giảng không hợp lý  ôn tập cuối kỳ còn chưa tập trung vào vấn đề',
#  'giảng viên nhiệt tình  bài giảng thu hút',
#  'nhờ thầy và giảng viên lý thuyết  em đã hiểu rõ về môn này rất nhiều',
#  'môn này khá trừu tượng nên mong thầy có nhiều liên tưởng tới thực tiễn hơn để chúng em có thể hiểu',
#  'cần thêm nhiều tài liệu cho sinh viên',
#  'bài tập trên lớp',
#  'tăng số tiết dạy lên để sinh viên có nhiều cơ hội hỏi đáp thắc mắc về môn học',
#  'thầy nhiệt tình dễ hiểu',
#  'thực hành và lý thuyết nên dạy song song',
#  'giảng viên dạy nhanh',
#  'bài tập trên lớp nên được giới thiệu ngay từ đầu tiết học để học sinh không tốn thời gian đọc đề cũng như có thể suy nghĩ cách giải cùng lúc với việc nghe giảng',
#  'giảng viên cho bài tập hay',
#  'cập nhật bài tập mới',
#  'lên lớp ai làm việc người ấy  thầy không có giảng gì thêm',
#  'tận tâm  nhiệt tình  quan tâm đến sinh viên',
#  'phản hồi giải đáp thắc mắc cho sinh viên',
#  'dạy quá nhanh',
#  'mong ban thiết bị sớm khắc phục ạ',
#  'môn này cần làm đề tài để áp dụng lý thuyết vào thực tiễn mà trên lớp chỉ học một đống lý thuyết và hiếm ai nhớ đa số khá buồn ngủ khi lên lớp',
#  'giảng viên nên đổi mới phương pháp giảng dạy  tránh thô cứng  không hấp dẫn sinh viên',
#  'nhiệt tình  tạo cách chủ động cho học sinh tiếp cận với môn học và tham gia các chương trình phong trào liên quan để nâng cao kỹ năng',
#  'cô dạy rất tận tình  dễ hiểu',
#  'không đáp ứng được nhu cầu của sinh viên',
#  'thầy rất nhiệt tình với chúng em và điều này làm em rất hài lòng',
#  'cách giảng dạy của thầy rất hay và có phần dễ hiễu',
#  'nhiệt tình  dễ thương',
#  'không hướng dẫn đồ án',
#  'em xin đề nghị nhà trường nên bổ sung tài liệu về môn học và cập nhật nội dung',
#  'chép bài rất nhiều  lãng phí thời gian nghe giảng',
#  'em không học thầy wzjwz178 kỳ này  giáo viên thực hành có 2 người nên có lẽ daa nhầm',
#  'đề thi môn dài sinh viên làm không đủ thời gian',
#  'cho làm nhiều bài test',
#  'theo em thì nên thi phòng máy nào có visual 2013 trở lên',
#  'cần thêm nhiều tài liệu cho môn học',
#  'thầy giảng dạy tốt',
#  'mong thầy có thể hướng dẫn cách cụ thể nhất cho những bài khó',
#  'thầy cần cho bài tập và hướng dẫn nhiều hơn',
#  'giáo viên lên lớp đúng giờ  giảng bài sôi động',
#  'em thấy thầy chỉ giảng cho có',
#  'cần xác định rõ mục đích môn học và cho sinh viên đề cương chi tiết môn học trước khi bắt đầu',
#  'thầy nói chuyện với sinh viên rất tự nhiên  chia sẻ kinh nghiệm thực tế',
#  'dạy theo sát chương trình',
#  'cung cấp thêm trang thiết bị phục vụ nhu cầu môn học',
#  'đề nghị nâng cấp phòng lab khoa mạng',
#  'thầy giảng hay và tâm huyết  bài giảng có tính thực tiễn cao',
#  'đi dạy đúng giờ',
#  'thầy cung cấp nhiều kiến thức mới  thầy dạy tận tâm và nhiệt tình',
#  'có tăng thêm nhiều ví dụ để minh họa cho lý thuyết vì có nhiều phần lý thuyết rất trừu tượng',
#  'các yêu cầu về đồ án môn học nên đươc đưa ra chính xác trước khi sinh viên bắt đầu thực hiện chia nhóm và làm đồ án',
#  'dạy dễ hiểu dễ tiếp thu  tập trung vài kiến thức trọng tâm',
#  'dạy chưa được kỹ lắm  điểm nên thoáng hơn',
#  'chưa chuẩn bị kỹ bài giảng để có thể trả lời các thắc mắc của sinh viên trên lớp',
#  'cô khá tận tâm cho học sinh',
#  'cần cải cách lại nội dung các bài thực hành  một số kiến nội dung trong bài thực hành đã trở nên lỗi thời',
#  'giảng viên có khả năng truyền đạt kiến thức tốt',
#  'cho làm nhiều bài tập',
#  'nghiên cứu khoa học',
#  'giáo viên dạy rất tận tâm  nhiệt tình',
#  'thầy cô hướng dẫn đồ án hệ thống thông tin cần có thêm một vài buổi gặp mặt với sinh viên và đưa ra lịch cố định trên trường để sinh viên thắc mắc có thể lên hỏi trực tiếp',
#  'chỉ thông báo trên lớp sẽ khó tránh sai sót',
#  'cô viết ở góc bảng gần chổ bụt giảng khiến nhiều khi khó quan sát được ạ',
#  'đề nghị lắp thêm quạt',
#  'dạy kỹ',
#  'bài tập cần đa dạng hơn',
#  'nói rất nhỏ',
#  'có lúc làm bài sai giáo viên nói làm hơi tự ái',
#  'không sửa các bài tập thực hành',
#  'em chưa hiểu rõ cách thức chấm điểm bài kiểm tra thực hành',
#  'làm bài tập nhiều mặc dù không hiểu lắm',
#  'thi thoảng nghỉ học không thông báo trên daa',
#  'thầy dạy dễ hiểu  tiết học dễ hiểu  sôi nổi',
#  'thầy giảng dạy nhiệt tình  truyền cảm',
#  'giảng dạy rất chi tiết  dễ hiểu và dễ tiếp thu',
#  'truyền đạt những kiến thức tốt',
#  'cô vui tính',
#  'nếu có thì chỉ hướng dẫn bằng lý thuyết mà không làm bài tập mẫu cho sinh viên',
#  'cô chưa có nhiều kênh bài tập cho sinh viên',
#  'bạn nào khá thì có thể áp dụng công thức vào bài tập cả lớp chưa đến 30 còn thực sự hiểu môn học thì rất ít người hiểu',
#  'thầy dạy hơi nhanh',
#  'ít hướng dẫn sinh viên trong giờ thực hành',
#  'không thực hành được buổi nào',
#  'thầy dạy phần lý thuyết hay  nắm bắt được khả năng của sinh viên',
#  'ví dụ đề tài của em là doubledot các nguyên lý cơ bản  bao gồm 7 nguyên tắc của bohm  1983',
#  'giáo viên nhiệt tình  dạy dễ hiểu  tận tình với sinh viên',
#  'tân tâm  nhiệt tình trong lớp lẫn bên ngoài',
#  'thầy giảng dạy tận tâm nhiệt tình',
#  'thầy vui tính  giảng bài dễ hiểu  nhiệt tình',
#  'thầy giáo dạy nhiệt tình',
#  'dạy dễ hiểu  gần gũi sinh viên',
#  'cô dạy rất nhiệt tình và tài liệu của cô rất cụ thể dễ hiểu  cô hướng dẫn rất tận tình',
#  'mong thầy cố gắng trong các học kỳ sau',
#  'cần đưa ra nhiều ví dụ minh họa hơn',
#  'giảng viên hoà đồng  vui vẻ  chỉ giảng tận tình sinh viên ham học hỏi',
#  'giảng viên không dạy một tiết thực hành nào',
#  'không',
#  'nên có sự thống nhất giữa các giảng viên bộ môn trong đề cương giảng dạy',
#  'có những phần kiến thức chỉ một nửa lớp được học nhưng giảng viên nghĩ là cả lớp đã học rồi nên chỉ overview  những sinh viên còn lại khó nắm được',
#  'máy tính cập nhật nhanh hơn',
#  'vui  hòa đồng  nhiệt tình',
#  'có giúp đỡ sinh viên học tập nghiên cứu',
#  'giảng viên tận tâm  nhiệt tình  ham học hỏi',
#  'tuy nhiên cô nên cân nhắc lại về số lượng yêu cầu đối với sinh viên để sinh viên không bị khớp vì quá nhiều dẫn đến làm qua loa cho có  như vậy thì kết quả lại không tốt',
#  'cô rất tận tâm  rất ok  em rất thích cách dạy và học của cô  mặc dù hơi nhanh tí',
#  'mong thầy và nhà trường xem xét lại những điều em vừa nói',
#  'thầy tận tâm  nhiệt tình  tạo động lực cho sinh viên',
#  'thầy giáo tận tình  dạy kỹ  thường đưa ra câu hỏi để xem xét mức độ hiểu biết của sinh viên',
#  'cần tăng cương trao đổi giữa sinh viên và giáo viên',
#  'nói chung là nghe không bao giờ nghe rõ được',
#  'cách truyền đạt của giáo viên chưa có sức hút đối với sinh viên nhiều cho lắm',
#  'cô giáo thân thiện dễ gần  thực hành nhiều',
#  'chưa tiếp thu trọn vẹn',
#  'cần cải tiến trang thiết thực hành',
#  'giảng kỹ hơn',
#  'còn hơi kéo thời gian',
#  'có nhiều bài tập về nhà cơ bản lẫn nâng cao và giảng viên sửa bài đủ',
#  'thầy rất hiền và kiên trì giảng dạy cho lớp mặc dù môn học này đối với em không được hứng thú lắm',
#  'đôi lúc giảng bài hơi nhanh',
#  'có một số buổi không đi dạy',
#  'thầy nhiệt tình và dạy dễ hiểu',
#  'có kiến thức nền tảng này  sinh viên có thể học thêm bất kỳ công nghệ cụ thể nào đó dễ dàng  cũng như tiếp thu thay đổi công nghệ mới nhanh chóng',
#  'cấu trúc đề cương của thầy chưa rõ ràng  lý thuyết chưa được trình bày rõ trong các buổi học',
#  'tài liệu hỗ trợ toàn tiếng anh rất khó học',
#  'chưa nhận được gì từ môn học này',
#  'giảng viên không hề giảng dạy  chỉ đưa đề cương rồi thôi',
#  'bài tập mỗi tuần đều có và đầy đủ',
#  'em xin cảm ơn',
#  'thầy cần phải cho sinh viên biết được học môn này có tác dụng gì và làm được gì khi học xong',
#  'đề nghị tăng thời gian thưc hành',
#  'không được làm những chuyện riêng trong lúc dạy thực hành',
#  'hỗ trợ thêm giáo trình không phải slide cho sinh viên',
#  'cô wzjwz259 rất vui và nhiệt tình',
#  'giáo viện nhiệt tình  tận tâm',
#  'kiến thức được giảng viên trình bày rõ ràng  dễ hiểu cho sinh viên',
#  'cần thêm nhiều kit để thực hành',
#  'dạy khó hiểu quá nhanh',
#  'luôn gần gũi  tham khảo ý kiến sinh viên và thống nhất cũng sinh viên',
#  'sắp xếp lịch học bù chưa hợp lý',
#  'nhà trường nên đưa môn học này vào thời khóa biểu bắt buộc ở học kỳ 1 của các sinh viên năm nhất nhằm giúp các em nắm biết được mình nên học gì  mình có nên chuyển đổi ngành hay không',
#  'thời gian thực hành cần nhiều hơn',
#  'giảng viên rất nhiệt tình trong giảng dạy',
#  'slide chuẩn bị chưa tốt',
#  'thầy hay đòi hỏi sinh viên những điều hơi quá cao',
#  'cô giảng hướng dẫn nhiệt tình',
#  'chúng em đã gặp khó khắn với khổ giấy nhỏ  mô hình thì lớn và phức tạp',
#  'giảng quá nhiều không đánh vào trọng tâm',
#  'em không muốn nói gì nhưng mong thầy xem lại cách đánh giá sinh viên để công bằng hơn  cái sinh viên không biết không phải chỉ ở cúp tiết mà còn ở cách giảng dạy  truyền đạt ở giảng viên  ví dụ như cô wzjwz324  rất dễ hiểu  tận tâm',
#  'cô có nhiều hình thức giảng dạy hay',
#  'hơi khó',
#  'thầy đi trễ',
#  'giảng tốt',
#  'nói mở rộng nhiều vấn đề về môn học',
#  'cần tăng cường nội dung nghe và nói để sinh viên giao tiếp tốt hơn bằng tiếng anh',
#  'giảng viên tạo điều kiện làm nhiều bài tập',
#  'hỗ trợ thêm về các thiết bị dạy và học',
#  'ít giải bài tập trên lớp',
#  'chia sẻ',
#  'bám sát nội dung chính',
#  'cần thêm các đoạn code cho các giải thuật bổ sung các phương pháp để giải quyết các bài toán liệt kê',
#  'thông tin đầy đủ về bài tập và các nguồn tham khảo',
#  'cô tận tâm  nhiệt tình  phương pháp dạy dễ hiểu',
#  'thầy giảng rất dễ hiểu và thú vị  thu hút',
#  'hướng dẫn chi tiết về cách thực hành',
#  'giảng viên chỉ cho đồ án và giải đáp các yêu cầu đồ án  không cung cấp tài liệu hay hướng dẫn cơ bản  sinh viên tự tìm hiểu với lý do là hệ tài năng nên cần tự xoay sở',
#  'môn học toàn kiến thức mới mẻ  giảng viên nên giảng chi tiết hơn',
#  'đến khi cuối kỳ  chỉ cần sinh viên mắc một sai sót nhỏ thì sẽ rớt môn',
#  'cần thay đổi cách dạy và nội dung học của phần thực hành  các bài thực hành hiện tại của môn mạng máy tính chưa đảm bảo hiệu quả',
#  'thầy dạy hay  tận tình góp ý từng bài',
#  'cơ sở vật chất  phỏng máy không đủ phích cắm cho dụng cụ thực hành và số lượng sinh viên  máy còn tiềm ẩn nhiều virus',
#  'trên lớp lý thuyết giảng viên yêu cầu sinh viên phải thực hiện đồ án theo những gì mình hướng dẫn  những nhóm sinh viên bổ sung thêm những liên hệ thực tiễn đều bị cho là sai  không phù hợp với đồ án',
#  'thầy giảng bài hay và hiệu quả',
#  'giảng viên nhiệt tình vui vẻ',
#  'phòng học nên có rèm che sáng để khi chiếu slide được nhìn rõ hơn',
#  'chương trình dạy lý thuyết và thực hành nên khớp với nhau hơn  tránh tình trạng thực hành trước khi học lý thuyết',
#  'thầy giảng dạy nhiệt tình  dễ hiểu',
#  'mong giảng viên ngày càng chấn chỉnh việc dạy học để các khoá sau được hiểu tốt hơn',
#  'thầy dạy rất có tâm  và giảng cho sinh viên rất nhiều thứ',
#  'nội dung khảo sat quá dài  nhiều mục lặp đi lặp lại  nhiều bạn khảo sát mà không cần đọc  toàn tích chàn',
#  'dạy tốt và rất nhiệt tình chỉ dạy hoc sinh',
#  'nhiệt tình  tân tâm',
#  'nhưng học mới thấy kiến thức thầy dạy rất hay  bám sát thực tế  thầy dạy rất nhiệt tình  vui vẻ  khác với mọi người nói',
#  'bài tập rất hay',
#  'thầy cô cần cho nhiều dạng bài tập sát với đề thi hơn',
#  'thầy giảng hay nhưng nên tự tin hơn  nói to hơn để học sinh hiểu bài một cách rõ ràng hơn',
#  'mong thầy vui tính  gần gũi với sinh viên hơn',
#  'giáo viên vui tính  hòa đồng  nhiệt tình',
#  'cung cấp kiến thức trọng tâm',
#  'cố gắng truyền đạt một cách tốt nhất để sinh viên được hiểu',
#  'giọng của giảng viên nhỏ dù đã sử dụng micro',
#  'dù phương pháp học tập này khá hiệu quả nhưng vẫn có chút nào đó nghi ngờ từ phần thuyết trình của các bạn  liệu các kiến thức đó có chuẩn xác và cập nhật chưa',
#  'giáo viên có phong cách giảng dạy nghiêm túc',
#  'cô rất vui tính nà  không khí lớp lúc nào cũng vui hết  cô dạy rất hay  dễ hiểu',
#  'giảng viên giảng dạy rất tốt  thường xuyên cung cấp thêm nhiều kiến thức',
#  'thầy luôn nhiệt tình  có những chia sẻ rất gần gũi với sinh viên',
#  'có khả năng truyền đạt tốt',
#  'thậm chí còn không có bài nào khó bằng các bài trong nội dung của lớp chuyên tin ở các trường cấp 3',
#  'thầy dạy tận tụy và tâm huyết',
#  'thầy nên có cách dạy mới cho môn học này để được kết quả tốt cho tất cả mọi người thay vì để rớt rất nhiều người',
#  'lịch thi thực hành cần được thông báo sớm tới sinh viên và phù hợp với thời gian môn học',
#  'cô nên giảng kỹ và chi tiết từng bài vì nhiều bài đa số các bạn chưa hiểu thì cô lại giảng nhanh để chuyển qua bài khác',
#  'dạy tốt đúng trọng tâm những gì cần biết',
#  'nhiệt tình  lên lớp đúng giờ  dạy dễ hiểu',
#  'nếu em buồn ngủ  dù lên lớp em vẫn sẽ ngủ  mà ngủ ở trên lớp thì đau lưng và tê chân lắm',
#  'cơ mà em học môn này em hiểu colonlove',
#  'thiếu kinh nghiệm truyền đạt',
#  'bài giảng thú vị',
#  'em nghĩ nội dung thực hành nên gần với đồ án hơn',
#  'thầy nhiệt huyết và giảng bao quát đề cập đến nhiều khía cạnh của bài học vấn đề',
#  'giảng viên giảng bài kỹ',
#  'hệ thống đồ án chấm điểm theo mức độ hoàn thành của sinh viên  tạo sự ganh đua không hề nhẹ với những nhóm làm chung đồ án  kích thích sáng tạo không ngừng tìm hiểu xây dựng thêm chức năng mới cho đồ án nếu muốn được điểm cao',
#  'nhiệt tình  tâm huyết',
#  'ít chú trọng phần ngữ pháp',
#  'giảng viên còn chưa tận tâm  phong cách giảng dạy chưa thu hút được sinh viên',
#  'giảng rất dễ hiểu  hướng dẫn làm thực hành tốt',
#  'thầy dạy rất nhiệt tình  khi dạy thầy luôn đi tới từng sinh viên để hướng dẫn',
#  'giảng viên nhiệt tình trong giảng dạy và chấm điểm',
#  'cách truyền đạt kiến thức đối với em là rất hiệu quả  trao đổi bài với sinh viên  cô rất nhiệt tình',
#  'giảng dạy hay  dễ hiểu  tận tình',
#  'kiến thức rộng  kinh nghiệm thực tế nhiều  truyền cảm hứng cho sinh viên',
#  'cách dạy sáng tạo',
#  'giảng bài dễ tiếp thu',
#  'em rất hài lòng với cô',
#  'thầy dạy dễ hiểu  sinh động',
#  'cô chưa nắm bắt được thực trạng học của sinh viên',
#  'ảnh hưởng đến tiến độ học tập và quỹ thời gian của sinh viên  do học bù',
#  'cô giảng bài dễ hiểu',
#  'điều em hài lòng nhất đó là thầy đi rất đúng giờ và không dạy quá nhanh',
#  'nên có giáo trình thống nhất cho tất cả các lớp và học kỳ học',
#  'em nghĩ cần có các bài tập lớn để nâng cao khả năng lập trình của các sinh viên',
#  'rất nhiệt tình với sinh viên',
#  'giảng viên có phương pháp giảng dạy hay  cập nhật  phù hợp với sinh viên',
#  'giảng dạy tốt và có tâm',
#  'dạy lý thuyết hơi nhiều',
#  'giảng viên chấm bài quy chụp theo kết quả',
#  'thời lượng môn học quá dài  sinh viên cảm thấy mệt mỏi',
#  'giảng viên vui tính dễ tương tác với sinh viên',
#  'nhiệt tình hay giúp đỡ sinh viên khi không biết  cho nhiều bài tập',
#  'thầy cho điểm phần nào còn theo cảm tính  chưa được công bằng',
#  'thầy giảng dạy rất nhiệt tình',
#  'thầy nhiệt tình  bài giảng phong phú đa dạng',
#  'không có gì đặc biệt',
#  'mỗi tháng chỉ gặp giảng viên một lần rất khó cho việc học hỏi  hướng dẫn từ giáo viên',
#  'thầy nên chuẩn bị riêng một slide cho mình để giảng dạy  không nên lấy slide của người khác rồi đến khi sơ sót  thầy lại lấy cái lý do  đây không là slide của tôi    cái này tôi cũng không rõ nữa',
#  'thầy cho làm các bài tập tại lớp trong khi sinh viên chưa biết gì về vấn đề đó',
#  'đôi khi đi quá sâu vào một vấn đề bên lề',
#  'giảng viên dạy tận tâm  nhiệt tình  dễ hiểu',
#  'cô thật nhiệt tình',
#  'phòng thực hành tốt',
#  'nói chuyện lan man  không liên quan đến môn học quá nhiều',
#  'giảng viên rất tận tâm',
#  'phân bổ hợp lý thời gian học và nên cho xem nhiều video hơn là nghe',
#  'thầy bận nhiều nên cũng nghỉ nhiều  hi vọng thầy có thể sắp xếp thời gian',
#  'giáo viên sử dụng giờ trên lớp hiệu quả',
#  'giáo viên tận tình  dạy truyền đạt tốt',
#  'giảng viên dạy tốt  nhiệt tình',
#  'giảng viên tạo cảm hứng cho sinh viên học tập',
#  'chán',
#  'thầy nhiệt tình  tận tâm giúp đỡ sinh viên',
#  'dạy quá chậm  quá cặn kẽ',
#  'thầy wzjwz174 ít cho bài tập về nhà',
#  'thầy đôi khi nói hơi khó hiểu',
#  'giảng viên tận tâm  nhiệt tình  hỗ trợ giải đáp thắc mắc môn học cho sinh viên',
#  'nên đi sâu vào vấn đề  giúp sinh viên hiểu tốt môn học  và nên có những ứng dụng cụ thể mà môn học đem lại',
#  'làm bài tập',
#  'cứ ngỡ được 10 điểm là chắc chắn rồi',
#  'thầy yêu cầu quá cao đối với một sinh viên có thể tiếp thu mọi kỹ năng cần truyền đạt vào một đồ án',
#  'thêm phòng thiết bị để thực hành',
#  'dễ hiểu đầy đủ',
#  'điểm',
#  'giáo viên tốt bụng  vui tính',
#  'slide quá khó hiểu  nhiều chỗ không giải thích rõ ràng  đặc biệt là các bài hướng dẫn thực hành',
#  'nói rõ mục tiêu cũng như các bước làm của lab  khối lượng bài tập vừa phải',
#  'giải đáp kịp thời những thắc mắc cho sinh viên',
#  'giảng viên nhiệt tình  phương pháp dạy dễ tiếp cận  dễ hiểu',
#  'phòng học cần lắp thêm quạt và ổ cắm vì sinh viên phải sử dụng laptop để làm bài tập  cần có thêm màn che cửa sổ để có thể theo dõi bài giảng trên slide tốt hơn',
#  'bài tập không cho ví dụ về nhà để xem lại',
#  'giảng viên thiếu rất nhiều hoạt động để việc học bớt nhàm chán khi quá bám sát bài học',
#  'thầy dạy dễ hiểu  rất hài lòng',
#  'micro và các thiết bị âm thanh  máy chiếu cần nâng cấp',
#  'cách giảng bài dễ hiểu  hay',
#  'đầy đủ kiến thức',
#  'chất lượng phòng máy rất tệ',
#  'thầy giảng ngắn gọn  đầy đủ',
#  'tốt giỏi chu đáo',
#  'tuy có phần chém gió kinh điển nhưng kiến thức  hiểu biết rộng  đặc biệt về công nghệ',
#  'chờ học sinh gửi email mới show được slide to lên  giảng cho qua loa không hỏi học sinh có hiểu gì hay không',
#  'tạo niềm vui cho bọn em tuy lý thuyết bọn em rất đuối sức',
#  'nhiệt tình  truyền cảm hứng',
#  'thầy hài hước  giọng truyền cảm',
#  'thầy dạy rất nhiệt tình  tâm huyết  dễ hiểu',
#  'không hiểu cách chấm bài thi của thầy',
#  'tiết học chưa được thu hút',
#  'giảng viên nên thay đổi phương pháp giảng dạy để tương tác nhiều hơn với sinh viên',
#  'cần vào thẳng nội dung',
#  'thầy đẹp trai  dạy dễ hiểu  hay trò chuyện thực tiễn với học sinh',
#  'cô dạy trên lớp và thực hành tận tâm',
#  'em rất hài lòng về thầy',
#  'thầy quá bảo thủ  thầy luôn cho rằng ý kiến của thầy là đúng nhất  ngoài ra mọi ý kiến khác đều sai',
#  'thầy wzjwz252 giảng bài rất thu hút  kiến thức thầy rất rộng  luôn giải đáp thắc mắc cho sinh viên',
#  'giảng viên rất hòa đồng vui vẻ  nhiệt tình trong giảng dạy',
#  'giảng viên tận tâm  tạo điều kiện cho học sinh làm bài tập',
#  'cần giải bài tập nhiều hơn',
#  'kiến thức thực tiễn của thầy rộng  giảng dạy vui vẻ',
#  'cô cũng không cung cấp hay giải thích gì đáp án của bài thi',
#  'thầy rất nhiệt tình  nói rất nhiều đến khản giọng mà sức truyền tải không bằng thầy wzjwz159',
#  'kiến thức giảng dạy môn tiếng anh hầu như không giúp ích nhiều cho sinh viên trong việc tìm hiểu các tài liệu chuyên ngành',
#  'thấy rất hiền  rất chi là hơi trẻ con',
#  'giảng dạy hay  dễ hiểu  cuốn hút sinh viên',
#  'cách tìm kiếm chúng ở đâu  khai thác chúng ở đâu chứ không phải là phải nhớ mấy cái phương thức hay các hàm rồi viết lên giấy vào đề thi cuối kỳ',
#  'giảng hơi nhanh  chưa kỹ lắm',
#  'những phần trọng tâm bài tập thì cũng không nói được  đây là phần quan trọng có trong đề thi các em cần chú ý',
#  'nghe  nói luyện tập cao',
#  'giáo viên giảng hay dễ hiểu',
#  'sử dụng phần mềm crack',
#  'nhiều khi dạy quá thời gian',
#  'tuy dạy chậm giúp học sinh dễ hiêu tuy nhiên nhiều bài khó thì sẽ khiến sinh viên dễ chán',
#  'thầy vui tính  thương sinh viên  dạy dễ hiểu',
#  'thầy bằng nhiệt tình tận tụy với sinh viên trong việc hướng dẫn đồ án',
#  'dạy dễ hiểu  thân thiện',
#  'có các phần ôn tập không liên tới bài kiểm tra',
#  'không nên tổ chức thực hành hình thức 2',
#  'sự thân thiện và tận tình đối với học viên',
#  'thầy giảng bài nhiệt tình  gần gũi với sinh viên  nội dung không hiểu có thể hỏi ngay thầy tại lớp',
#  'giảng viên cần nắm vững xem sinh viên có hiểu được bài hay không và đưa ra phương án để sinh viên nắm vững kiến thức',
#  'thầy thiện nhiệt tình',
#  'truyền đạt thực tiễn vấn đề',
#  'giáo viên rất nhiệt tình và tâm huyết đối với sinh viên',
#  'âm thanh thầy giảng hơi nhỏ  khó khăn trong việc nghe giảng',
#  'nên thay đổi hình thức khảo sát với môn học này thì môn học này không có lên lớp và chỉ có đến hạn thì báo cáo với giảng viên',
#  'sinh viên hỏi  nhận câu trả lời cũng như không hỏi',
#  'thầy dạy khá nhiệt tình  vui tính',
#  'em nghĩ chỉ nên bắt buộc các bài tập có dạng căn bản  còn bài tập tương tự thì chỉ khuyến khích sinh viên làm thêm',
#  'thầy dạy rất hay ạ',
#  'không thống nhất trước về hình thức thi và làm bài tập  đến những tuần cuối cùng mới công bố',
#  'nhằm giảm thời lượng giảng dạy cũng như sự thú vị khi học môn toán',
#  'giảng viên dạy nhiệt tình  dễ hiểu',
#  'em mong cô cũng như toàn thể các giảng viên hãy xem xét lại việc điểm danh vì đại học dù sao cũng là tự học chứ không phải như là phổ thông nữa',
#  'cô cực kỳ nhiệt huyết  cô rất dễ thương colonlove cô yêu học trò của mình  cô cực kỳ khách quan  phong cách làm việc của cô rất giống người nước ngoài  em thích cô',
#  'giảng viên nhiệt tình  tận tâm với công việc  slide dễ hiểu  hoạt động học tập sôi nổi',
#  'chú ý giữ sức khỏe  nhất là cổ họng colonsmile',
#  'thầy tận tâm  nhiệt tình',
#  'máy ở phòng thực hành quá tệ',
#  'thầy rất dễ thương',
#  'giảng viên nhiệt tình  thân thiện',
#  'thầy truyền đạt rất tận tình  dễ hiểu lượng bài tập  nội dung thi hợp lý  vừa sức với sinh viên',
#  'giảng viên nên đến đúng giờ hơn và cho nhiều bài tập hơn',
#  'em thấy những nội dung như vậy rất mơ hồ  có tính áp đặt suy nghĩ cho người học',
#  'cần nâng cấp máy tính trong phòng thực hành  nhiều kit de2 bị lỗi cần sửa chữa hoặc thay mới',
#  'em thấy môn này nhiều lý thuyết không đáp ứng đủ trong việc làm đồ án',
#  'tạo điều kiện cho sinh viên làm việc nhóm',
#  'phương pháp dạy chưa hay',
#  'hay bị về trễ colonsad',
#  'cần dạy chi tiết hơn',
#  'cô giảng rất nhiệt tình',
#  'dạy rất chi tiết và đầy đủ những kiến thức quan trọng',
#  'đề thi thực hành cần nêu yêu cầu cụ thể  rõ ràng hơn',
#  'giọng của giảng viên rất khó nghe nên không thể nghe giảng hết những điều thầy nói',
#  'giảng dạy hay  nhiệt tình',
#  'giảng viên biết cách truyền đạt  giảng rất hay và dễ hiểu',
#  'dạy hơi nhiều  và hơi nhanh',
#  'nên tạo không khí thoải mái cho tiết học để sinh viên dễ hiểu bài và thêm yêu thích môn học của giảng viên',
#  'giảng dạy tận tâm',
#  'cả năm toàn học vòng lặp  if   for   while  đến bữa cuối mới lơ mơ học được struct với tạo file header mà ra đề 5 điểm trong phần đó',
#  'gần gũi  thân thiện với sinh viên  khả năng truyền đạt kiến thức tốt',
#  'quá dễ dẫn đến buồn ngủ',
#  'giảng viên không có tính hài hước',
#  'vui tính  nhiệt tình',
#  'thầy vui tính  giảng bài hay  đưa nhiều thông tin thực tế vào bài giảng',
#  'thẩy wzjwz311 rất vui và nhiệt tình',
#  'giáo viên giảng dạy lôi cuốn',
#  'nhiệt tình  dễ gần  truyền đạt tận tâm',
#  'phương pháp truyền đạt của giảng viên chưa hiệu quả lắm',
#  'giáo viên chưa tạo được không khí vui vẻ trong lớp học',
#  'thầy giúp em biết mạch số là gì',
#  'có lúc thầy lạc đề',
#  'thầy dạy hơi chậm',
#  'lần được học thầy  thấm nhiều thứ quá',
#  'nhiều phần trong slide bài giảng của giảng viên không chính xác',
#  'môn học cần phân chia hợp lý giữa các phần  phần nào khó cần nhiều thời gian để học nó  phần nào đã học thì chỉ ra những điểm đặc biệt cũng như thời gian học phần đó rút ngắn lại để các phần chưa học khác sẽ có thời gian nhiều hơn',
#  'thực hành đúng tiêu chí môn học  đi từ dễ đến khó cho sinh viên học tập từng bước dễ hiểu  giảng viên tích cực giải đáp thắc mắc và hỗ trợ sinh viên trong giờ thực hành',
#  'dạy dễ hiểu  sâu rộng',
#  'thầy dạy nhiệt tình  vui vẻ',
#  'thầy cực kỳ tâm lý  vui tính  dạy nhiệt tình và tận tụy với học trò',
#  'thầy luôn chủ động tạo tranh luận và kiểm tra bài tập đầu giờ để sinh viên dễ dàng nắm bắt kiến thức',
#  'nội dung tiết học còn lan man  cảm tưởng như thầy đang dạy về tiếng anh chuyên ngành  chứ không đào sâu về kỹ thuật',
#  'nên tự tin hơn trong việc giảng dạy',
#  'giảng viên có cập nhật thông tin mới nhất về tình hình thực tế',
#  'giáo viên rất nhiệt tình đối với sinh viên',
#  'cảm thấy hứng thú khi lên lớp',
#  'cùng một kiến thức nhưng cách truyền đạt của thầy dễ hiểu hơn  phù hợp với đại đa số sinh viên và tất nhiên là hữu dụng cho các môn khác chứ không hề lan man  thiếu trọng tâm như các giảng viên toán khác',
#  'giảng viên chưa bám sát được sinh viên',
#  'nhiều lúc thầy vẫn nói lý thuyết nhiều gây nhàm chán',
#  'phần kiểm tra  thi cử đối với môn này nên đề cao tính tư duy logic của người học cũng như khả năng áp dụng kiến thức đã học vào thực tế thực nghiệm bằng cách chủ yếu đánh giá cao phần thực hành  viết code  làm project',
#  'do môn còn mới nên nhiều vấn đề trục trặc trong quá trình thực hành thầy vẫn chưa giải quyết được  nhưng vẫn rất ủng hộ thầy',
#  'luôn đảm bảo giờ giấc trong tiết học',
#  'phòng lab chán lắm  hư hỏng hết cả',
#  'nội dung môn học còn khô  cứng',
#  'cô nói hơi nhỏ nên hơi buồn ngủ',
#  'có lúc dạy khó hiểu',
#  'thầy cho bài tập lạ  đa dạng',
#  'sau khi đã học xong môn nhập môn điện tử  em thiết nghĩ môn học này cần có thêm những phần học về thực tế  để sinh viên chúng em có thêm động lực khi học những phần lý thuyết đôi khi  khô khan  và  xa lạ  đồng thời sẽ tạo được sự đam mê với bộ môn điện tử nói chung ngay từ những ngày đầu học  nhập môn',
#  'giáo viên vui tính  tích cực',
#  'thầy dạy nghiêm túc',
#  'cơ sở dữ liệu năm nay đã kết hợp với thiết kế cơ sở dữ liệu rồi  kiến thức nhiều mà thi có phần trắc nghiệm nữa thì đánh giá kiến thức học được chưa đảm bảo cho lắm ạ',
#  'nội dung có liên hệ nhiều với thực tế',
#  'nhiệt tình  luôn luôn giúp học sinh hiểu vấn đề cặn kẽ',
#  'ra đề thì phải có đáp án  để sinh viên tập dần thói quen đọc code',
#  'em nghĩ là cần thêm bài tập trên lớp và giải ngay trên lớp',
#  'môn học chỉ nên thuyết trình tìm hiểu về egov không làm đồ án',
#  'giảng viên có nhiều phương pháp giảng hay',
#  'thực hành hình thức 2 khó có thể tham gia học thường xuyên lắm ạ',
#  'cô giảng rất hay  rất nhiệt tình khi giảng dạy  rất vui tính',
#  'giáo viên luôn chia sẻ những ứng dụng của kiến thức đã học với thực tiễn  chia sẻ khá nhiều kinh nghiệm thực tế vô cùng bổ ích với sinh viên',
#  'thầy dạy nhiệt tình  rất chu đáo',
#  'thầy dạy rất nhiệt tình với sinh viên',
#  'em thấy rất hài lòng về môn học này  nên em không có ý kiến gì khác cả',
#  'bàn ghế còn bụi',
#  'cô vui tính  dạy tốt',
#  'nhiệt tình  giỏi hay giúp đỡ sinh viên và cho nhiều bài tập',
#  'kể chuyện hay',
#  'tôi đã thấy giảng viên chỉ nhìn qua chưa đầy 30 giây và cho điểm 9 ngay lập tức',
#  'phòng thực hành nên nâng cấp máy tính',
#  'thầy ít khi nhắc lại về phần đã dạy hôm trước',
#  'thầy nên tham gia thực hành cùng sinh viên  không phải là chỉ ngồi một chỗ  tụi em tự mày mò làm xong rồi thầy mới xuống chấm điểm',
#  'mong muốn giảng viên nào cũng áp dụng như vậy thì quá tốt',
#  'giảng viên cần chuẩn bị giáo án trước khi đến lớp  giảng viên diễn đạt không tốt cần phải học cách diễn đạt cho sinh viên dễ hiểu',
#  'cần học môn lập trình trực quan trước',
#  'cách truyền đạt kiến thức kém hiệu quả  cô dạy giống như là không dạy  chỉ đọc chữ trong slide rồi cho sinh viên làm bài tập',
#  'làm tốn thời gian truyền đạt  dẫn đến hứng thú lên lớp nghe giảng bị hạn chế',
#  'thầy luôn tạo cơ hội để sinh viên có thể được thực hành',
#  'thêm phần anh văn chuyên ngành vào nội dung học',
#  'cảm ơn cô và chúc cô nghỉ đẻ vui vẻ  mẹ tròn con vuông',
#  'thầy dạy tốt  giảng dễ hiểu',
#  'mở rộng kiến thức nâng cao cho sinh viên',
#  'chưa có thời gian cho sinh viên ngẫm nghĩ điều mình mới học mà đã qua nội dung khác để theo kịp chương trình',
#  'dạy dễ hiểu',
#  'thầy vui vẻ  thoải mái',
#  'thầy tận tâm  dạy dễ hiểu  vui tính  lớp học thoải mái dễ tiếp thu',
#  'em thích học môn này với cô wzjwz157',
#  'cô tận tình hướng dẫn chỉ bảo',
#  'cập nhật điểm thi giữa kỳ chậm  nên sinh viên không biết mức độ phấn đấu như thế nào',
#  'giảng dạy tận tâm  nhiệt tình  dễ hiểu',
#  'đôi khi trong giờ học kể vài chuyện về đời để đỡ chán',
#  'thầy không vui tính',
#  'giảng nhiều phần nâng cao làm sinh viên bối rối',
#  'thầy dạy vui vẻ',
#  'cô dạy dễ hiểu  hỗ trợ tốt cho các bạn',
#  'thời gian nộp bài tại lớp hơi ngắn',
#  'cần có sách học hay  chi tiết  hiệu quả colonsmilesmile',
#  'phương pháp giảng dạy còn khó hiểu',
#  'tận tình chu đáo',
#  'nội dung lý thuyết và thực hành của môn học không có bất kỳ liên hệ gì với nhau nội dung lý thuyết không phù hợp với môn học và không tạo được sự quan tâm và mong muốn của sinh viên về kiến thức quản trị mạng như mong đợi',
#  'cần có khả năng truyền đạt tốt hơn',
#  'giảng viên dạy có hiệu quả cao  mang tính thực tiễn',
#  'giáo viên truyền đạt kiến thức đầy đủ  dễ hiểu  nhiệt tình giảng dạy',
#  'em xin lỗi nhưng đó là sự thật',
#  'cô tận tâm  hỗ trợ nhiệt tình',
#  'không có giáo trình',
#  'phương pháp tư duy cho sinh viên  để sinh viên tự giải quyết các vấn đề',
#  'giảng dạy dễ hiểu  linh động trong nhiều bài tập',
#  'giảng viên giảng dạy tận tình  vui vẻ giúp học viên nhận thức được nhiều kiến thức',
#  'cải thiện chất lượng phòng máy thực hành',
#  'nếu được chọn  cô luôn là lựa chọn hàng đầu cho các môn kinh tế',
#  'cần thêm bài tập và rèn luyện kỹ năng giao tiếp',
#  'nhiệt tình giảng dạy',
#  'thoải mái về thời gian',
#  'em còn chưa thấy mặt thầy nữa  hoặc có nhưng quên rồi colondoublesurprise',
#  'các nội dung môn học thầy triển khai không đúng theo khung  mới vào mà thầy dạy servlet thì rất khó hiểu  sinh viên có góp ý qua thầy chủ nhiệm nhưng vẫn không thay đổi',
#  'mọi việc điều được sinh viên tự học  tự tìm hiểu thông qua các trang mạng  thông qua việc email trực tiếp với giảng viên',
#  'slide bài giảng còn lẫn lộn anh việt  phần tiếng việt thì giảng viên lại dùng google dịch nên đọc không hiểu',
#  'cách truyền đạt tốt  tận tâm',
#  'cô rất nhiệt tình và thân thiện với sinh viên',
#  'giảng viên tận tâm với việc dạy học  tạo cảm hứng học tập cho sinh viên',
#  'cần cho nhiều thời gian để sinh viên có đủ thời gian hoàn thành đồ án môn học',
#  'thầy rất vui tính  truyền tải thông tin tuyệt vời',
#  'đôi lúc hỏi một số câu hỏi rất mơ hồ khiến sinh viên không biết đang được hỏi về khía cạnh nào  cũ hay mới  chương trước hay chương hiện tại',
#  'hy vọng thầy sẽ cải tiến làm cho hoạt động sôi nổi hơn',
#  'quá nhàm chán  không nâng cao được kiến thức',
#  'thầy dạy khá nhiệt tình vui tính',
#  'thầy khá nhiệt huyết và gần gủi với sinh viên',
#  'bài tập khắt khe',
#  'theo thời khóa biểu hiện nay thì học thực hành trước nên sinh viên lúc thực hành chưa hiểu vấn đề nên khó khăn trong việc làm bài',
#  'cô nên tăng tốc độ giải bài hơn',
#  'tài liệu tiếng anh gây khó khăn cho ôn thi',
#  'giảng dạy tận tình  vui vẻ',
#  'giảng viên dạy có tâm huyết  kỹ càng với sinh viên  nhiệt tình giúp đỡ',
#  'khả năng truyền đạt kiến thức không cao',
#  'cần nâng cao chất lượng trang thiết bị',
#  'giảng viên vui tính  thân thiện',
#  'đầu tư các thiết bị cho sinh viên mượn  như điện thoại android  windows phone',
#  'thầy dạy tốt và tâm huyết',
#  'việc phân chia nhóm không hợp lý dẫn tới chất lượng học tập không tốt',
#  'thầy nhiệt tình  vui vẻ',
#  'tận tâm nhiệt tình  giảng giải cho sinh viên chưa hiểu tỉ mỉ',
#  'phần máy tính không hỗ trợ cho việc học nhiều  chỉ làm sinh viên phân tán',
#  'sự nhiệt tình  tâm huyết',
#  'đó là tiền của họ  họ muốn dùng thì tùy họ  người khác nghèo không phải lỗi của họ  chưa kể tiền thuế họ đóng góp cho nước cũng đủ để gọi là xây dựng rồi',
#  'các dạng bài tập rõ ràng  tài liệu cung cấp đầy đủ',
#  'giảng viên dạy tận tình  cung cấp đầy đủ kiến thức cho sinh viên',
#  'cần tăng thời gian học',
#  'nên tổ chức thêm những buổi hội thảo liên quan đến nội dung môn học',
#  'dạy đúng trọng tâm',
#  'đề nghị thầy share slide giảng dạy trên lớp',
#  'nên trang bị trang thiết bị cho phòng thực hành và phòng lab để sinh viên có thể thực hành và học trực tiếp trên thiết bị thật',
#  'thầy giảng dạy rất nhiệt tình và vui tính',
#  'nên cải tiến hệ thống chấm điểm online  update bài tập cho tất cả học sinh làm rồi có bảng xếp hạng  như bên codefun của miền bắc',
#  'bài giảng thực tế',
#  'kiến thức thầy dạy rất hay và bổ ích',
#  'hạn chế dạy bằng slide',
#  'nói sâu về vấn đề khó',
#  'thầy lên lớp không đúng giờ giấc  thường xuyên đi trễ',
#  'chất lượng phòng máy kém',
#  'phong cách giảng dạy rất hay',
#  'giáo viên giảng dạy sử dụng nhiều ví dụ thực tiễn',
#  'cần tuân thủ đúng và đủ giờ',
#  'thầy rất nhiệt tình và năng động  học thầy có thêm nhiều kiến thức mới không chỉ gói gọn trong nội dung môn học',
#  'thầy giảng bài kỹ  dễ hiểu',
#  'nhiệt tình giảng dạy  giải đáp thắc mắc rất chi tiết  cung cấp đầy đủ kiến thức cần thiết để kiểm tra',
#  'thầy giảng nhanh và cách truyền đạt hơi khó hiểu  đưa ra khá ít ví dụ để sinh viên có thể hiểu bài rõ hơn',
#  'các giảng dạy của giảng viên còn khó hiểu  rối rắm',
#  'điện thoại không liên lạc được',
#  'chưa học nhiều với thầy nên chưa có ý kiến gì về thầy',
#  'nội dung thực hành nên thay đổi doubledot mỗi tuần thực hành các phần lý thuyết trên lớp và giảng viên hướng dẫn làm đồ án cuối kỳ',
#  'giảng viên tăng cường giải đề của các năm',
#  'thiếu thiết bị thật để thực hành',
#  'nhiệt tình giúp đỡ sinh viên',
#  'giảng bài rất dễ hiểu',
#  'thực sự em vẫn chưa hiểu ngoài việc để làm bài tập thì wireshark được dùng để làm việc gì khác',
#  'em nghĩ cơ sở vật chất vẫn còn yếu kém  ngồi xa không thể nhìn rõ được slide bài giảng của cô giáo  phòng học rất nóng',
#  'thầy giải nhiều bài tập cho sinh viên giúp sinh viên củng cố kiến thức sau khi học lý thuyết',
#  'cô rất vui vẻ  nhiệt tình  tâm huyết',
#  'cần có các thiết bị di động thật để sinh viên thực hành khi cần thiết  vì các chương trình mô phỏng trên máy tính là không đầy đủ',
#  'thầy dạy dễ hiểu  code mẫu đầy đủ',
#  'điều em hài lòng nhất đó là thầy với tốc độ phù hợp và rất dễ hiễu',
#  'nên thống nhất lại nội dung môn học so với cách thi của phòng đào tạo',
#  'thầy dạy hay  nhiệt tình  không bao chê bai sinh viên dù mặc dù không tốt mà hướng sinh viên đến suy nghĩ tích cực hơn  cố gắng hơn',
#  'giảng dạy nhiệt tình  quan tâm tới sinh viên',
#  'cần tăng chú ý về kỹ năng cần thiết trong toeic như nghe  đọc',
#  'kính mong giảng viên có thể cho thêm nhiều bài tập nhằm giúp sinh viên luyện tập  nắm bắt nội dung môn học và vận dụng nó hiệu quả hơn  giúp ích cho việc học các môn sau này',
#  'cần chú trọng hơn vấn đề học thực hành phòng máy không đáp ứng yêu cầu doubledot không có trình biên dịch giáo viên thực hành không sử dụng hiệu quả giờ thực hành',
#  'thầy wzjwz239 nói chuyện cọc lốc  không hiểu vấn đề gì hỏi thầy thì thầy lại như quát vào mặt  tạt nước lạnh  … nói chuyện xưng hô mày  tao  có lúc thì xưng tớ  cậu nhưng lời nói đầy ẩn ý   hay nói móc và tìm cách bắt bẻ sinh viên',
#  'thầy có hướng dẫn đồ án rất tận tình  luôn giải đáp các câu hỏi và thắc mắc của sinh viên về đồ án rất nhanh',
#  'giúp sinh viên cảm thấy thoải mái trong giờ học',
#  'cô giảng dạy tận tình',
#  'hơi khó tính ạ',
#  'kiến thức nhiều  khó tiếp thu  phân loại chưa rõ',
#  'thầy nên cho thêm bài tập về nhà',
#  'những điều này nghe tưởng chừng không liên quan đến môn học  nhưng lại giúp cho sinh viên phần nào có định hướng được công việc tương lai của mình',
#  'em học ở phòng mà bên cạnh là công trình đang thi công  khá là ồn ào  vì thế khi học đến phần nghe  em không thể nghe được gì  và bài nghe bị gián đoạn',
#  'thầy không sửa bài tập  trên lớp thầy chỉ giảng lý thuyết theo em như thế là ít có hiệu quả',
#  'thầy ít quan tâm',
#  'giảng dạy tích cực  dễ hiểu',
#  'không dùng điểm để đánh giá  nó làm sinh viên không dám thực hiện',
#  'dạy hay  dễ hiểu  tận tình',
#  'không khí lớp học thì không được sôi nổi',
#  'bài tập thực hành mỗi tuần hơi khó  mong rằng ở mỗi bài tập giảng viên có thể cung cấp bài giải kỹ càng để sinh viên có thể nghiên cứu và hiểu được cách làm',
#  'thầy rất thoáng và thoải mái',
#  'thầy cần có tương tác với sinh viên qua mail hay moodle vì có đôi lúc có thắc mắc nhưng thầy không phản hồi',
#  'kiến thức đơn giản',
#  'phần lý thuyết lặp lại nên chán  không thu hút',
#  'thầy dạy rất hay và rất nhiệt tình',
#  'giảng viên giảng dạy theo đúng thời gian môn học',
#  'thầy rất dễ gần',
#  'khi sinh viên hỏi phải có câu trả lời chính xác không được bỏ qua những câu hỏi của sinh viên',
#  'chấm điểm dựa trên mức độ thấu hiểu bài  hay đưa ra lời khuyên hữu ích',
#  'luôn nhiệt tình trong giảng dạy',
#  'thầy vui vẻ',
#  'giảng bài kỹ càng  dễ hiểu',
#  'cần tăng thời gian thực hành nói lên',
#  'cô giảng dạy rất nhiệt tình và dễ hiểu',
#  'giảng dạy tốt',
#  'nhiệt tình  cô dễ thương',
#  'giảng viên dạy truyền cảm hứng  sử dụng thời gian hợp lý',
#  'giảng viên dạy tận tâm nhiệt tình',
#  'thì có thể lướt nhanh hơn vì phần này khá dễ',
#  'giảng viên có chuyên môn rất tốt  kiến thức rộng  giải đáp được mọi thắc mắc của sinh viên',
#  'giảng viên hiền lành  nhiệt tình giúp đỡ khá nhiều cho sinh viên khi sinh viên không hiểu bài',
#  'giảng viên rất tận tình',
#  'thầy rất nhiệt tình  năng nổ',
#  'truyền đạt có cảm hứng  hướng dẫn sinh viên học tập thế nào sau khi ra trường để xin việc',
#  'học thoải mái  ít áp lực',
#  'cô dễ thương và giảng bài tận tình',
#  'cô dạy rất tốt  nhiều bài tập',
#  'thầy giảng dạy nhiệt tình dễ hiểu  sửa bài tập cẩn thận',
#  'giảng viên rất đảm bảo giờ lên lớp',
#  'thầy là giảng viên dạy toán hay nhất trường',
#  'môn học này thật sự rất khó và chương trình học hơi nặng  lúc trước môn này dược chia ra làm 2 môn là cấu trúc dữ liệu 1 và cấu trúc dữ liệu 2  năm nay lại gộp thành một nên sinh viên khó tải nổi kiến thức',
#  'cần kết nối được mạng trong phòng lab',
#  'nhiệt tình  phương pháp giảng dạy rất hiệu quả cách truyền đạt rất dễ hiểu và dễ tiếp thu biết cách truyền cảm hứng và tạo động lực học tập cho sinh viên',
#  'luyện nghe nhiều hơn',
#  'giảng viên giảng dạy rất truyền cảm  tạo cảm giác ham học và hệ thống bài tập dồi dào phong phú',
#  'thầy có cách giảng bài rất hay và dễ hiểu',
#  'thầy dạy bằng slide bài giảng hơi nhanh',
#  'cách dạy của cô hay  thú vị  tạo động lực',
#  'thầy dạy vui vẻ  không có áp lực quá khắt khe',
#  'giải thích cặn kẽ đi sâu hơn nữa',
#  'cho bài tập nhiều em rất thích colonsmile',
#  'giảng viên vui vẻ nhiệt tình',
#  'giảng viên nhiệt tình  phương pháp giảng dạy dễ hiểu',
#  'giảng viên rất tâm huyết và nhiệt tình  giảng bài dễ hiểu',
#  'thầy wzjwz127 dạy rất nhiệt tình',
#  'cô nhiệt tình và đưa ra bài giảng hợp lý  dễ hiểu  có thể vận dụng làm bài',
#  'giảng viên dạy nhiệt tình  truyền đạt kiến dễ hiểu',
#  'thời gian học tập luôn thiếu sót  giảng viên chưa nhiệt tình giảng dạy',
#  'rất thích được học cô',
#  'tiếp cận với sinh viên một cách thân thiện  phương pháp dạy khoa học  dễ tiếp thu  dễ hiểu',
#  'chữ viết nhỏ',
#  'thường xuyên cho nghỉ mà không thông báo',
#  'dạy hơi cao so với năng lực',
#  'giáo viên nhiệt tình  tận tâm giúp đỡ sinh viên',
#  'thích thầy chia sẻ kinh nghiệm',
#  'quá khó tính  giờ cao su  giảng dạy lan man không hiệu quả',
#  'giảng viên giảng không hay  đã vậy còn không nhiệt tình  không vui vẻ  không tạo cơ hội cho sinh viên hỏi về bài giảng',
#  'thầy dạy không có sức hút  nhàm chán  gây buồn ngủ cho sinh viên',
#  'thầy thật sự là một giảng viên dạy học rất có tâm',
#  'thầy dạy nhiệt tình  rất hăng hái',
#  'giọng cô êm êm  dễ buồn ngủ',
#  'truyền đạt nhiều kinh nghiệm tốt cho sinh viên',
#  'khi phản ánh kết quả bài tập không đúng thì cô lại lơ  cười rồi bỏ đi  không có một đáp án cụ thể',
#  'thầy khá hài hước  nói những việc thực tế về ngành it  rất thiết thực',
#  'thầy wzjwz177 rất gần gũi với sinh viên  thầy phát âm tiếng anh cũng rất dễ nghe',
#  'phòng học ồn do cạnh khu xây dựng',
#  'giảng bài dễ tiếp thu nhiệt tình',
#  'lớp đã nghỉ 4 tuần liên tiếp chưa tính một vài ngày nghỉ khác',
#  'em mong phần thực hành được hỗ trợ nhiều hơn nữa từ phía giảng viên',
#  'giảng bài khó hiểu',
#  'cô dạy rất nhiệt tình  cung cấp thông tin đầy đủ nhưng vẫn tạo điều kiện cho sinh viên tìm hiểu thêm',
#  'thầy rất nhiệt tình với học sinh',
#  'dễ học dễ hiểu',
#  'hình như em đăng ký thầy dạy mà thầy dạy mấy buổi người khác dạy mấy buổi thì phải',
#  'chưa giảng dạy nhiều về bài tập  cũng như hướng dẫn sinh viên hướng giải quyết nó',
#  'thầy rất tận tình  luôn luôn giúp đỡ  hỗ trợ sinh viên',
#  'thầy giảng rất hay và dễ hiểu  phong cách dạy độc đáo',
#  'thầy wzjwz237 rất vui và nhiệt tình',
#  'nên đưa môn wzjwz129 vào giảng dạy ngay sau môn wzjwz130 và trước khi học các môn chuyên ngành',
#  'chất lượng tốt giáo viên nhiệt tình',
#  'giảng viên dạy rất nhiệt tình',
#  'thầy dạy sát theo slide nhưng một số kiến thức bài tập lại khó hơn nhiều',
#  'trao dồi thêm về kỹ năng speaking và listening',
#  'ít bài tập',
#  'cô dạy có tâm huyết với học sinh  truyền đạt tốt  dễ hiểu',
#  'đảm bảo giời lên lớp',
#  'ngiêm túc  cứng rắn về vấn đề tự học',
#  'em mail bổ sung bài thực hành giáo viên không hồi đáp  mail xin sửa điểm giảng viên không reply đồng ý xem xét hay không đồng ý',
#  'thời gian cô up slide lên module còn chậm',
#  'thầy đưa ra những demo thực tế  giúp sinh viên dễ hiểu',
#  'nope',
#  'thầy cho khá nhiều bài tập đa dạng',
#  'các phần tiếng việt trong slide được ghi một cách khó hiểu và không rõ ràng  nhiều chỗ trong slide bài giảng có vẻ như được dịch bằng google dịch từ năm 2009',
#  'cô quan tâm đến sinh viên và truyền đạt kiến thức rất bổ ích',
#  'không thực tế',
#  'tiết học của thầy rất vui',
#  'học trong phòng chất lượng cao hơn  phòng học hiện tại không có máy lạnh',
#  'giảng viên chưa truyền đạt tốt  dạy còn chán  không có sự thu hút trong cách dạy lắm',
#  'hướng dẫn rất tận tình  trình bày hướng dẫn rất đẹp  có phong cách  thể hiện một thái độ rất nghiêm túc trong công việc giảng dạy',
#  'giảng bài dễ hiểu  dễ vận dụng',
#  'thầy vui tính dạy dễ hiểu và cung cấp nhiều thông tin hữu ích cho sinh viên',
#  'thầy quá chuyên nghiệp',
#  'cô giảng có hơi khó hiểu',
#  'tạo bầu không khí thoải mái cho sinh viên',
#  'em rất hài lòng về phương pháp giảng dạy của thầy',
#  'dạy nhiệt tình  theo sát môn học',
#  'vì tính cô kỹ nên đôi lúc nói quá nhiều về một vấn đề  lặp đi lặp lại  làm mất thời gian trên lớp và sử dụng giờ học không hiệu quả',
#  'mong giáo viên có thể giải đáp nhiều bài tập cho sinh viên hơn trên lớp',
#  'đầu tư thêm nhiều công cụ dạy học',
#  'giảng viên rất đúng giờ',
#  'cách giảng dễ hiểu',
#  'thang điểm đưa ra đầu khóa học không rõ ràng  nhất quán so với thang điểm cuối khóa',
#  'thầy hứa sẽ up điểm giữa kỳ sớm mà điểm giữa kỳ thì tới giờ này vẫn chưa có',
#  'thực hành nhiều',
#  'nhiệt tình với sinh viên  tư tưởng thoải mái',
#  'cho sinh viên chép bài để nhớ kiến thức hơn  rèn luyện nhiều bài tập  dạy nhiệt tình',
#  'nhiều hoạt động',
#  'giảng viên áp dụng mô hình scrum để làm project là tốt nhưng không thành công',
#  'hay kể các chuyện liên quan đến thực tiễn giúp bọn em tiếp thu nhanh hơn và cũng có hứng thú trong quá trình học',
#  'đây là điều gây bức xúc với sinh viên',
#  'khó hiểu ạ',
#  'ân cần  tận tụy',
#  'máy chiếu chưa rõ nét cho toàn thẻ sinh viên trong phòng',
#  'cô nhiệt tình  sẵn sàng giảng lại các kiến thức mà sinh viên chưa nắm được khi học lý thuyết',
#  'nâng cao trang thiết bị phòng học',
#  'giảng viên nhiệt tình  hết mình truyền đạt kiến thức',
#  'cô có thể giảng phần lý thuyết kỹ hơn được không ạ',
#  'thầy nên share lại slide cho sinh viên',
#  'nhiều tâm huyết với nghề',
#  'dạy tốt  tận tình',
#  'thầy rất nhiệt tình trong việc trả lời các câu hỏi phụ của sinh viên',
#  'hiện tại em không nhớ nổi mặt của thầy fraction cô như nào nữa colondoublesurprise',
#  'phòng thực hành cần nâng cấp và bổ sung thêm thiết bị để mọi người đều có điều kiện thực hành thực tế nhiều hơn',
#  'giảng viên nên trao đổi với sinh viên nhiều hơn  giao bài tập và giải thích những thắc mắc của sinh viên về môn học',
#  'cô thân thiện với học sinh  truyền cảm hứng  động lực tốt',
#  'thầy kiểm tra quá nhiều',
#  'thầy rất khắt khe trong việc dùng từ chuyên ngành',
#  'thầy dạy rất tốt',
#  'những gì được học nó nhằm mục đích gì',
#  'cần cung cấp thêm tài liệu học tập môn học này',
#  'cách dạy của thầy rất nhàm chán  không có nhiều hoạt động thực tế  bài tập thầy cho chỉ áp sát lý thuyết mà chưa thực tế',
#  'nên dành nhiều thời gian cho bài tập và hướng dẫn cụ thể phương pháp giải hơn',
#  'đôi khi học sinh nào bận muốn về trước thầy vẫn cho',
#  'nhiều lúc lớp chỉ có hai người đi học',
#  'có thể chia nhóm ra làm thực hành',
#  'thầy wzjwz83 rất nhiệt huyết trong việc giảng dạy',
#  'thầy vui quá đi hi hi',
#  'giảng viên nhiệt tình  chắt lọc nội dung cũng như mở rộng nhiều kiến thức về bộ môn',
#  'thầy giảng rất hay  rất tận tâm với sinh viên',
#  'em mong có sự thống nhất giữa thầy cô trong quá trình giảng dạy môn này',
#  'chưa ổn',
#  'giảng viên tận tâm  dạy tốt',
#  'sử dụng giờ học hiệu quả',
#  'cách nói chưa lôi cuốn',
#  'thầy không đảm bảo giờ lên lớp  nếu có nghỉ thầy cũng không thông báo trước rất vô lý',
#  'nhiệt tình truyền đạt kiến thức cho sinh viên',
#  'lý thuyết và thực hành nên đi đôi với nhau',
#  'thân',
#  'thầy dạy quá tệ',
#  'không có nhiều bài tập để làm thêm',
#  'phòng học quá sáng  màn chiếu bị mờ rất khó nhìn  xin ban quản lý lắp rèm để sinh viên và giảng viên thuận tiện trong việc học tập và giảng dạy',
#  'giáo viên quá tốt',
#  'cần cân bằng việc giảng dạy giữa sinh viên yếu và khá trở lên',
#  'nhiệt tình  giảng dễ hiểu  dễ thương',
#  'giảng viên dạy rất dễ hiểu',
#  'tài liệu cung cấp thiếu',
#  'thầy nên đánh giá kỹ hoạt động trên lớp của từng thành viên trong nhóm  ai đóng góp nhiều  nghiêm túc',
#  'giáo viên lên lớp muộn  nghe điện thoại trong lúc lên lớp thường xuyên  nghỉ dạy không thông báo',
#  'đề nghị nên cho bài tập về nhà',
#  'mong thầy giảng giải và cho bài tập từng bước nhiều hơn',
#  'thầy cho đề thực hành cũng khá hay  nhưng mà thật thì em toàn code mấy bài đó trên notepad rồi nộp  không test gì cả  nhưng được cái là đồ án 10 thì điểm thực hành cũng 10 luôn',
#  'khó hiểu  không sinh động',
#  'chỉ dạy nhiệt tình',
#  'giáo viên truyền đạt những vẫn đê sâu',
#  'chưa cung cấp cách nhìn sâu hơn về môn học vào thực tế hiện nay  chỉ mới mang tính trừu tượng',
#  'giảng viên dạy dễ hiểu  và đầy đủ nội dung',
#  'không hướng dẫn kỹ',
#  'nhiệt tình  chi tiết',
#  'thầy cho chép bài ít thôi  tập trung sửa bài được không ạ',
#  'khả năng truyền đạt chưa đi vào lòng người cho lắm',
#  'thầy rất nhiệt tình  dạy rất kỹ  thầy cũng rất vui tính',
#  'giảng viên nhiệt tình  vui vẻ  giờ học vui',
#  'cô dạy không hấp dẫn  tuy hay nhưng không kích thích được sinh viên hoạt động',
#  'thưa  không có ạ',
#  'kiến thức môn học mang lại tương đối đầy đủ và thực tế giúp sinh viên nắm rõ phương pháp và cách thức để học tập các môn chuyên ngành sau này',
#  'cách giảng dạy  tạo không khí sôi nổi trong lớp',
#  'trình bày bài giảng một cách khoa học và hợp lý',
#  'tuy nhiên  giờ trên lớp thầy chưa thực sự sử dụng hiệu quả lắm khi thiếu tương tác với sinh viên trong lớp để nắm tình hình học viên của mình',
#  'thầy dễ thương  nhiệt tình  dạy dễ hiểu',
#  'nên cho thời gian học nhiều hơn 2 tiết',
#  'cô vui tính  hiền  khá nhiệt tình và gần gũi với sinh viên colonsmilesmile',
#  'những gì quan trọng cần nắm bắt và tìm hiểu thêm',
#  'cá nhân em thấy đôi khi nhìn thầy em cảm thấy hơi sợ sợ',
#  'rèn luyện được kỹ năng giao tiếp  mạnh dạng đứng trước lớp nói tiếng anh',
#  'thầy hướng dẫn thực hành hay',
#  'cập nhật kiến thức thực tế',
#  'giảng viên nhiệt tình  luôn luôn đến lớp đúng giờ',
#  'chỉ có vấn đề thầy dạy hơi nhanh',
#  'giảng viên truyền đạt còn chưa tốt',
#  'tình trạng nghỉ không thông báo cho sinh viên để sinh viên đứng đợi giảng viên gần hết giờ rồi ra về nhiều lần',
#  'cô giảng dạy chi tiết trong quá trình học',
#  'kiến thức chưa có trọng tâm',
#  'tiết học vui vẻ  thoải mái',
#  'chưa tương tác nhiều với sinh viên',
#  'thân thiện  nhiệt tình',
#  'yêu cầu quá cao đối với một sinh viên  mặc dù chỉ là một đồ án nhưng không nhất thiết phải quá chi tiết về mọi khía cạnh cụ thể',
#  'cô hướng dẫn phương pháp học tập hiệu quả',
#  'thầy cần hoạt động trao đổi nhiều hơn với sinh viên',
#  'thầy dạy rất dễ hiểu  đúng trọng tâm bài học',
#  'cho quá nhiều bài tập  chỉ nên cho bài tập ví dụ điển hình',
#  'giúp em hiểu ra được nhiều cái hay',
#  'thầy giảng rất hay  dễ hiểu',
#  'giảng viên giảng bài hơi nhàm chán  gây cảm giác buồn ngủ  có nhiều chỗ hơi lan man',
#  'giáo viên giạy theo cách quá thụ động  tạo sự nhàm chán cho sinh viên',
#  'thầy rất tận tâm nhưng không có kỹ năng sư phạm',
#  'nội dung hơi nhiều nên giảm bớt lại',
#  'thầy chỉ dạy rất tận tình  luôn hỏi học sinh phần nào chưa hiểu và giảng lại rất kỹ  những bài giảng của thầy rất hay',
#  'mong thầy giải bài tập trên lớp',
#  'do thời gian mỗi buổi học khá ngắn nên giảng viên cần tập trung vào những chủ đề quan trọng  phần còn lại nên để sinh viên tự tìm hiểu',
#  'giáo viên rất tận tâm nhiệt tình',
#  'mong rằng những môn có thực hành  giáo viên nên mở chat box và forum cho sinh viên dễ trao đổi với nhau  cũng như nhanh chóng nhận được lời giải đáp thắc mắc từ giáo viên',
#  'cô dạy quá hay rồi',
#  'thêm hệ thống ổ điện ngầm dưới nền nhà để tiện cho việc sinh viên có thể cắm laptop phục vụ học tập',
#  'chất lượng môn học phù hợp',
#  'cô dạy rất nhiệt tình và rất kiên nhẫn với sinh viên',
#  'có sai nhận sai và sửa đổi khắc phục',
#  'thầy dễ tính  dạy dễ hiểu  thầy dạy hay',
#  'giáo viên dễ gần  tận tâm',
#  'thầy rất vui tính dạy dễ hiểu',
#  'không có hoạt động giảng dạy nào không hài lòng',
#  'lên vừa cho học lý thuyết vừa cho thực hành',
#  'môn học với kiến thức không quá nặng',
#  'nội dung thực hành đã cũ  không được đổi mới và không sát với thực tế',
#  'các code ví dụ không được chiếu hết trên slide',
#  'chỉ dạy tận tâm',
#  'thầy dạy nhiệt tình  chia sẻ những kiến thức bổ ích',
#  'thầy dạy rất nhiệt tình  dễ hiểu  tận tâm',
#  'giảng hơi ít',
#  'em mong môn này có thể áp dụng nhiều hơn trong những đồ án',
#  'giải ví dụ  bài tập nhiều hơn',
#  'thành thật mà nói thì sau khi học buổi đầu xong thì em không muốn học thêm buổi thứ hai',
#  'đề nghị thầy xem lại việc chấm chéo đồ án và báo cáo chéo đồ án',
#  'bài dạy phụ thuộc nhiều vào slide  cách truyền đạt chưa thực sự phù hợp với cá nhân',
#  'có slide bài giảng tiếng anh giúp nâng cao trình độ đọc hiểu tài liệu chuyên ngành và nâng cao kiến thức cho sinh viên',
#  'học đúng giờ nhưng ra về thì sớm hơn quy định',
#  'chuyên nghiệp',
#  'giảng viên thoải mái  hòa đồng',
#  'thầy dạy rất tốt',
#  'cách truyền đạt kiến thức của thầy đối với em thì em cảm thấy không phù hợp lắm  em cần phải rất rất tập trung và hỏi đi hỏi lại nhiều lần mới có thể nắm bắt kiến thức',
#  'thầy cho nghỉ hơi nhiều',
#  'giảng viên nên cung cấp tài liệu học tập cho sinh viên',
#  'thầy dạy nhiêt tình  kỹ càng',
#  'thầy dạy hay  nhiều kiến thức mở rộng  được học trên slide tiếng anh',
#  'thầy dạy tốt không phụ thuộc nặng vào chương trình',
#  'slide bao nhiêu thầy đọc lại bấy nhiêu  cực kỳ khó hiểu và buồn ngủ',
#  'cải tiến trang thiết bị phòng thực hành',
#  'giảng viên nên dạy đúng giờ hơn hạn chế cho sinh viên về sớm',
#  'em hi vọng trong các tiết học thầy có thể đi sâu vào kiến thức chuyên môn và giảm bớt thời lượng của hoạt động liên hệ thực tế',
#  'chân thành cảm ơn thầy',
#  'không có ý kiến nhiều',
#  'không có',
#  'cách chấm điểm của giảng viên không đánh giá đúng năng lực của sinh viên',
#  'em không có ý kiến về mục này ạ',
#  'thời gian và cách thức thầy dạy',
#  'giảng quá khó hiểu',
#  'các thiết bị âm thanh cần được đảm bảo hơn',
#  'nên phát hành giáo trình chuẩn cho môn học',
#  'dưới đây là hình thầy cung cấp toàn bộ tài liệu trong quá trình học',
#  'lịch thực hành không được thông báo',
#  'thầy dạy rất tốt  nhiệt tình và rất dễ hiểu',
#  'lắp quạt phù hợp vì phòng có 2 dãy quạt 2 bên nhưng ngồi ở dãy giữa vẫn nóng  cần có màn che cửa sổ và có ổ cắm điện',
#  'lên lớp toàn cho làm paper',
#  'kiến thức được đưa vào ứng dụng nhiều bài toán',
#  'giảng viên làm rất tốt trong việc giảng dạy bộ môn thực hành',
#  'cô wzjwz253 nhiệt tình  giảng bài kỹ',
#  'thầy wzjwz199 rất nhiệt tình trong quá trình giảng dạy',
#  'sau kỳ thi giữa kỳ cấu trúc dữ liệu lý thuyết  chủ yếu là thi về thuật toán sắp xếp  thì thầy mới cho làm bài tập về các thuật toán sắp xếp',
#  'giảng viên nhiệt tình  gần gũi với sinh viên',
#  'có nghĩ 2 buổi không hề báo trước',
#  'them nhiều tài liệu và video hướng dẫn',
#  'giảng viên nên cho số lượng bài tập vừa phải  giải chậm và sâu ở mỗi dạng toán đặc biệt là những dạng toán khó',
#  'cần có nhiều buổi thực hành trên thiết bị thật hoặc giảng viên nên đem thiết bị thật làm vài bày mẫu trên lớp',
#  'môn học nên tập trung vào chuyên sâu các mục  nên có biên soạn giáo trình mới  chuyên sâu hơn',
#  'thầy dạy dễ hiểu  rất hay',
#  'thời khóa biểu phân chia không hợp lý  chưa học lý thuyết đã phải học thực hành',
#  'cung cấp nhiều bài tập cho sinh viên tham khảo',
#  'thầy cô dạy chưa sâu vào bài học',
#  'nói nhỏ  rất khó nghe',
#  'thầy hầu như không giải đáp thắc mắc của sinh viên khi bài tập mắc lỗi hoặc có nhưng rất hời hợt',
#  'chưa thực sự tận dụng tốt thời gian và chưa mở rộng vấn đề',
#  'công bằng',
#  'thầy giảng rất kỹ và dễ hiểu  cho rất nhiều bài tập giúp sinh viên ứng dụng và nhớ được những gì đã học',
#  'cô dạy dễ hiểu  vui vẻ với sinh viên  cung cấp đầy đủ kiến thức cần thiết',
#  'bài giảng hơi khó hiểu',
#  'nên muốn nhà trường tăng thêm thời gian học lý thuyết của môn này',
#  'thường xuyên tổ chức thảo luận  thực hành nói',
#  'giảng viên dạy có phần hơi nhanh',
#  'giúp chúng em học tập tốt hơn',
#  'thầy dạy hay tận tình',
#  'thầy dạy rất hay  chi tiết',
#  'tận tụy với sinh viên',
#  'thầy rất nhiệt tình và có kiến thức sâu rộng  cung cấp nhiều kiến thức hay',
#  'hầu như trong cả năm học  giảng viên chỉ đi dạy đúng thời khoá biểu chỉ từ 2 đến 3 ngày  còn lại giảng viên lại tự ý dời lịch học sang ngày thứ 7 mà không hỏi ý kiến của sinh viên  vì vào ngày thứ 7 có rất nhiều sinh viên có lịch học môn khác',
#  'cần thêm nhiêu bài tập thực tế',
#  'không tập trung vào giảng kiến thức cho học sinh hiểu',
#  'thật sự rất thất vọng về việc dạy thực hành của thầy',
#  'góp ý doubledot thầy nên có cách tiếp cận khác để cân bằng giữa vấn đề ngoại ngữ và kiến thức chuyên ngành',
#  'thầy dạy lý thuyết được',
#  'thầy dạy nhanh  hay',
#  'nên cho nhiều bài tập hơn',
#  'giảng viên nhiệt tình  quan tâm đến học sinh',
#  'môn học có 5 lab mà chỉ học 2 lab là thi cuối kỳ  thầy nên lên lớp đủ số buổi quy định',
#  'slide hơi khó hiểu',
#  'giáo viên thực hành cần quan tâm  chỉ dẫn sinh viên tận tình hơn',
#  'giảng viên lên lớp đầy đủ',
#  'giảng viên nhiệt tình  hỗ trợ sinh viên tốt',
#  'giảng viên hay cho nghỉ học mà không báo trước',
#  'trang thiết bị còn hỏng hóc nhiều  thường xuyên trục trặc trong giờ học',
#  'hiểu tâm lý học sinh nên mọi người trong lớp đều chú ý giảng bài',
#  'phòng wzjwz325 thiết bị âm thanh hay xảy ra trục trặc làm gián đoạn buổi học',
#  'vui tính  thân thiện',
#  'nhiệt tình  năng nổ',
#  'không có sự thoải mái khi học tập',
#  'giảng viên dạy tận tâm  nhiệt tình  lên lớp đúng giờ',
#  'mong cô cung cấp nhiều tài liệu có hướng dẫn giải cụ thể các dạng toán để đáp ứng nhu cầu tự học',
#  'giảng viên nhiệt tình  vui vẻ  hoà đồng  gần gũi giúp sinh viên khá nhiều trong việc tiếp thu kiến thức',
#  'mong nhà trường xem xét lại để có sự nhất quán trong công tác dạy và chấm thi',
#  'truyền đật kiến thức tốt  dễ hiểu',
#  'tài liệu thực hành nên nêu rõ mục tiêu cũng như kiến thức cần đạt được sau bài thực hành',
#  'và giảng dạy khó hiểu',
#  'ít quan sát sinh viên thực hành',
#  'có một bạn trong phòng của em học thầy ở học kỳ trước hâm mộ thầy',
#  'bài tập cuối kỳ làm quá nhiều',
#  'cô dạy có tâm  post tài liệu và bài tập lên moodle rất đầy đủ',
#  ...]

# %%
def word_segmentation(sentences):
    segmented_sentences = []
    for sent in sentences:
        segmented_sent = underthesea.word_tokenize(sent, format="text")
        segmented_sentences.append(segmented_sent)
    return segmented_sentences
train_sents = word_segmentation(train_sents)
train_sents
# Out:
# ['slide giáo_trình đầy_đủ',
#  'nhiệt_tình giảng_dạy gần_gũi với sinh_viên',
#  'đi học đầy_đủ full điểm chuyên cần',
#  'chưa áp_dụng công_nghệ_thông_tin và các thiết_bị hỗ_trợ cho việc giảng_dạy',
#  'thầy giảng bài hay có nhiều bài_tập ví_dụ ngay trên lớp',
#  'giảng_viên đảm_bảo thời_gian lên lớp tích_cực trả_lời câu_hỏi của sinh_viên thường_xuyên đặt câu hỏi cho sinh_viên',
#  'em sẽ nợ môn này nhưng em sẽ học_lại ở các học_kỳ kế_tiếp',
#  'thời_lượng học quá dài không đảm_bảo tiếp_thu hiệu_quả',
#  'nội_dung môn_học có phần thiếu trọng_tâm hầu_như là chung_chung khái_quát khiến sinh_viên rất khó nắm được nội_dung môn_học',
#  'cần nói rõ hơn bằng cách trình_bày lên bảng thay_vì nhìn vào slide',
#  'thầy rất tận_tình và đi dạy rất đúng giờ',
#  'dễ bị áp_lực',
#  'đang dạy thầy wzjwz208 đi qua nước_ngoài giữa_chừng thầy wzjwz209 dạy thay',
#  'môn_học còn dễ cần nâng độ khó lên nữa',
#  'có_thể cho sinh_viên đi thăm quan nhiều công_ty xem quy_mô và cách làm_việc để giúp hiểu rõ hơn vê ngành mình đang học',
#  'hài_lòng về tất_cả',
#  'nhiệt_tình vui_vẻ',
#  'thấy nhiệt_tình trong việc trao_đổi giúp_đỡ về học_tập',
#  'phong_cách giảng bài của thầy rất gần_gũi với sinh_viên',
#  'giảng_dạy kết_hợp các hoạt_động giải_trí có hiệu_quả',
#  'cần tạo các buổi seminar để sinh_viên có_thể hiểu sâu thêm về các vấn_đề trong chuyên_ngành nhưng không có trong môn_học',
#  'tiết học thoải_mái',
#  'thầy nhiệt_tình quan_tâm tới sinh_viên',
#  'giảng_dạy nhiệt_tình hướng_dẫn chi_tiết đến lúc sinh_viên hiểu',
#  'chưa có nhiều tiết làm bài tập chữa bài_tập trên lớp',
#  'tài_liệu được bổ_sung nhiều và đầy_đủ trên moodle',
#  'giảng_viên phải nên cho ví_dụ cụ_thể những phần quan_trọng nên nói kỹ có_thể lấy ví_dụ minh_họa tránh việc lập đi lập lại nhiều lần sẽ tạo cảm_giác chán cho sinh_viên',
#  'nên biên_soạn một tài_liệu của chính_trường ta',
#  'không giúp_đỡ sinh_viên trong những vấn_đề xung_quanh',
#  'bài tập đa_dạng cụ_thể',
#  'nội_dung giảng_viên yêu câu seminar hầu_như không có tài_liệu tham_khảo và rất ít ứng_dụng trong thực_tế đề_nghị có sự thay_đổi trong những năm_học tới',
#  'slide up đầy_đủ trước mỗi buổi học',
#  'nội_dung giảng_dạy quá nhàm_chán khô_khan',
#  'lượng kiến_thức quá nhiều trong một học_kỳ',
#  'thầy chép bảng nhiều',
#  'thầy tận_tình hướng_dẫn cách làm giải_quyết những thắc_mắc của sinh_viên',
#  'chúc các thầy_cô anh_chị làm_việc vui_vẻ',
#  'hay nhiệt_tình dễ hiểu',
#  'mặc_dù nhiệt_tình nhưng khi truyền_đạt thì lại khó hiểu sử_dụng ngôn_từ gây khó_khăn cho việc hiểu bài',
#  'thầy dạy khá hay cung_cấp nhiều thông_tin liên_quan đến môn_học đưa ra nhiều hướng giải_quyết khi sinh_viên gặp vấn_đề khó_khăn với đồ_án',
#  'hy_vọng học_kỳ sau có_thể học được với cô',
#  'nhiều khi em lên lớp học môn đặc_tả hình_thức giống như lên lớp_học mà không biết mình học cái gì',
#  'trong khi giảng nói_nhỏ quá',
#  'thực_hành khó hiểu',
#  'thầy rất tận_tâm nhiệt_tình quan_tâm đến sinh_viên giảng bài dễ hiểu kiến_thức sâu_rộng am_hiểu cao',
#  'cô dạy với nhiệt_huyết của mình dù như thế_nào cô vẫn luôn mỉm cười và kiên_trì giảng bài cho chúng_em đến khi chúng em hiểu',
#  'cô lên_lớp đúng giờ giảng bài rất dễ hiểu cho sinh_viên',
#  'những thông_tin cần_thiết như doubledot thời_gian dealine cách nộp bài thường không dặn lớp thực_hành thứ hai',
#  'thầy nhiệt_tình dễ_chịu',
#  'giảng_viên chưa đi sâu vào bản_chất của vấn_đề em chỉ học thôi mà không biết bản_chất của nó là gì nó có ứng_dụng gì sau_này cho chuyên nghành của em',
#  'đặc_biệt hơn là thầy đã bỏ rất nhiều công_sức trong việc ra bài tập và chấm điểm một_cách rõ_ràng và minh_bạch',
#  'cô rất nhiệt_tình và tận_dụng tốt thời_gian',
#  'giảng_viên tận_tâm nhiệt_huyết trong giảng_dạy',
#  'thầy nhiệt_tình gần_gũi',
#  'giảng_viên tận_tâm giảng dễ hiểu dễ tiếp_thu',
#  'tạo ra sự cạnh_tranh trong mỗi buổi thực_hành',
#  'bài tập và có code tham_khảo',
#  'cần nâng_cấp hệ_thống wifi vì khi vào phòng thực_hành sinh_viên không_thể truy_cập internet buộc phải xin phép ra ngoài để làm bài',
#  'tài_liệu không chi_tiết lắm',
#  'tận_tâm nhiệt_tình vui_tính dễ gần với sinh_viên',
#  'thầy dạy rất hay và nhiệt_tình',
#  'thầy dạy không đúng giờ không hướng_dẫn sinh_viên thực_hành',
#  'giúp_đỡ học_sinh quá ít',
#  'cô dạy buồn_ngủ quá',
#  'nên kinh mong nội_dung môn_học được giảm tải cho phù_hợp hơn với đặc_thù của một trường công_nghệ_thông_tin',
#  'thầy tận_tình vui_tính',
#  'cô lại kiểu khó_tính nữa',
#  'tạo hứng_thú cho sinh_viên',
#  'cô giảng hay cuốn_hút và truyền_đạt dễ hiểu',
#  'có hứng_thú học',
#  'ôn_tập đúng theo thầy nhưng không biết cuối kỳ được mấy điểm',
#  'giảng_viên hướng_dẫn cụ_thể chi_tiết',
#  'giáo_trình quá ít và nội_dung không khác nhau là mấy',
#  'giáo_viên nghỉ dạy liên_tục cuối học_kỳ lại tăng học bù những tiết học bù đó đã ảnh_hưởng đến những đồ_án và trễ deadline',
#  'giáo_viên lúc dạy lúc không không dạy cũng không thông_báo sinh_viên tốn thời_gian công_sức tiền_bạc rồi ngồi đợi và đi về',
#  'cần có một phòng máy tốt hơn hiện_đại hơn',
#  'thầy nên cho làm bài tập tương_tự nhau nhiều hơn một_vài bài để tránh tình_trạng quên hoặc các dạng tựa nhau nhưng hơi khác cách làm',
#  'không ngờ môn này lại chán đến như vậy không học được gì từ môn này thầy dạy chán kinh_khủng hay đi trễ từ 30 45 phút không nhiệt_tình',
#  'giảng_viên đánh_giá sai điểm và năng_lực của học_sinh',
#  'không đáp_ứng được đề_cương môn_học đề ra',
#  'thầy nên hướng_dẫn thực_hành nhiều hơn',
#  'giảng_viên thân_thiện quan_tâm tới sinh_viên',
#  'môn lập_trình hướng đối_tượng nên cập_nhật thêm những nội_dung mới dễ hiểu và giảng_giải cụ_thể hơn',
#  'giáo_viên nhiệt_tình tâm_huyết khả_năng truyền_đạt tốt',
#  'thầy dạy rất tốt và nhiệt_tình',
#  'cô nói hơi nhỏ nếu lớp ồn sẽ khó nghe',
#  'bài tập cô đưa ra nhiều và khó tìm_hiểu với kiến thực_hiện tại của sinh_viên thì khó có_thể tìm_hiểu và làm tốt bài_tập cô ra',
#  'bài tập và hoạt_động nhóm còn ít',
#  'giảng_viên rất nhiệt_tình phương_pháp giảng_dạy hay sinh_viên nắm_bắt kiến_thức ngay trên lớp',
#  'cô hướng_dẫn thực_hành khá đầy_đủ',
#  'được học nhiều kinh_nghiệm từ thầy wzjwz163',
#  'kiến_thức của thầy rất tốt bảo_đảm giờ lên lớp',
#  'hiện_tại em chưa thấy tác_dụng gì nhiều khi học môn này',
#  'cải_thiện lại cơ_sở_vật_chất máy chiếu trong phòng_học',
#  'dạy không phù_hợp với cách học của em',
#  'giải_thích nội_dung mới rõ_ràng',
#  'lớp học quá đông',
#  'môn căn_bản mà thầy không dạy cho sinh_viên kỹ gây không hiểu mất căn_bản',
#  'giảng_viên chưa cho bài_tập về nhà để sinh_viên làm_nên cho 5 bài mỗi chương không cần chữa chỉ cần đáp_án',
#  'mà hiện_tại trường ta chưa có đây là thiệt_thòi lớn đối_với tụi em',
#  'tôi cảm_thấy giảng_viên dạy rất tốt',
#  'không biết thầy nào dạy chính_thức mà học thường nghỉ không thông_báo trước để sinh_viên đứng chờ sắp hết tiết rồi tự về nhiều lần',
#  'cần có sự tương_tác giữa giảng_viên và sinh_viên nhiều hơn',
#  'giảng_viên thân_thiện nhiệt_tình cởi_mở',
#  'giáo_viên có mời các công_ty về trình_bày giúp sinh_viên cập_nhật kiến_thức thực_tiễn',
#  'coi lại thái_độ giảng_viên thực_hành',
#  'giảng_viên nhiệt_tình giải nhiều bài tập',
#  'bài giảng của thầy rất nhiệt_tình',
#  'môn_học chưa thực_tiễn chưa thu_hút sinh_viên',
#  'dạy hơi nhanh',
#  'ít làm bài tập',
#  'giảng bài kém thu_hút vị_trí đứng giảng không hợp_lý ôn_tập cuối kỳ còn chưa tập_trung vào vấn_đề',
#  'giảng_viên nhiệt_tình bài_giảng thu_hút',
#  'nhờ thầy và giảng_viên lý_thuyết em đã hiểu rõ về môn này rất nhiều',
#  'môn này khá trừu_tượng nên mong thầy có nhiều liên_tưởng tới thực_tiễn hơn để chúng_em có_thể hiểu',
#  'cần thêm nhiều tài_liệu cho sinh_viên',
#  'bài tập trên lớp',
#  'tăng số tiết dạy lên để sinh_viên có nhiều cơ_hội hỏi đáp thắc_mắc về môn_học',
#  'thầy nhiệt_tình dễ hiểu',
#  'thực_hành và lý_thuyết nên dạy song_song',
#  'giảng_viên dạy nhanh',
#  'bài tập trên lớp nên được giới_thiệu ngay từ đầu tiết học để học_sinh không tốn thời_gian đọc đề cũng như có_thể suy_nghĩ cách giải cùng lúc với việc nghe giảng',
#  'giảng_viên cho bài_tập hay',
#  'cập_nhật bài_tập mới',
#  'lên lớp ai làm_việc người ấy thầy không có giảng gì thêm',
#  'tận_tâm nhiệt_tình quan_tâm đến sinh_viên',
#  'phản_hồi giải_đáp thắc_mắc cho sinh_viên',
#  'dạy quá nhanh',
#  'mong ban thiết_bị sớm khắc_phục ạ',
#  'môn này cần làm đề_tài để áp_dụng lý_thuyết vào thực_tiễn mà trên lớp chỉ học một đống lý_thuyết và hiếm ai nhớ đa_số khá buồn_ngủ khi lên lớp',
#  'giảng_viên nên đổi_mới phương_pháp giảng_dạy tránh thô cứng không hấp_dẫn sinh_viên',
#  'nhiệt_tình tạo cách chủ_động cho học_sinh tiếp_cận với môn_học và tham_gia các chương_trình phong_trào liên_quan để nâng cao kỹ_năng',
#  'cô dạy rất tận_tình dễ hiểu',
#  'không đáp_ứng được nhu_cầu của sinh_viên',
#  'thầy rất nhiệt_tình với chúng_em và điều này làm em rất hài_lòng',
#  'cách giảng_dạy của thầy rất hay và có phần dễ hiễu',
#  'nhiệt_tình dễ_thương',
#  'không hướng_dẫn đồ_án',
#  'em xin đề_nghị nhà_trường nên bổ_sung tài_liệu về môn_học và cập_nhật nội_dung',
#  'chép bài rất nhiều lãng_phí thời_gian nghe giảng',
#  'em không học thầy wzjwz178 kỳ này giáo_viên thực_hành có 2 người nên có_lẽ daa nhầm',
#  'đề thi môn dài sinh_viên làm không đủ thời_gian',
#  'cho làm nhiều bài test',
#  'theo em thì nên thi phòng máy nào có visual 2013 trở lên',
#  'cần thêm nhiều tài_liệu cho môn_học',
#  'thầy giảng_dạy tốt',
#  'mong thầy có_thể hướng_dẫn cách cụ_thể nhất cho những bài khó',
#  'thầy cần cho bài_tập và hướng_dẫn nhiều hơn',
#  'giáo_viên lên_lớp đúng giờ giảng bài sôi_động',
#  'em thấy thầy chỉ giảng cho có',
#  'cần xác_định rõ mục_đích môn_học và cho sinh_viên đề_cương chi_tiết môn_học trước khi bắt_đầu',
#  'thầy nói_chuyện với sinh_viên rất tự_nhiên chia_sẻ kinh_nghiệm thực_tế',
#  'dạy theo sát chương_trình',
#  'cung_cấp thêm trang_thiết_bị phục_vụ nhu_cầu môn_học',
#  'đề_nghị nâng_cấp phòng lab khoa mạng',
#  'thầy giảng hay và tâm_huyết bài giảng có tính thực_tiễn cao',
#  'đi dạy đúng giờ',
#  'thầy cung_cấp nhiều kiến_thức mới thầy dạy tận_tâm và nhiệt_tình',
#  'có tăng thêm nhiều ví_dụ để minh_họa cho lý_thuyết vì có nhiều phần lý_thuyết rất trừu_tượng',
#  'các yêu_cầu về đồ_án môn_học nên đươc đưa ra chính_xác trước khi sinh_viên bắt_đầu thực_hiện chia nhóm và làm đồ_án',
#  'dạy dễ hiểu dễ tiếp_thu tập_trung vài kiến_thức trọng_tâm',
#  'dạy chưa được kỹ lắm điểm nên thoáng hơn',
#  'chưa chuẩn_bị kỹ bài giảng để có_thể trả_lời các thắc_mắc của sinh_viên trên lớp',
#  'cô khá tận_tâm cho học_sinh',
#  'cần cải_cách lại nội_dung các bài thực_hành một_số kiến nội_dung trong bài thực_hành đã trở_nên lỗi_thời',
#  'giảng_viên có khả_năng truyền_đạt kiến_thức tốt',
#  'cho làm nhiều bài tập',
#  'nghiên_cứu khoa_học',
#  'giáo_viên dạy rất tận_tâm nhiệt_tình',
#  'thầy cô hướng_dẫn đồ_án hệ_thống thông_tin cần có thêm một_vài buổi gặp_mặt với sinh_viên và đưa ra lịch cố_định trên trường để sinh_viên thắc_mắc có_thể lên hỏi trực_tiếp',
#  'chỉ thông_báo trên lớp sẽ khó tránh sai_sót',
#  'cô viết ở góc bảng gần chổ bụt giảng khiến nhiều khi khó quan_sát được ạ',
#  'đề_nghị lắp thêm quạt',
#  'dạy kỹ',
#  'bài tập cần đa_dạng hơn',
#  'nói rất nhỏ',
#  'có lúc làm bài sai giáo_viên nói làm hơi tự_ái',
#  'không sửa các bài_tập thực_hành',
#  'em chưa hiểu rõ cách_thức chấm điểm bài kiểm_tra thực_hành',
#  'làm bài tập nhiều mặc_dù không hiểu lắm',
#  'thi_thoảng nghỉ học không thông_báo trên daa',
#  'thầy dạy dễ hiểu tiết học dễ hiểu sôi_nổi',
#  'thầy giảng_dạy nhiệt_tình truyền_cảm',
#  'giảng_dạy rất chi_tiết dễ hiểu và dễ tiếp_thu',
#  'truyền_đạt những kiến_thức tốt',
#  'cô vui_tính',
#  'nếu có thì chỉ hướng_dẫn bằng lý_thuyết mà không làm bài tập mẫu cho sinh_viên',
#  'cô chưa có nhiều kênh bài_tập cho sinh_viên',
#  'bạn nào khá thì có_thể áp_dụng công_thức vào bài_tập cả lớp chưa đến 30 còn thực_sự hiểu môn_học thì rất ít người hiểu',
#  'thầy dạy hơi nhanh',
#  'ít hướng_dẫn sinh_viên trong giờ thực_hành',
#  'không thực_hành được buổi nào',
#  'thầy dạy phần lý_thuyết hay nắm_bắt được khả_năng của sinh_viên',
#  'ví_dụ đề_tài của em là doubledot các nguyên_lý cơ_bản bao_gồm 7 nguyên_tắc của bohm 1983',
#  'giáo_viên nhiệt_tình dạy dễ hiểu tận_tình với sinh_viên',
#  'tân tâm nhiệt_tình trong lớp lẫn bên ngoài',
#  'thầy giảng_dạy tận_tâm nhiệt_tình',
#  'thầy vui_tính giảng bài dễ hiểu nhiệt_tình',
#  'thầy_giáo dạy nhiệt_tình',
#  'dạy dễ hiểu gần_gũi sinh_viên',
#  'cô dạy rất nhiệt_tình và tài_liệu của cô rất cụ_thể dễ hiểu cô hướng_dẫn rất tận_tình',
#  'mong thầy cố_gắng trong các học_kỳ sau',
#  'cần đưa ra nhiều ví_dụ minh_họa hơn',
#  'giảng_viên hoà_đồng vui_vẻ chỉ giảng tận_tình sinh_viên ham học_hỏi',
#  'giảng_viên không dạy một tiết_thực_hành nào',
#  'không',
#  'nên có sự thống_nhất giữa các giảng_viên bộ_môn trong đề_cương giảng_dạy',
#  'có những phần kiến_thức chỉ một nửa lớp được học nhưng giảng_viên nghĩ là cả lớp đã học rồi nên chỉ overview những sinh_viên còn lại khó nắm được',
#  'máy_tính cập_nhật nhanh hơn',
#  'vui hòa đồng_nhiệt_tình',
#  'có giúp_đỡ sinh_viên học_tập nghiên_cứu',
#  'giảng_viên tận_tâm nhiệt_tình ham học_hỏi',
#  'tuy_nhiên cô nên cân_nhắc lại về số_lượng yêu_cầu đối_với sinh_viên để sinh_viên không bị khớp vì quá nhiều dẫn đến làm qua_loa cho có như vậy thì kết_quả lại không tốt',
#  'cô rất tận_tâm rất ok em rất thích cách dạy và học của cô mặc_dù hơi nhanh tí',
#  'mong thầy và nhà_trường xem_xét lại những điều em vừa nói',
#  'thầy tận_tâm nhiệt_tình tạo động_lực cho sinh_viên',
#  'thầy_giáo tận_tình dạy kỹ thường đưa ra câu hỏi để xem_xét mức_độ hiểu_biết của sinh_viên',
#  'cần tăng cương trao_đổi giữa sinh_viên và giáo_viên',
#  'nói_chung là nghe không bao_giờ nghe rõ được',
#  'cách truyền_đạt của giáo_viên chưa có sức hút đối_với sinh_viên nhiều cho lắm',
#  'cô_giáo thân_thiện dễ gần thực_hành nhiều',
#  'chưa tiếp_thu trọn_vẹn',
#  'cần cải_tiến trang thiết_thực_hành',
#  'giảng kỹ hơn',
#  'còn hơi kéo thời_gian',
#  'có nhiều bài tập về nhà cơ_bản lẫn nâng cao và giảng_viên sửa bài đủ',
#  'thầy rất hiền và kiên_trì giảng_dạy cho lớp mặc_dù môn_học này đối_với em không được hứng_thú lắm',
#  'đôi lúc giảng bài hơi nhanh',
#  'có một_số buổi không đi dạy',
#  'thầy nhiệt_tình và dạy dễ hiểu',
#  'có kiến_thức nền_tảng này sinh_viên có_thể học thêm bất_kỳ_công_nghệ cụ_thể nào đó dễ_dàng cũng như tiếp_thu thay_đổi công_nghệ mới nhanh_chóng',
#  'cấu_trúc đề_cương của thầy chưa rõ_ràng lý_thuyết chưa được trình_bày rõ trong các buổi học',
#  'tài_liệu hỗ_trợ toàn tiếng anh rất khó học',
#  'chưa nhận được gì từ môn_học này',
#  'giảng_viên không hề giảng_dạy chỉ đưa đề_cương rồi thôi',
#  'bài tập mỗi tuần đều có và đầy_đủ',
#  'em xin cảm_ơn',
#  'thầy cần phải cho sinh_viên biết được học môn này có tác_dụng gì và làm được gì khi học xong',
#  'đề_nghị tăng thời_gian thưc hành',
#  'không được làm những chuyện riêng trong lúc dạy thực_hành',
#  'hỗ_trợ thêm giáo_trình không phải slide cho sinh_viên',
#  'cô wzjwz259 rất vui và nhiệt_tình',
#  'giáo viện nhiệt_tình tận_tâm',
#  'kiến_thức được giảng_viên trình_bày rõ_ràng dễ hiểu cho sinh_viên',
#  'cần thêm nhiều kit để thực_hành',
#  'dạy khó hiểu quá nhanh',
#  'luôn gần_gũi tham_khảo ý_kiến sinh_viên và thống_nhất cũng sinh_viên',
#  'sắp_xếp lịch học bù chưa hợp_lý',
#  'nhà_trường nên đưa môn_học này vào thời_khóa_biểu bắt_buộc ở học_kỳ 1 của các sinh_viên năm nhất nhằm giúp các em nắm biết được mình nên học gì mình có nên chuyển_đổi ngành hay không',
#  'thời_gian thực_hành cần nhiều hơn',
#  'giảng_viên rất nhiệt_tình trong giảng_dạy',
#  'slide chuẩn_bị chưa tốt',
#  'thầy hay đòi_hỏi sinh_viên những điều hơi quá cao',
#  'cô giảng hướng_dẫn_nhiệt_tình',
#  'chúng em đã gặp khó khắn với khổ giấy nhỏ mô_hình thì lớn và phức_tạp',
#  'giảng quá nhiều không đánh vào trọng_tâm',
#  'em không muốn nói gì nhưng mong thầy xem lại cách đánh_giá sinh_viên để công_bằng hơn cái sinh_viên không biết không phải chỉ ở cúp tiết mà_còn ở cách giảng_dạy truyền_đạt ở giảng_viên ví_dụ như cô wzjwz324 rất dễ hiểu tận_tâm',
#  'cô có nhiều hình_thức giảng_dạy hay',
#  'hơi khó',
#  'thầy đi trễ',
#  'giảng tốt',
#  'nói mở_rộng nhiều vấn_đề về môn_học',
#  'cần tăng_cường nội_dung nghe và nói để sinh_viên giao_tiếp tốt hơn bằng tiếng anh',
#  'giảng_viên tạo điều_kiện làm nhiều bài tập',
#  'hỗ_trợ thêm về các thiết_bị dạy và học',
#  'ít giải bài_tập trên lớp',
#  'chia_sẻ',
#  'bám sát nội_dung chính',
#  'cần thêm các đoạn code cho các giải_thuật bổ_sung các phương_pháp để giải_quyết các bài_toán liệt_kê',
#  'thông_tin đầy_đủ về bài_tập và các nguồn tham_khảo',
#  'cô tận_tâm nhiệt_tình phương_pháp dạy dễ hiểu',
#  'thầy giảng rất dễ hiểu và thú_vị thu_hút',
#  'hướng_dẫn chi_tiết về cách thực_hành',
#  'giảng_viên chỉ cho đồ_án và giải_đáp các yêu_cầu đồ_án không cung_cấp tài_liệu hay hướng_dẫn cơ_bản sinh_viên tự tìm_hiểu với lý_do là hệ tài_năng nên cần tự xoay sở',
#  'môn_học toàn kiến_thức mới_mẻ giảng_viên nên giảng chi_tiết hơn',
#  'đến khi cuối kỳ chỉ cần sinh_viên mắc một sai_sót nhỏ thì sẽ rớt môn',
#  'cần thay_đổi cách dạy và nội_dung học của phần thực_hành các bài thực_hành hiện_tại của môn mạng máy_tính chưa đảm_bảo hiệu_quả',
#  'thầy dạy hay tận_tình góp_ý từng bài',
#  'cơ_sở_vật_chất phỏng máy không đủ phích cắm cho dụng_cụ thực_hành và số_lượng sinh_viên máy còn tiềm_ẩn nhiều virus',
#  'trên lớp lý_thuyết giảng_viên yêu_cầu sinh_viên phải thực_hiện đồ_án theo những gì mình hướng_dẫn những nhóm sinh_viên bổ_sung thêm những liên_hệ thực_tiễn đều bị cho là sai không phù_hợp với đồ_án',
#  'thầy giảng bài hay và hiệu_quả',
#  'giảng_viên nhiệt_tình vui_vẻ',
#  'phòng học nên có rèm che sáng để khi chiếu slide được nhìn rõ hơn',
#  'chương_trình dạy lý_thuyết và thực_hành nên khớp với nhau hơn tránh tình_trạng thực_hành trước khi học lý_thuyết',
#  'thầy giảng_dạy nhiệt_tình dễ hiểu',
#  'mong giảng_viên ngày_càng chấn_chỉnh việc dạy_học để các khoá sau được hiểu tốt hơn',
#  'thầy dạy rất có tâm và giảng cho sinh_viên rất nhiều thứ',
#  'nội_dung khảo sat quá dài nhiều mục lặp đi lặp lại nhiều bạn khảo_sát mà không cần đọc toàn tích chàn',
#  'dạy tốt và rất nhiệt_tình chỉ dạy hoc sinh',
#  'nhiệt_tình tân tâm',
#  'nhưng học mới thấy kiến_thức thầy dạy rất hay bám sát thực_tế thầy dạy rất nhiệt_tình vui_vẻ khác với mọi người nói',
#  'bài tập rất hay',
#  'thầy cô cần cho nhiều dạng bài tập sát với đề thi hơn',
#  'thầy giảng hay nhưng nên tự_tin hơn nói to hơn để học_sinh hiểu bài một_cách rõ_ràng hơn',
#  'mong thầy vui_tính gần_gũi với sinh_viên hơn',
#  'giáo_viên vui_tính hòa đồng_nhiệt_tình',
#  'cung_cấp kiến_thức trọng_tâm',
#  'cố_gắng truyền_đạt một_cách tốt nhất để sinh_viên được hiểu',
#  'giọng của giảng_viên nhỏ dù đã sử_dụng micro',
#  'dù phương_pháp_học_tập này khá hiệu_quả nhưng vẫn có chút nào đó nghi_ngờ từ phần thuyết_trình của các bạn liệu các kiến_thức đó có chuẩn_xác và cập_nhật chưa',
#  'giáo_viên có phong_cách giảng_dạy nghiêm_túc',
#  'cô rất vui_tính nà không_khí lớp lúc_nào cũng vui hết cô dạy rất hay dễ hiểu',
#  'giảng_viên giảng_dạy rất tốt thường_xuyên cung_cấp thêm nhiều kiến_thức',
#  'thầy luôn nhiệt_tình có những chia_sẻ rất gần_gũi với sinh_viên',
#  'có khả_năng truyền_đạt tốt',
#  'thậm_chí còn không có bài nào khó bằng các bài trong nội_dung của lớp chuyên tin ở các trường cấp 3',
#  'thầy dạy tận_tụy và tâm_huyết',
#  'thầy nên có cách dạy mới cho môn_học này để được kết_quả tốt cho tất_cả mọi người thay_vì để rớt rất nhiều người',
#  'lịch thi thực_hành cần được thông_báo sớm tới sinh_viên và phù_hợp với thời_gian môn_học',
#  'cô nên giảng kỹ và chi_tiết từng bài vì nhiều bài đa_số các bạn chưa hiểu thì cô lại giảng nhanh để chuyển qua bài khác',
#  'dạy tốt đúng trọng_tâm những gì cần biết',
#  'nhiệt_tình lên_lớp đúng giờ dạy dễ hiểu',
#  'nếu em buồn_ngủ dù lên_lớp em vẫn sẽ ngủ mà ngủ ở trên lớp thì đau_lưng và tê chân lắm',
#  'cơ_mà em học môn này em hiểu colonlove',
#  'thiếu kinh_nghiệm truyền_đạt',
#  'bài giảng thú_vị',
#  'em nghĩ nội_dung thực_hành nên gần với đồ_án hơn',
#  'thầy nhiệt_huyết và giảng bao_quát đề_cập đến nhiều khía_cạnh của bài_học vấn_đề',
#  'giảng_viên giảng bài kỹ',
#  'hệ_thống đồ_án chấm điểm theo mức_độ hoàn_thành của sinh_viên tạo sự ganh_đua không hề nhẹ với những nhóm làm chung đồ_án kích_thích sáng_tạo không ngừng tìm_hiểu xây_dựng thêm chức_năng mới cho đồ_án nếu muốn được điểm cao',
#  'nhiệt_tình tâm_huyết',
#  'ít chú_trọng phần ngữ_pháp',
#  'giảng_viên còn chưa tận_tâm phong_cách giảng_dạy chưa thu_hút được sinh_viên',
#  'giảng rất dễ hiểu hướng_dẫn làm thực_hành tốt',
#  'thầy dạy rất nhiệt_tình khi dạy thầy luôn đi tới từng sinh_viên để hướng_dẫn',
#  'giảng_viên nhiệt_tình trong giảng_dạy và chấm điểm',
#  'cách truyền_đạt kiến_thức đối_với em là rất hiệu_quả trao_đổi bài với sinh_viên cô rất nhiệt_tình',
#  'giảng_dạy hay dễ hiểu tận_tình',
#  'kiến_thức rộng kinh_nghiệm thực_tế nhiều truyền_cảm_hứng cho sinh_viên',
#  'cách dạy sáng_tạo',
#  'giảng bài dễ tiếp_thu',
#  'em rất hài_lòng với cô',
#  'thầy dạy dễ hiểu sinh_động',
#  'cô chưa nắm_bắt được thực_trạng học của sinh_viên',
#  'ảnh_hưởng đến tiến_độ học_tập và quỹ thời_gian của sinh_viên do học bù',
#  'cô giảng bài dễ hiểu',
#  'điều em hài_lòng nhất đó là thầy đi rất đúng giờ và không dạy quá nhanh',
#  'nên có giáo_trình thống_nhất cho tất_cả các lớp và học_kỳ học',
#  'em nghĩ cần có các bài_tập lớn để nâng cao khả_năng lập_trình của các sinh_viên',
#  'rất nhiệt_tình với sinh_viên',
#  'giảng_viên có phương_pháp giảng_dạy hay cập_nhật phù_hợp với sinh_viên',
#  'giảng_dạy tốt và có tâm',
#  'dạy lý_thuyết hơi nhiều',
#  'giảng_viên chấm_bài quy_chụp theo kết_quả',
#  'thời_lượng môn_học quá dài sinh_viên cảm_thấy mệt_mỏi',
#  'giảng_viên vui_tính dễ tương_tác với sinh_viên',
#  'nhiệt_tình hay giúp_đỡ sinh_viên khi không biết cho nhiều bài tập',
#  'thầy cho điểm phần_nào còn theo cảm_tính chưa được công_bằng',
#  'thầy giảng_dạy rất nhiệt_tình',
#  'thầy nhiệt_tình bài_giảng phong_phú đa_dạng',
#  'không có gì đặc_biệt',
#  'mỗi tháng chỉ gặp giảng_viên một lần rất khó cho việc học_hỏi hướng_dẫn từ giáo_viên',
#  'thầy nên chuẩn_bị riêng một slide cho mình để giảng_dạy không nên lấy slide của người khác rồi đến khi sơ_sót thầy lại lấy cái lý_do đây không là slide của tôi cái này tôi cũng không rõ nữa',
#  'thầy cho làm các bài_tập tại lớp trong khi sinh_viên chưa biết gì về vấn_đề đó',
#  'đôi khi đi quá sâu vào một vấn_đề bên lề',
#  'giảng_viên dạy tận_tâm nhiệt_tình dễ hiểu',
#  'cô thật nhiệt_tình',
#  'phòng thực_hành tốt',
#  'nói_chuyện lan_man không liên_quan đến môn_học quá nhiều',
#  'giảng_viên rất tận_tâm',
#  'phân_bổ hợp_lý thời_gian học và nên cho xem nhiều video hơn là nghe',
#  'thầy bận nhiều nên cũng nghỉ nhiều hi_vọng thầy có_thể sắp_xếp thời_gian',
#  'giáo_viên sử_dụng giờ trên lớp hiệu_quả',
#  'giáo_viên tận_tình dạy truyền_đạt tốt',
#  'giảng_viên dạy tốt nhiệt_tình',
#  'giảng_viên tạo cảm_hứng cho sinh_viên học_tập',
#  'chán',
#  'thầy nhiệt_tình tận_tâm giúp_đỡ sinh_viên',
#  'dạy quá chậm quá cặn_kẽ',
#  'thầy wzjwz174 ít cho bài_tập về nhà',
#  'thầy đôi_khi nói hơi khó hiểu',
#  'giảng_viên tận_tâm nhiệt_tình hỗ_trợ giải_đáp thắc_mắc môn_học cho sinh_viên',
#  'nên đi sâu vào vấn_đề giúp sinh_viên hiểu tốt môn_học và nên có những ứng_dụng cụ_thể mà môn_học đem lại',
#  'làm bài tập',
#  'cứ ngỡ được 10 điểm là chắc_chắn rồi',
#  'thầy yêu_cầu quá cao đối_với một sinh_viên có_thể tiếp_thu mọi kỹ_năng cần truyền_đạt vào một đồ_án',
#  'thêm phòng thiết_bị để thực_hành',
#  'dễ hiểu đầy_đủ',
#  'điểm',
#  'giáo_viên tốt_bụng vui_tính',
#  'slide quá khó hiểu nhiều chỗ không giải_thích rõ_ràng đặc_biệt là các bài hướng_dẫn thực_hành',
#  'nói rõ mục_tiêu cũng như các bước làm của lab khối_lượng bài_tập vừa phải',
#  'giải_đáp kịp_thời những thắc_mắc cho sinh_viên',
#  'giảng_viên nhiệt_tình phương_pháp dạy dễ tiếp_cận dễ hiểu',
#  'phòng học cần lắp thêm quạt và ổ_cắm vì sinh_viên phải sử_dụng laptop để làm bài tập cần có thêm màn che cửa_sổ để có_thể theo_dõi bài_giảng trên slide tốt hơn',
#  'bài tập không cho ví_dụ về nhà để xem lại',
#  'giảng_viên thiếu rất nhiều hoạt_động để việc học bớt nhàm_chán khi quá bám sát bài_học',
#  'thầy dạy dễ hiểu rất hài_lòng',
#  'micro và các thiết_bị âm_thanh máy chiếu cần nâng_cấp',
#  'cách giảng bài dễ hiểu hay',
#  'đầy_đủ kiến_thức',
#  'chất_lượng phòng máy rất tệ',
#  'thầy giảng ngắn_gọn đầy_đủ',
#  'tốt giỏi chu_đáo',
#  'tuy có phần chém gió kinh_điển nhưng kiến_thức hiểu_biết rộng đặc_biệt về công_nghệ',
#  'chờ học_sinh gửi email mới show được slide to lên giảng cho qua loa không hỏi học_sinh có hiểu gì hay không',
#  'tạo niềm vui cho bọn em tuy lý_thuyết bọn em rất đuối sức',
#  'nhiệt_tình truyền_cảm_hứng',
#  'thầy hài_hước giọng truyền_cảm',
#  'thầy dạy rất nhiệt_tình tâm_huyết dễ hiểu',
#  'không hiểu cách chấm bài thi của thầy',
#  'tiết học chưa được thu_hút',
#  'giảng_viên nên thay_đổi phương_pháp giảng_dạy để tương_tác nhiều hơn với sinh_viên',
#  'cần vào thẳng nội_dung',
#  'thầy đẹp_trai dạy dễ hiểu hay trò_chuyện thực_tiễn với học_sinh',
#  'cô dạy trên lớp và thực_hành tận_tâm',
#  'em rất hài_lòng về thầy',
#  'thầy quá bảo_thủ thầy luôn cho rằng ý_kiến của thầy là đúng nhất ngoài_ra mọi ý_kiến khác đều sai',
#  'thầy wzjwz252 giảng bài rất thu_hút kiến_thức thầy rất rộng luôn giải_đáp thắc_mắc cho sinh_viên',
#  'giảng_viên rất hòa_đồng vui_vẻ nhiệt_tình trong giảng_dạy',
#  'giảng_viên tận_tâm tạo điều_kiện cho học_sinh làm bài tập',
#  'cần giải bài_tập nhiều hơn',
#  'kiến_thức thực_tiễn của thầy rộng giảng_dạy vui_vẻ',
#  'cô cũng không cung_cấp hay giải_thích gì đáp_án của bài thi',
#  'thầy rất nhiệt_tình nói rất nhiều đến khản giọng mà sức truyền_tải không bằng thầy wzjwz159',
#  'kiến_thức giảng_dạy môn tiếng anh hầu_như không giúp_ích nhiều cho sinh_viên trong việc tìm_hiểu các tài_liệu chuyên_ngành',
#  'thấy rất hiền rất chi là_hơi trẻ_con',
#  'giảng_dạy hay dễ hiểu cuốn_hút sinh_viên',
#  'cách tìm_kiếm chúng ở đâu khai_thác chúng ở đâu chứ không phải là phải nhớ mấy cái phương_thức hay các hàm rồi viết lên giấy vào đề thi cuối kỳ',
#  'giảng hơi nhanh chưa kỹ lắm',
#  'những phần trọng_tâm bài_tập thì cũng không nói được đây là phần quan_trọng có trong đề thi các em cần chú_ý',
#  'nghe nói luyện_tập cao',
#  'giáo_viên giảng hay dễ hiểu',
#  'sử_dụng phần_mềm crack',
#  'nhiều khi dạy quá thời_gian',
#  'tuy dạy chậm giúp học_sinh dễ hiêu tuy_nhiên nhiều bài khó thì sẽ khiến sinh_viên dễ chán',
#  'thầy vui_tính thương_sinh_viên dạy dễ hiểu',
#  'thầy bằng nhiệt_tình tận_tụy với sinh_viên trong việc hướng_dẫn đồ_án',
#  'dạy dễ hiểu thân_thiện',
#  'có các phần ôn_tập không liên tới bài kiểm_tra',
#  'không nên tổ_chức thực_hành hình_thức 2',
#  'sự thân_thiện và tận_tình đối_với học_viên',
#  'thầy giảng bài nhiệt_tình gần_gũi với sinh_viên nội_dung không hiểu có_thể hỏi ngay thầy tại lớp',
#  'giảng_viên cần nắm vững xem sinh_viên có hiểu được bài hay không và đưa ra phương_án để sinh_viên nắm vững kiến_thức',
#  'thầy thiện nhiệt_tình',
#  'truyền_đạt thực_tiễn vấn_đề',
#  'giáo_viên rất nhiệt_tình và tâm_huyết đối_với sinh_viên',
#  'âm_thanh thầy giảng hơi nhỏ khó_khăn trong việc nghe giảng',
#  'nên thay_đổi hình_thức khảo_sát với môn_học này thì môn_học này không có lên_lớp và chỉ có đến hạn thì báo_cáo với giảng_viên',
#  'sinh_viên hỏi nhận câu trả_lời cũng như không hỏi',
#  'thầy dạy khá nhiệt_tình vui_tính',
#  'em nghĩ chỉ nên bắt_buộc các bài_tập có dạng căn_bản còn bài_tập tương_tự thì chỉ khuyến_khích sinh_viên làm thêm',
#  'thầy dạy rất hay ạ',
#  'không thống_nhất trước về hình_thức thi và làm bài tập đến những tuần cuối_cùng mới công_bố',
#  'nhằm giảm thời_lượng giảng_dạy cũng như sự thú_vị khi học môn toán',
#  'giảng_viên dạy nhiệt_tình dễ hiểu',
#  'em mong cô cũng như toàn_thể các giảng_viên hãy xem_xét lại việc điểm_danh vì đại_học dù_sao cũng là tự học chứ không phải như là phổ_thông nữa',
#  'cô cực_kỳ nhiệt_huyết cô rất dễ_thương colonlove cô yêu học_trò của mình cô cực_kỳ khách_quan phong_cách làm_việc của cô rất giống người nước_ngoài em thích cô',
#  'giảng_viên nhiệt_tình tận_tâm với công_việc slide dễ hiểu hoạt_động học_tập sôi_nổi',
#  'chú_ý giữ sức_khỏe nhất là cổ_họng colonsmile',
#  'thầy tận_tâm nhiệt_tình',
#  'máy ở phòng thực_hành quá tệ',
#  'thầy rất dễ_thương',
#  'giảng_viên nhiệt_tình thân_thiện',
#  'thầy truyền_đạt rất tận_tình dễ hiểu lượng bài_tập nội_dung thi hợp_lý vừa_sức với sinh_viên',
#  'giảng_viên nên đến đúng giờ hơn và cho nhiều bài_tập hơn',
#  'em thấy những nội_dung như_vậy rất mơ_hồ có tính áp_đặt suy_nghĩ cho người học',
#  'cần nâng_cấp máy_tính trong phòng thực_hành nhiều kit de2 bị lỗi cần sửa_chữa hoặc thay mới',
#  'em thấy môn này nhiều lý_thuyết không đáp_ứng đủ trong việc_làm đồ_án',
#  'tạo điều_kiện cho sinh_viên làm_việc nhóm',
#  'phương_pháp dạy chưa hay',
#  'hay bị về trễ colonsad',
#  'cần dạy chi_tiết hơn',
#  'cô giảng rất nhiệt_tình',
#  'dạy rất chi_tiết và đầy_đủ những kiến_thức quan_trọng',
#  'đề thi thực_hành cần nêu yêu_cầu cụ_thể rõ_ràng hơn',
#  'giọng của giảng_viên rất khó nghe nên không_thể nghe giảng hết những điều thầy nói',
#  'giảng_dạy hay nhiệt_tình',
#  'giảng_viên biết cách truyền_đạt giảng rất hay và dễ hiểu',
#  'dạy hơi nhiều và hơi nhanh',
#  'nên tạo không_khí thoải_mái cho tiết học để sinh_viên dễ hiểu bài và thêm yêu_thích môn_học của giảng_viên',
#  'giảng_dạy tận_tâm',
#  'cả năm toàn học vòng lặp if for while đến bữa cuối mới lơ_mơ học được struct với tạo file header mà ra đề 5 điểm trong phần đó',
#  'gần_gũi thân_thiện với sinh_viên khả_năng truyền_đạt kiến_thức tốt',
#  'quá dễ dẫn đến buồn_ngủ',
#  'giảng_viên không có tính hài_hước',
#  'vui_tính nhiệt_tình',
#  'thầy vui_tính giảng bài hay đưa nhiều thông_tin thực_tế vào bài giảng',
#  'thẩy wzjwz311 rất vui và nhiệt_tình',
#  'giáo_viên giảng_dạy lôi_cuốn',
#  'nhiệt_tình dễ gần truyền_đạt tận_tâm',
#  'phương_pháp truyền_đạt của giảng_viên chưa hiệu_quả lắm',
#  'giáo_viên chưa tạo được không_khí vui_vẻ trong lớp_học',
#  'thầy giúp em biết mạch số là gì',
#  'có lúc thầy lạc_đề',
#  'thầy dạy hơi chậm',
#  'lần được học thầy thấm nhiều thứ quá',
#  'nhiều phần trong slide bài_giảng của giảng_viên không chính_xác',
#  'môn_học cần phân_chia hợp_lý giữa các phần phần_nào khó cần nhiều thời_gian để học nó phần_nào đã học thì chỉ ra những điểm đặc_biệt cũng như thời_gian học_phần đó rút ngắn lại để các phần chưa học khác sẽ có thời_gian nhiều hơn',
#  'thực_hành đúng tiêu_chí môn_học đi từ dễ đến khó cho sinh_viên học_tập từng bước dễ hiểu giảng_viên tích_cực giải_đáp thắc_mắc và hỗ_trợ sinh_viên trong giờ thực_hành',
#  'dạy dễ hiểu sâu_rộng',
#  'thầy dạy nhiệt_tình vui_vẻ',
#  'thầy cực_kỳ tâm_lý vui_tính dạy nhiệt_tình và tận_tụy với học_trò',
#  'thầy luôn chủ_động tạo tranh_luận và kiểm_tra bài_tập đầu giờ để sinh_viên dễ_dàng nắm_bắt kiến_thức',
#  'nội_dung tiết học còn lan_man cảm_tưởng như thầy đang dạy về tiếng anh chuyên_ngành chứ không đào_sâu về kỹ_thuật',
#  'nên tự_tin hơn trong việc giảng_dạy',
#  'giảng_viên có cập_nhật thông_tin mới nhất về tình_hình thực_tế',
#  'giáo_viên rất nhiệt_tình đối_với sinh_viên',
#  'cảm_thấy hứng_thú khi lên lớp',
#  'cùng một kiến_thức nhưng cách truyền_đạt của thầy dễ hiểu hơn phù_hợp với đại_đa_số sinh_viên và tất_nhiên là hữu_dụng cho các môn khác chứ không hề lan_man thiếu trọng_tâm như các giảng_viên toán khác',
#  'giảng_viên chưa bám sát được sinh_viên',
#  'nhiều lúc thầy vẫn nói lý_thuyết nhiều gây nhàm_chán',
#  'phần kiểm_tra thi_cử đối_với môn này nên đề_cao tính tư_duy logic của người học cũng như khả_năng áp_dụng kiến_thức đã học vào thực_tế thực_nghiệm bằng cách chủ_yếu đánh_giá cao phần thực_hành viết code làm project',
#  'do môn còn mới nên nhiều vấn_đề trục_trặc trong quá_trình thực_hành thầy vẫn chưa giải_quyết được nhưng vẫn rất ủng_hộ thầy',
#  'luôn đảm_bảo giờ_giấc trong tiết học',
#  'phòng lab chán lắm hư_hỏng hết cả',
#  'nội_dung môn_học còn khô_cứng',
#  'cô nói hơi nhỏ nên hơi buồn_ngủ',
#  'có lúc dạy khó hiểu',
#  'thầy cho bài_tập lạ đa_dạng',
#  'sau khi đã học xong môn nhập_môn điện_tử em thiết_nghĩ môn_học này cần có thêm những phần học về thực_tế để sinh_viên chúng_em có thêm động_lực khi học những phần lý_thuyết đôi_khi khô_khan và xa_lạ đồng_thời sẽ tạo được sự đam_mê với bộ_môn điện_tử nói_chung ngay từ những ngày đầu học nhập_môn',
#  'giáo_viên vui_tính tích_cực',
#  'thầy dạy nghiêm_túc',
#  'cơ_sở dữ_liệu năm nay đã kết_hợp với thiết_kế cơ_sở dữ_liệu rồi kiến_thức nhiều mà thi có phần trắc_nghiệm nữa thì đánh_giá kiến_thức học được chưa đảm_bảo cho lắm ạ',
#  'nội_dung có liên_hệ nhiều với thực_tế',
#  'nhiệt_tình luôn_luôn giúp học_sinh hiểu vấn_đề cặn_kẽ',
#  'ra đề thì phải có đáp_án để sinh_viên tập dần thói_quen đọc code',
#  'em nghĩ là cần thêm bài_tập trên lớp và giải ngay trên lớp',
#  'môn_học chỉ nên thuyết_trình tìm_hiểu về egov không làm đồ_án',
#  'giảng_viên có nhiều phương_pháp giảng hay',
#  'thực_hành hình_thức 2 khó có_thể tham_gia học thường_xuyên lắm ạ',
#  'cô giảng rất hay rất nhiệt_tình khi giảng_dạy rất vui_tính',
#  'giáo_viên luôn chia_sẻ những ứng_dụng của kiến_thức đã học với thực_tiễn chia_sẻ khá nhiều kinh_nghiệm thực_tế vô_cùng bổ_ích với sinh_viên',
#  'thầy dạy nhiệt_tình rất chu_đáo',
#  'thầy dạy rất nhiệt_tình với sinh_viên',
#  'em thấy rất hài_lòng về môn_học này nên em không có ý_kiến gì khác cả',
#  'bàn_ghế còn bụi',
#  'cô vui_tính dạy tốt',
#  'nhiệt_tình giỏi hay giúp_đỡ sinh_viên và cho nhiều bài tập',
#  'kể chuyện hay',
#  'tôi đã thấy giảng_viên chỉ nhìn qua chưa đầy 30 giây và cho điểm 9 ngay_lập_tức',
#  'phòng thực_hành nên nâng_cấp máy_tính',
#  'thầy ít khi nhắc lại về_phần đã dạy hôm trước',
#  'thầy nên tham_gia thực_hành cùng sinh_viên không phải là chỉ ngồi một chỗ tụi em tự mày_mò làm xong rồi thầy mới xuống chấm điểm',
#  'mong_muốn giảng_viên nào cũng áp_dụng như vậy thì quá tốt',
#  'giảng_viên cần chuẩn_bị giáo_án trước khi đến lớp giảng_viên diễn_đạt không tốt cần phải học cách_diễn_đạt cho sinh_viên dễ hiểu',
#  'cần học môn lập_trình trực_quan trước',
#  'cách truyền_đạt kiến_thức kém hiệu_quả cô dạy giống như là không dạy chỉ đọc chữ trong slide rồi cho sinh_viên làm bài tập',
#  'làm tốn thời_gian truyền_đạt dẫn đến hứng_thú lên_lớp nghe giảng bị hạn_chế',
#  'thầy luôn tạo cơ_hội để sinh_viên có_thể được thực_hành',
#  'thêm phần anh văn chuyên_ngành vào nội_dung học',
#  'cảm_ơn cô và chúc cô nghỉ_đẻ vui_vẻ mẹ tròn con vuông',
#  'thầy dạy tốt giảng dễ hiểu',
#  'mở_rộng kiến_thức nâng cao cho sinh_viên',
#  'chưa có thời_gian cho sinh_viên ngẫm_nghĩ điều mình mới học mà đã qua nội_dung khác để theo kịp chương_trình',
#  'dạy dễ hiểu',
#  'thầy vui_vẻ thoải_mái',
#  'thầy tận_tâm dạy dễ hiểu vui_tính lớp_học thoải_mái dễ tiếp_thu',
#  'em thích học môn này với cô wzjwz157',
#  'cô tận_tình hướng_dẫn chỉ bảo',
#  'cập_nhật điểm thi giữa kỳ chậm nên sinh_viên không biết mức_độ phấn_đấu như thế_nào',
#  'giảng_dạy tận_tâm nhiệt_tình dễ hiểu',
#  'đôi khi trong giờ học kể vài chuyện về đời để đỡ chán',
#  'thầy không vui_tính',
#  'giảng nhiều phần nâng cao làm sinh_viên bối_rối',
#  'thầy dạy vui_vẻ',
#  'cô dạy dễ hiểu hỗ_trợ tốt cho các bạn',
#  'thời_gian nộp bài tại lớp hơi ngắn',
#  'cần có sách học hay chi_tiết hiệu_quả colonsmilesmile',
#  'phương_pháp giảng_dạy còn khó hiểu',
#  'tận_tình chu_đáo',
#  'nội_dung lý_thuyết và thực_hành của môn_học không có bất_kỳ liên_hệ gì với nhau nội_dung lý_thuyết không phù_hợp với môn_học và không tạo được sự quan_tâm và mong_muốn của sinh_viên về kiến_thức quản_trị mạng như mong_đợi',
#  'cần có khả_năng truyền_đạt tốt hơn',
#  'giảng_viên dạy có hiệu_quả cao mang tính thực_tiễn',
#  'giáo_viên truyền_đạt kiến_thức đầy_đủ dễ hiểu nhiệt_tình giảng_dạy',
#  'em xin_lỗi nhưng đó là sự_thật',
#  'cô tận_tâm hỗ_trợ nhiệt_tình',
#  'không có giáo_trình',
#  'phương_pháp tư_duy cho sinh_viên để sinh_viên tự giải_quyết các vấn_đề',
#  'giảng_dạy dễ hiểu linh_động trong nhiều bài tập',
#  'giảng_viên giảng_dạy tận_tình vui_vẻ giúp học_viên nhận_thức được nhiều kiến_thức',
#  'cải_thiện chất_lượng phòng máy thực_hành',
#  'nếu được chọn cô luôn là lựa_chọn hàng_đầu cho các môn kinh_tế',
#  'cần thêm bài_tập và rèn_luyện kỹ_năng giao_tiếp',
#  'nhiệt_tình giảng_dạy',
#  'thoải_mái về thời_gian',
#  'em còn chưa thấy mặt thầy nữa hoặc có nhưng quên rồi colondoublesurprise',
#  'các nội_dung môn_học thầy triển_khai không đúng theo khung mới vào mà thầy dạy servlet thì rất khó hiểu sinh_viên có góp_ý qua thầy chủ_nhiệm nhưng vẫn không thay_đổi',
#  'mọi việc điều được sinh_viên tự học tự tìm_hiểu thông_qua các trang mạng thông_qua việc email trực_tiếp với giảng_viên',
#  'slide bài_giảng còn lẫn_lộn anh việt phần tiếng việt thì giảng_viên lại dùng google dịch nên đọc không hiểu',
#  'cách truyền_đạt tốt tận_tâm',
#  'cô rất nhiệt_tình và thân_thiện với sinh_viên',
#  'giảng_viên tận_tâm với việc dạy_học tạo cảm_hứng học_tập cho sinh_viên',
#  'cần cho nhiều thời_gian để sinh_viên có đủ thời_gian hoàn_thành đồ_án môn_học',
#  'thầy rất vui_tính truyền_tải thông_tin tuyệt_vời',
#  'đôi lúc hỏi một_số câu hỏi rất mơ_hồ khiến sinh_viên không biết đang được hỏi về khía_cạnh nào cũ hay mới chương trước hay chương hiện_tại',
#  'hy_vọng thầy sẽ cải_tiến làm cho hoạt_động sôi_nổi hơn',
#  'quá nhàm_chán không nâng cao được kiến_thức',
#  'thầy dạy khá nhiệt_tình vui_tính',
#  'thầy khá nhiệt_huyết và gần gủi với sinh_viên',
#  'bài tập khắt_khe',
#  'theo thời_khóa biểu hiện_nay thì học thực_hành trước nên sinh_viên lúc thực_hành chưa hiểu vấn_đề nên khó_khăn trong việc làm bài',
#  'cô nên tăng tốc_độ giải bài hơn',
#  'tài_liệu tiếng anh gây khó_khăn cho ôn thi',
#  'giảng_dạy tận_tình vui_vẻ',
#  'giảng_viên dạy có tâm_huyết kỹ càng với sinh_viên nhiệt_tình giúp_đỡ',
#  'khả_năng truyền_đạt kiến_thức không cao',
#  'cần nâng cao chất_lượng trang_thiết_bị',
#  'giảng_viên vui_tính thân_thiện',
#  'đầu_tư các thiết_bị cho sinh_viên mượn như điện_thoại android windows phone',
#  'thầy dạy tốt và tâm_huyết',
#  'việc phân_chia nhóm không hợp_lý dẫn tới chất_lượng học_tập không tốt',
#  'thầy nhiệt_tình vui_vẻ',
#  'tận_tâm nhiệt_tình giảng_giải cho sinh_viên chưa hiểu tỉ_mỉ',
#  'phần máy_tính không hỗ_trợ cho việc học nhiều chỉ làm sinh_viên phân_tán',
#  'sự nhiệt_tình tâm_huyết',
#  'đó là tiền của họ họ muốn dùng thì tùy họ người khác nghèo không phải lỗi của họ chưa kể tiền thuế họ đóng_góp cho nước cũng đủ để gọi_là xây_dựng rồi',
#  'các dạng bài_tập rõ_ràng tài_liệu cung_cấp đầy_đủ',
#  'giảng_viên dạy tận_tình cung_cấp đầy_đủ kiến_thức cho sinh_viên',
#  'cần tăng thời_gian học',
#  'nên tổ_chức thêm những buổi hội_thảo liên_quan đến nội_dung môn_học',
#  'dạy đúng trọng_tâm',
#  'đề_nghị thầy share slide giảng_dạy trên lớp',
#  'nên trang_bị trang_thiết_bị cho phòng thực_hành và phòng lab để sinh_viên có_thể thực_hành và học trực_tiếp trên thiết_bị thật',
#  'thầy giảng_dạy rất nhiệt_tình và vui_tính',
#  'nên cải_tiến hệ_thống chấm điểm online update bài_tập cho tất_cả học_sinh làm rồi có bảng xếp_hạng như bên codefun của miền bắc',
#  'bài giảng thực_tế',
#  'kiến_thức thầy dạy rất hay và bổ_ích',
#  'hạn_chế dạy bằng slide',
#  'nói sâu về vấn_đề khó',
#  'thầy lên_lớp không đúng giờ giấc thường_xuyên đi trễ',
#  'chất_lượng phòng máy kém',
#  'phong_cách giảng_dạy rất hay',
#  'giáo_viên giảng_dạy sử_dụng nhiều ví_dụ thực_tiễn',
#  'cần tuân_thủ đúng và đủ giờ',
#  'thầy rất nhiệt_tình và năng_động_học thầy có thêm nhiều kiến_thức mới không chỉ gói gọn trong nội_dung môn_học',
#  'thầy giảng bài kỹ dễ hiểu',
#  'nhiệt_tình giảng_dạy giải_đáp thắc_mắc rất chi_tiết cung_cấp đầy_đủ kiến_thức cần_thiết để kiểm_tra',
#  'thầy giảng nhanh và cách truyền_đạt hơi khó_hiểu đưa ra khá ít ví_dụ để sinh_viên có_thể hiểu bài rõ hơn',
#  'các giảng_dạy của giảng_viên còn khó hiểu rối_rắm',
#  'điện_thoại không liên_lạc được',
#  'chưa học nhiều với thầy nên chưa có ý_kiến gì về thầy',
#  'nội_dung thực_hành nên thay_đổi doubledot mỗi tuần thực_hành các phần lý_thuyết trên lớp và giảng_viên hướng_dẫn làm đồ_án cuối kỳ',
#  'giảng_viên tăng_cường giải đề của các năm',
#  'thiếu thiết_bị thật để thực_hành',
#  'nhiệt_tình giúp_đỡ sinh_viên',
#  'giảng bài rất dễ hiểu',
#  'thực_sự em vẫn chưa hiểu ngoài việc để làm bài tập thì wireshark được dùng để làm_việc gì khác',
#  'em nghĩ cơ_sở_vật_chất vẫn còn yếu_kém ngồi xa không_thể nhìn rõ được slide bài_giảng của cô_giáo phòng_học rất nóng',
#  'thầy giải nhiều bài tập cho sinh_viên giúp sinh_viên củng_cố kiến_thức sau khi học lý_thuyết',
#  'cô rất vui_vẻ nhiệt_tình tâm_huyết',
#  'cần có các thiết_bị di_động thật để sinh_viên thực_hành khi cần_thiết vì các chương_trình mô_phỏng trên máy_tính là không đầy_đủ',
#  'thầy dạy dễ hiểu code mẫu đầy_đủ',
#  'điều em hài_lòng nhất đó là thầy với tốc_độ phù_hợp và rất dễ hiễu',
#  'nên thống_nhất lại nội_dung môn_học so với cách thi của phòng đào_tạo',
#  'thầy dạy hay nhiệt_tình không bao chê_bai sinh_viên dù mặc_dù không tốt mà hướng sinh_viên đến suy_nghĩ tích_cực hơn cố_gắng hơn',
#  'giảng_dạy nhiệt_tình quan_tâm tới sinh_viên',
#  'cần tăng chú_ý về kỹ_năng cần_thiết trong toeic như nghe đọc',
#  'kính mong giảng_viên có_thể cho thêm nhiều bài_tập nhằm giúp sinh_viên luyện_tập nắm_bắt nội_dung môn_học và vận_dụng nó hiệu_quả hơn giúp_ích cho việc học các môn sau_này',
#  'cần chú_trọng hơn vấn_đề học thực_hành phòng máy không đáp_ứng yêu_cầu doubledot không có trình biên_dịch giáo_viên thực_hành không sử_dụng hiệu_quả giờ thực_hành',
#  'thầy wzjwz239 nói_chuyện cọc lốc không hiểu vấn_đề gì hỏi thầy thì thầy lại như quát vào mặt tạt nước lạnh … nói_chuyện xưng_hô mày_tao có lúc thì xưng tớ cậu nhưng lời_nói đầy ẩn_ý hay nói_móc và tìm cách bắt_bẻ sinh_viên',
#  'thầy có hướng_dẫn đồ_án rất tận_tình luôn giải_đáp các câu hỏi và thắc_mắc của sinh_viên về đồ_án rất nhanh',
#  'giúp sinh_viên cảm_thấy thoải_mái trong giờ học',
#  'cô giảng_dạy tận_tình',
#  'hơi khó_tính ạ',
#  'kiến_thức nhiều khó tiếp_thu phân_loại chưa rõ',
#  'thầy nên cho thêm bài_tập về nhà',
#  'những điều này nghe tưởng_chừng không liên_quan đến môn_học nhưng lại giúp cho sinh_viên phần_nào có định_hướng được công_việc tương_lai của mình',
#  'em học ở phòng mà bên cạnh là công_trình đang thi_công khá là ồn_ào vì_thế khi học đến phần nghe em không_thể nghe được gì và bài nghe bị gián_đoạn',
#  'thầy không sửa bài_tập trên lớp thầy chỉ giảng lý_thuyết theo em như thế là ít có hiệu_quả',
#  'thầy ít quan_tâm',
#  'giảng_dạy tích_cực dễ hiểu',
#  'không dùng điểm để đánh_giá nó làm sinh_viên không dám thực_hiện',
#  'dạy hay dễ hiểu tận_tình',
#  'không_khí lớp_học thì không được sôi_nổi',
#  'bài tập thực_hành mỗi tuần hơi khó mong rằng ở mỗi bài tập giảng_viên có_thể cung_cấp bài giải kỹ càng để sinh_viên có_thể nghiên_cứu và hiểu được cách làm',
#  'thầy rất thoáng và thoải_mái',
#  'thầy cần có tương_tác với sinh_viên qua mail hay moodle vì có đôi lúc có thắc_mắc nhưng thầy không phản_hồi',
#  'kiến_thức đơn_giản',
#  'phần lý_thuyết lặp lại nên chán không thu_hút',
#  'thầy dạy rất hay và rất nhiệt_tình',
#  'giảng_viên giảng_dạy theo đúng thời_gian môn_học',
#  'thầy rất dễ gần',
#  'khi sinh_viên hỏi phải có câu trả_lời chính_xác không được bỏ_qua những câu hỏi của sinh_viên',
#  'chấm điểm dựa trên mức_độ thấu_hiểu bài hay đưa ra lời khuyên hữu_ích',
#  'luôn nhiệt_tình trong giảng_dạy',
#  'thầy vui_vẻ',
#  'giảng bài kỹ càng dễ hiểu',
#  'cần tăng thời_gian thực_hành nói lên',
#  'cô giảng_dạy rất nhiệt_tình và dễ hiểu',
#  'giảng_dạy tốt',
#  'nhiệt_tình cô dễ_thương',
#  'giảng_viên dạy truyền_cảm_hứng sử_dụng thời_gian hợp_lý',
#  'giảng_viên dạy tận_tâm nhiệt_tình',
#  'thì có_thể lướt nhanh hơn vì phần này khá dễ',
#  'giảng_viên có chuyên_môn rất tốt kiến_thức rộng giải_đáp được mọi thắc_mắc của sinh_viên',
#  'giảng_viên hiền_lành nhiệt_tình giúp_đỡ khá nhiều cho sinh_viên khi sinh_viên không hiểu bài',
#  'giảng_viên rất tận_tình',
#  'thầy rất nhiệt_tình năng_nổ',
#  'truyền_đạt có cảm_hứng hướng_dẫn sinh_viên học_tập thế_nào sau khi ra trường để xin việc',
#  'học thoải_mái ít áp_lực',
#  'cô dễ_thương và giảng bài tận_tình',
#  'cô dạy rất tốt nhiều bài tập',
#  'thầy giảng_dạy nhiệt_tình dễ hiểu sửa bài_tập cẩn_thận',
#  'giảng_viên rất đảm_bảo giờ lên lớp',
#  'thầy là giảng_viên dạy toán hay nhất trường',
#  'môn_học này thật_sự rất khó và chương_trình học hơi nặng lúc trước môn này dược chia ra làm 2 môn là cấu_trúc dữ_liệu 1 và cấu_trúc dữ_liệu 2 năm nay lại gộp thành một nên sinh_viên khó tải nổi kiến_thức',
#  'cần kết_nối được mạng trong phòng lab',
#  'nhiệt_tình phương_pháp giảng_dạy rất hiệu_quả cách truyền_đạt rất dễ hiểu và dễ tiếp_thu biết cách truyền_cảm_hứng và tạo động_lực_học_tập cho sinh_viên',
#  'luyện nghe nhiều hơn',
#  'giảng_viên giảng_dạy rất truyền_cảm tạo cảm_giác ham học và hệ_thống bài_tập dồi_dào phong_phú',
#  'thầy có cách giảng bài rất hay và dễ hiểu',
#  'thầy dạy bằng slide bài_giảng hơi nhanh',
#  'cách dạy của cô hay thú_vị tạo động_lực',
#  'thầy dạy vui_vẻ không có áp_lực quá khắt_khe',
#  'giải_thích cặn_kẽ đi sâu hơn nữa',
#  'cho bài tập nhiều em rất thích colonsmile',
#  'giảng_viên vui_vẻ nhiệt_tình',
#  'giảng_viên nhiệt_tình phương_pháp giảng_dạy dễ hiểu',
#  'giảng_viên rất tâm_huyết và nhiệt_tình giảng bài dễ hiểu',
#  'thầy wzjwz127 dạy rất nhiệt_tình',
#  'cô nhiệt_tình và đưa ra bài giảng hợp_lý dễ hiểu có_thể vận_dụng làm bài',
#  'giảng_viên dạy nhiệt_tình truyền_đạt kiến dễ hiểu',
#  'thời_gian học_tập luôn thiếu_sót giảng_viên chưa nhiệt_tình giảng_dạy',
#  'rất thích được học cô',
#  'tiếp_cận với sinh_viên một_cách thân_thiện phương_pháp dạy khoa_học dễ tiếp_thu dễ hiểu',
#  'chữ viết nhỏ',
#  'thường_xuyên cho nghỉ mà không thông_báo',
#  'dạy hơi cao so với năng_lực',
#  'giáo_viên nhiệt_tình tận_tâm giúp_đỡ sinh_viên',
#  'thích thầy chia_sẻ kinh_nghiệm',
#  'quá khó_tính giờ cao_su giảng_dạy lan_man không hiệu_quả',
#  'giảng_viên giảng không hay đã vậy còn không nhiệt_tình không vui_vẻ không tạo cơ_hội cho sinh_viên hỏi về bài giảng',
#  'thầy dạy không có sức hút nhàm_chán gây buồn_ngủ cho sinh_viên',
#  'thầy thật_sự là một giảng_viên dạy_học rất có tâm',
#  'thầy dạy nhiệt_tình rất hăng_hái',
#  'giọng cô êm_êm dễ buồn_ngủ',
#  'truyền_đạt nhiều kinh_nghiệm tốt cho sinh_viên',
#  'khi phản_ánh kết_quả bài_tập không đúng thì cô lại lơ cười rồi bỏ đi không có một đáp_án cụ_thể',
#  'thầy khá hài_hước nói những việc thực_tế về ngành it rất thiết_thực',
#  'thầy wzjwz177 rất gần_gũi với sinh_viên thầy phát_âm tiếng anh cũng rất dễ nghe',
#  'phòng học ồn do cạnh khu xây_dựng',
#  'giảng bài dễ tiếp_thu_nhiệt_tình',
#  'lớp đã nghỉ 4 tuần liên_tiếp chưa tính một_vài ngày nghỉ khác',
#  'em mong phần thực_hành được hỗ_trợ nhiều hơn_nữa từ phía giảng_viên',
#  'giảng bài khó hiểu',
#  'cô dạy rất nhiệt_tình cung_cấp thông_tin đầy_đủ nhưng vẫn tạo điều_kiện cho sinh_viên tìm_hiểu thêm',
#  'thầy rất nhiệt_tình với học_sinh',
#  'dễ học dễ hiểu',
#  'hình_như em đăng_ký thầy dạy mà thầy dạy mấy buổi người khác dạy mấy buổi thì phải',
#  'chưa giảng_dạy nhiều về bài_tập cũng như hướng_dẫn sinh_viên hướng giải_quyết nó',
#  'thầy rất tận_tình luôn_luôn giúp_đỡ hỗ_trợ sinh_viên',
#  'thầy giảng rất hay và dễ hiểu phong_cách dạy độc_đáo',
#  'thầy wzjwz237 rất vui và nhiệt_tình',
#  'nên đưa môn wzjwz129 vào giảng_dạy ngay sau môn wzjwz130 và trước khi học các môn chuyên_ngành',
#  'chất_lượng tốt giáo_viên nhiệt_tình',
#  'giảng_viên dạy rất nhiệt_tình',
#  'thầy dạy sát theo slide nhưng một_số kiến_thức bài_tập lại khó hơn nhiều',
#  'trao dồi thêm về kỹ_năng speaking và listening',
#  'ít bài tập',
#  'cô dạy có tâm_huyết với học_sinh truyền_đạt tốt dễ hiểu',
#  'đảm_bảo giời lên lớp',
#  'ngiêm túc cứng_rắn về vấn_đề tự học',
#  'em mail bổ_sung bài thực_hành giáo_viên không hồi_đáp mail xin sửa điểm giảng_viên không reply đồng_ý xem_xét hay không đồng_ý',
#  'thời_gian cô up slide lên module còn chậm',
#  'thầy đưa ra những demo thực_tế giúp sinh_viên dễ hiểu',
#  'nope',
#  'thầy cho khá nhiều bài tập đa_dạng',
#  'các phần tiếng việt trong slide được ghi một_cách khó_hiểu và không rõ_ràng nhiều chỗ trong slide bài_giảng có_vẻ như được dịch bằng google dịch từ năm 2009',
#  'cô quan_tâm đến sinh_viên và truyền_đạt kiến_thức rất bổ_ích',
#  'không thực_tế',
#  'tiết học của thầy rất vui',
#  'học trong phòng chất_lượng cao hơn phòng_học hiện_tại không có máy_lạnh',
#  'giảng_viên chưa truyền_đạt tốt dạy còn chán không có sự thu_hút trong cách dạy lắm',
#  'hướng_dẫn rất tận_tình trình_bày hướng_dẫn rất đẹp có phong_cách thể_hiện một thái_độ rất nghiêm_túc trong công_việc giảng_dạy',
#  'giảng bài dễ hiểu dễ vận_dụng',
#  'thầy vui_tính dạy dễ hiểu và cung_cấp nhiều thông_tin hữu_ích cho sinh_viên',
#  'thầy quá chuyên_nghiệp',
#  'cô giảng có hơi khó hiểu',
#  'tạo bầu_không_khí thoải_mái cho sinh_viên',
#  'em rất hài_lòng về phương_pháp giảng_dạy của thầy',
#  'dạy nhiệt_tình theo sát môn_học',
#  'vì tính cô kỹ nên đôi lúc nói quá nhiều về một vấn_đề lặp đi lặp lại làm mất thời_gian trên lớp và sử_dụng giờ học không hiệu_quả',
#  'mong giáo_viên có_thể giải_đáp nhiều bài tập cho sinh_viên hơn trên lớp',
#  'đầu_tư thêm nhiều công_cụ dạy_học',
#  'giảng_viên rất đúng giờ',
#  'cách giảng dễ hiểu',
#  'thang điểm đưa ra đầu khóa học không rõ_ràng nhất_quán so với thang điểm cuối khóa',
#  'thầy hứa sẽ up điểm giữa kỳ sớm mà điểm giữa kỳ thì tới giờ này vẫn chưa có',
#  'thực_hành nhiều',
#  'nhiệt_tình với sinh_viên tư_tưởng thoải_mái',
#  'cho sinh_viên chép bài để nhớ kiến_thức hơn rèn_luyện nhiều bài_tập dạy nhiệt_tình',
#  'nhiều hoạt_động',
#  'giảng_viên áp_dụng mô_hình scrum để làm project là tốt nhưng không thành_công',
#  'hay kể các chuyện liên_quan đến thực_tiễn giúp bọn em tiếp_thu nhanh hơn và cũng có hứng_thú trong quá_trình học',
#  'đây là điều gây bức_xúc với sinh_viên',
#  'khó hiểu ạ',
#  'ân_cần tận_tụy',
#  'máy chiếu chưa rõ nét cho toàn thẻ sinh_viên trong phòng',
#  'cô nhiệt_tình sẵn_sàng giảng lại các kiến_thức mà sinh_viên chưa nắm được khi học lý_thuyết',
#  'nâng cao trang_thiết_bị phòng_học',
#  'giảng_viên nhiệt_tình hết_mình truyền_đạt kiến_thức',
#  'cô có_thể giảng phần lý_thuyết kỹ hơn được không ạ',
#  'thầy nên share lại slide cho sinh_viên',
#  'nhiều tâm_huyết với nghề',
#  'dạy tốt tận_tình',
#  'thầy rất nhiệt_tình trong việc trả_lời các câu hỏi phụ của sinh_viên',
#  'hiện tại em không nhớ nổi mặt của thầy fraction cô như nào nữa colondoublesurprise',
#  'phòng thực_hành cần nâng_cấp và bổ_sung thêm thiết_bị để mọi người đều có điều_kiện thực_hành thực_tế nhiều hơn',
#  'giảng_viên nên trao_đổi với sinh_viên nhiều hơn giao bài_tập và giải_thích những thắc_mắc của sinh_viên về môn_học',
#  'cô thân_thiện với học_sinh truyền_cảm_hứng động_lực tốt',
#  'thầy kiểm_tra quá nhiều',
#  'thầy rất khắt_khe trong việc dùng từ chuyên_ngành',
#  'thầy dạy rất tốt',
#  'những gì được học nó nhằm mục_đích gì',
#  'cần cung_cấp thêm tài_liệu học_tập môn_học này',
#  'cách dạy của thầy rất nhàm_chán không có nhiều hoạt_động thực_tế bài_tập thầy cho chỉ áp sát lý_thuyết mà chưa thực_tế',
#  'nên dành nhiều thời_gian cho bài_tập và hướng_dẫn cụ_thể phương_pháp giải hơn',
#  'đôi khi học_sinh nào bận muốn về trước thầy vẫn cho',
#  'nhiều lúc lớp chỉ có hai người đi học',
#  'có_thể chia nhóm ra làm thực_hành',
#  'thầy wzjwz83 rất nhiệt_huyết trong việc giảng_dạy',
#  'thầy vui quá đi hi_hi',
#  'giảng_viên nhiệt_tình chắt_lọc nội_dung cũng như mở_rộng nhiều kiến_thức về bộ_môn',
#  'thầy giảng rất hay rất tận_tâm với sinh_viên',
#  'em mong có sự thống_nhất giữa thầy_cô trong quá_trình giảng_dạy môn này',
#  'chưa ổn',
#  'giảng_viên tận_tâm dạy tốt',
#  'sử_dụng giờ học_hiệu_quả',
#  'cách nói chưa lôi_cuốn',
#  'thầy không đảm_bảo giờ lên_lớp nếu có nghỉ thầy cũng không thông_báo trước rất vô_lý',
#  'nhiệt_tình truyền_đạt kiến_thức cho sinh_viên',
#  'lý_thuyết và thực_hành nên đi_đôi với nhau',
#  'thân',
#  'thầy dạy quá tệ',
#  'không có nhiều bài_tập để làm thêm',
#  'phòng học quá sáng màn chiếu bị mờ rất khó nhìn xin ban quản_lý lắp rèm để sinh_viên và giảng_viên thuận_tiện trong việc học_tập và giảng_dạy',
#  'giáo_viên quá tốt',
#  'cần cân_bằng việc giảng_dạy giữa sinh_viên yếu và khá trở lên',
#  'nhiệt_tình giảng dễ hiểu dễ_thương',
#  'giảng_viên dạy rất dễ hiểu',
#  'tài_liệu cung_cấp thiếu',
#  'thầy nên đánh_giá kỹ hoạt_động trên lớp của từng thành_viên trong nhóm ai đóng_góp nhiều nghiêm_túc',
#  'giáo_viên lên_lớp muộn nghe điện_thoại trong lúc lên_lớp thường_xuyên nghỉ dạy không thông_báo',
#  'đề_nghị nên cho bài_tập về nhà',
#  'mong thầy giảng_giải và cho bài_tập từng bước nhiều hơn',
#  'thầy cho đề thực_hành cũng khá hay nhưng mà thật thì em toàn code mấy bài đó trên notepad rồi nộp không test gì cả nhưng được_cái là đồ_án 10 thì điểm thực_hành cũng 10 luôn',
#  'khó hiểu không sinh_động',
#  'chỉ dạy nhiệt_tình',
#  'giáo_viên truyền_đạt những vẫn đê sâu',
#  'chưa cung_cấp cách nhìn sâu hơn về môn_học vào thực_tế hiện_nay chỉ mới mang tính trừu_tượng',
#  'giảng_viên dạy dễ hiểu và đầy_đủ nội_dung',
#  'không hướng_dẫn kỹ',
#  'nhiệt_tình chi_tiết',
#  'thầy cho chép bài ít thôi tập_trung sửa bài được không ạ',
#  'khả_năng truyền_đạt chưa đi vào lòng người cho lắm',
#  'thầy rất nhiệt_tình dạy rất kỹ thầy cũng rất vui_tính',
#  'giảng_viên nhiệt_tình vui_vẻ giờ học vui',
#  'cô dạy không hấp_dẫn tuy hay nhưng không kích_thích được sinh_viên hoạt_động',
#  'thưa không có ạ',
#  'kiến_thức môn_học mang lại tương_đối đầy_đủ và thực_tế giúp sinh_viên nắm rõ phương_pháp và cách_thức để học_tập các môn chuyên_ngành sau_này',
#  'cách giảng_dạy tạo không_khí sôi_nổi trong lớp',
#  'trình_bày bài_giảng một_cách khoa_học và hợp_lý',
#  'tuy_nhiên giờ trên lớp thầy chưa thực_sự sử_dụng hiệu_quả lắm khi thiếu tương_tác với sinh_viên trong lớp để nắm tình_hình học_viên của mình',
#  'thầy dễ_thương nhiệt_tình dạy dễ hiểu',
#  'nên cho thời_gian học nhiều hơn 2 tiết',
#  'cô vui_tính hiền khá nhiệt_tình và gần_gũi với sinh_viên colonsmilesmile',
#  'những gì quan_trọng cần nắm_bắt và tìm_hiểu thêm',
#  'cá_nhân em thấy đôi_khi nhìn thầy em cảm_thấy hơi sợ sợ',
#  'rèn_luyện được kỹ_năng giao_tiếp mạnh dạng đứng trước lớp nói tiếng anh',
#  'thầy hướng_dẫn thực_hành hay',
#  'cập_nhật kiến_thức thực_tế',
#  'giảng_viên nhiệt_tình luôn_luôn đến lớp đúng giờ',
#  'chỉ có vấn_đề thầy dạy hơi nhanh',
#  'giảng_viên truyền_đạt còn chưa tốt',
#  'tình_trạng nghỉ không thông_báo cho sinh_viên để sinh_viên đứng đợi giảng_viên gần hết giờ rồi ra về nhiều lần',
#  'cô giảng_dạy chi_tiết trong quá_trình học',
#  'kiến_thức chưa có trọng_tâm',
#  'tiết học vui_vẻ thoải_mái',
#  'chưa tương_tác nhiều với sinh_viên',
#  'thân_thiện nhiệt_tình',
#  'yêu_cầu quá cao đối_với một sinh_viên mặc_dù chỉ là một đồ_án nhưng không nhất_thiết phải quá chi_tiết về mọi khía_cạnh cụ_thể',
#  'cô hướng_dẫn phương_pháp_học_tập hiệu_quả',
#  'thầy cần hoạt_động trao_đổi nhiều hơn với sinh_viên',
#  'thầy dạy rất dễ hiểu đúng trọng_tâm bài_học',
#  'cho quá nhiều bài tập chỉ nên cho bài_tập ví_dụ điển_hình',
#  'giúp em hiểu ra được nhiều cái hay',
#  'thầy giảng rất hay dễ hiểu',
#  'giảng_viên giảng bài hơi nhàm_chán gây cảm_giác buồn_ngủ có nhiều chỗ hơi lan_man',
#  'giáo_viên giạy theo cách quá thụ_động tạo sự nhàm_chán cho sinh_viên',
#  'thầy rất tận_tâm nhưng không có kỹ_năng sư_phạm',
#  'nội_dung hơi nhiều nên giảm bớt lại',
#  'thầy chỉ dạy rất tận_tình luôn hỏi học_sinh_phần_nào chưa hiểu và giảng lại rất kỹ những bài_giảng của thầy rất hay',
#  'mong thầy giải bài_tập trên lớp',
#  'do thời_gian mỗi buổi học khá ngắn nên giảng_viên cần tập_trung vào những chủ_đề quan_trọng phần còn lại nên để sinh_viên tự tìm_hiểu',
#  'giáo_viên rất tận_tâm nhiệt_tình',
#  'mong rằng những môn có thực_hành giáo_viên nên mở chat box và forum cho sinh_viên dễ trao_đổi với nhau cũng như nhanh_chóng nhận được lời giải_đáp thắc_mắc từ giáo_viên',
#  'cô dạy quá hay rồi',
#  'thêm hệ_thống ổ điện ngầm dưới nền nhà để tiện cho việc sinh_viên có_thể cắm laptop phục_vụ học_tập',
#  'chất_lượng môn_học phù_hợp',
#  'cô dạy rất nhiệt_tình và rất kiên_nhẫn với sinh_viên',
#  'có sai nhận sai và sửa_đổi khắc_phục',
#  'thầy dễ_tính dạy dễ hiểu thầy dạy hay',
#  'giáo_viên dễ gần tận_tâm',
#  'thầy rất vui_tính dạy dễ hiểu',
#  'không có hoạt_động giảng_dạy nào không hài_lòng',
#  'lên vừa cho học lý_thuyết vừa cho thực_hành',
#  'môn_học với kiến_thức không quá nặng',
#  'nội_dung thực_hành đã cũ không được đổi_mới và không sát với thực_tế',
#  'các code ví_dụ không được chiếu hết trên slide',
#  'chỉ dạy tận_tâm',
#  'thầy dạy nhiệt_tình chia_sẻ những kiến_thức bổ_ích',
#  'thầy dạy rất nhiệt_tình dễ hiểu tận_tâm',
#  'giảng hơi ít',
#  'em mong môn này có_thể áp_dụng nhiều hơn trong những đồ_án',
#  'giải ví_dụ bài_tập nhiều hơn',
#  'thành thật mà nói thì sau khi học buổi đầu xong thì em không muốn học thêm buổi thứ hai',
#  'đề_nghị thầy xem lại việc chấm chéo đồ_án và báo_cáo chéo đồ_án',
#  'bài dạy phụ_thuộc nhiều vào slide cách truyền_đạt chưa thực_sự phù_hợp với cá_nhân',
#  'có slide bài_giảng tiếng anh giúp nâng cao trình_độ đọc hiểu tài_liệu chuyên_ngành và nâng cao kiến_thức cho sinh_viên',
#  'học đúng giờ nhưng ra về thì sớm hơn quy_định',
#  'chuyên_nghiệp',
#  'giảng_viên thoải_mái hòa đồng',
#  'thầy dạy rất tốt',
#  'cách truyền_đạt kiến_thức của thầy đối_với em thì em cảm_thấy không phù_hợp lắm em cần phải rất rất tập_trung và hỏi_đi hỏi lại nhiều lần mới có_thể nắm_bắt kiến_thức',
#  'thầy cho nghỉ hơi nhiều',
#  'giảng_viên nên cung_cấp tài_liệu học_tập cho sinh_viên',
#  'thầy dạy nhiêt tình kỹ càng',
#  'thầy dạy hay nhiều kiến_thức mở_rộng được học trên slide tiếng anh',
#  'thầy dạy tốt không phụ_thuộc nặng vào chương_trình',
#  'slide bao_nhiêu thầy đọc lại bấy_nhiêu cực_kỳ khó hiểu và buồn_ngủ',
#  'cải_tiến trang_thiết_bị phòng thực_hành',
#  'giảng_viên nên dạy đúng giờ hơn hạn_chế cho sinh_viên về sớm',
#  'em hi_vọng trong các tiết học thầy có_thể đi sâu vào kiến_thức chuyên_môn và giảm bớt thời_lượng của hoạt_động liên_hệ thực_tế',
#  'chân_thành cảm_ơn thầy',
#  'không có ý_kiến nhiều',
#  'không có',
#  'cách chấm điểm của giảng_viên không đánh_giá đúng năng_lực của sinh_viên',
#  'em không có ý_kiến về mục này ạ',
#  'thời_gian và cách_thức thầy dạy',
#  'giảng quá khó hiểu',
#  'các thiết_bị âm_thanh cần được đảm_bảo hơn',
#  'nên phát_hành giáo_trình chuẩn cho môn_học',
#  'dưới đây là hình thầy cung_cấp toàn_bộ tài_liệu trong quá_trình học',
#  'lịch thực_hành không được thông_báo',
#  'thầy dạy rất tốt nhiệt_tình và rất dễ hiểu',
#  'lắp quạt phù_hợp vì phòng có 2 dãy quạt 2 bên nhưng ngồi ở dãy giữa vẫn nóng cần có màn che cửa_sổ và có ổ_cắm điện',
#  'lên lớp toàn cho làm paper',
#  'kiến_thức được đưa vào ứng_dụng nhiều bài_toán',
#  'giảng_viên làm rất tốt trong việc giảng_dạy bộ_môn thực_hành',
#  'cô wzjwz253 nhiệt_tình giảng bài kỹ',
#  'thầy wzjwz199 rất nhiệt_tình trong quá_trình giảng_dạy',
#  'sau kỳ thi giữa kỳ cấu_trúc dữ_liệu lý_thuyết chủ_yếu là thi về thuật_toán sắp_xếp thì thầy mới cho làm bài tập về các thuật_toán sắp_xếp',
#  'giảng_viên nhiệt_tình gần_gũi với sinh_viên',
#  'có nghĩ 2 buổi không hề báo trước',
#  'them nhiều tài_liệu và video hướng_dẫn',
#  'giảng_viên nên cho số_lượng bài_tập vừa phải giải chậm và sâu ở mỗi dạng toán đặc_biệt là những dạng toán khó',
#  'cần có nhiều buổi thực_hành trên thiết_bị thật hoặc giảng_viên nên đem thiết_bị thật làm vài bày mẫu trên lớp',
#  'môn_học nên tập_trung vào chuyên_sâu các mục nên có biên_soạn giáo_trình mới chuyên_sâu hơn',
#  'thầy dạy dễ hiểu rất hay',
#  'thời_khóa_biểu phân_chia không hợp_lý chưa học lý_thuyết đã phải học thực_hành',
#  'cung_cấp nhiều bài tập cho sinh_viên tham_khảo',
#  'thầy_cô dạy chưa sâu vào bài_học',
#  'nói_nhỏ rất khó nghe',
#  'thầy hầu_như không giải_đáp thắc_mắc của sinh_viên khi bài_tập mắc_lỗi hoặc có nhưng rất hời_hợt',
#  'chưa thực_sự tận_dụng tốt thời_gian và chưa mở_rộng vấn_đề',
#  'công_bằng',
#  'thầy giảng rất kỹ và dễ hiểu cho rất nhiều bài tập giúp sinh_viên ứng_dụng và nhớ được những gì đã học',
#  'cô dạy dễ hiểu vui_vẻ với sinh_viên cung_cấp đầy_đủ kiến_thức cần_thiết',
#  'bài giảng hơi khó hiểu',
#  'nên muốn nhà_trường tăng thêm thời_gian học lý_thuyết của môn này',
#  'thường_xuyên tổ_chức thảo_luận thực_hành nói',
#  'giảng_viên dạy có phần hơi nhanh',
#  'giúp chúng_em học_tập tốt hơn',
#  'thầy dạy hay tận_tình',
#  'thầy dạy rất hay chi_tiết',
#  'tận_tụy với sinh_viên',
#  'thầy rất nhiệt_tình và có kiến_thức sâu_rộng cung_cấp nhiều kiến_thức hay',
#  'hầu_như trong cả năm học giảng_viên chỉ đi dạy đúng thời_khoá_biểu chỉ từ 2 đến 3 ngày còn lại giảng_viên lại tự_ý dời lịch học sang ngày thứ 7 mà không hỏi ý_kiến của sinh_viên vì vào ngày thứ 7 có rất nhiều sinh_viên có lịch học môn khác',
#  'cần thêm nhiêu bài_tập thực_tế',
#  'không tập_trung vào giảng kiến_thức cho học_sinh hiểu',
#  'thật_sự rất thất_vọng về việc dạy thực_hành của thầy',
#  'góp ý doubledot thầy nên có cách tiếp_cận khác để cân_bằng giữa vấn_đề ngoại_ngữ và kiến_thức chuyên_ngành',
#  'thầy dạy lý_thuyết được',
#  'thầy dạy nhanh hay',
#  'nên cho nhiều bài_tập hơn',
#  'giảng_viên nhiệt_tình quan_tâm đến học_sinh',
#  'môn_học có 5 lab mà chỉ học 2 lab là thi cuối kỳ thầy nên lên_lớp đủ_số buổi quy_định',
#  'slide hơi khó hiểu',
#  'giáo_viên thực_hành cần quan_tâm chỉ_dẫn sinh_viên tận_tình hơn',
#  'giảng_viên lên_lớp đầy_đủ',
#  'giảng_viên nhiệt_tình hỗ_trợ sinh_viên tốt',
#  'giảng_viên hay cho nghỉ học mà không báo trước',
#  'trang_thiết_bị còn hỏng_hóc nhiều thường_xuyên trục_trặc trong giờ học',
#  'hiểu tâm_lý học_sinh nên mọi người trong lớp đều chú_ý giảng bài',
#  'phòng wzjwz325 thiết_bị âm_thanh hay xảy ra trục_trặc làm gián_đoạn buổi học',
#  'vui_tính thân_thiện',
#  'nhiệt_tình năng_nổ',
#  'không có sự thoải_mái khi học_tập',
#  'giảng_viên dạy tận_tâm nhiệt_tình lên_lớp đúng giờ',
#  'mong cô cung_cấp nhiều tài_liệu có hướng_dẫn_giải cụ_thể các dạng toán để đáp_ứng nhu_cầu tự học',
#  'giảng_viên nhiệt_tình vui_vẻ hoà_đồng gần_gũi giúp sinh_viên khá nhiều trong việc tiếp_thu kiến_thức',
#  'mong nhà_trường xem_xét lại để có sự nhất_quán trong công_tác dạy và chấm thi',
#  'truyền đật kiến_thức tốt dễ hiểu',
#  'tài_liệu thực_hành nên nêu rõ mục_tiêu cũng như kiến_thức cần đạt được sau bài thực_hành',
#  'và giảng_dạy khó hiểu',
#  'ít quan_sát sinh_viên thực_hành',
#  'có một bạn trong phòng của em học thầy ở học_kỳ trước hâm_mộ thầy',
#  'bài tập cuối kỳ làm quá nhiều',
#  'cô dạy có tâm post tài_liệu và bài_tập lên moodle rất đầy_đủ',
#  ...]

# %%
def name_removal(sentences):
    processed_sentences = []
    for sent in sentences:
        sent = sent.split(" ")
        for i in range(len(sent)):
            word = sent[i]
            if word.startswith("wzj"):
                sent[i] = "<name>"
        sent  = " ".join(sent)
        processed_sentences.append(sent)
    return processed_sentences
train_sents = name_removal(train_sents)

# %%
with open("./Data/train/sents.txt", "r", encoding = "utf8") as f:
    train_sents = [sent.strip() for sent in f.readlines()]
train_sents
# Out:
# ['slide giáo trình đầy đủ .',
#  'nhiệt tình giảng dạy , gần gũi với sinh viên .',
#  'đi học đầy đủ full điểm chuyên cần .',
#  'chưa áp dụng công nghệ thông tin và các thiết bị hỗ trợ cho việc giảng dạy .',
#  'thầy giảng bài hay , có nhiều bài tập ví dụ ngay trên lớp .',
#  'giảng viên đảm bảo thời gian lên lớp , tích cực trả lời câu hỏi của sinh viên , thường xuyên đặt câu hỏi cho sinh viên .',
#  'em sẽ nợ môn này , nhưng em sẽ học lại ở các học kỳ kế tiếp .',
#  'thời lượng học quá dài , không đảm bảo tiếp thu hiệu quả .',
#  'nội dung môn học có phần thiếu trọng tâm , hầu như là chung chung , khái quát khiến sinh viên rất khó nắm được nội dung môn học .',
#  'cần nói rõ hơn bằng cách trình bày lên bảng thay vì nhìn vào slide .',
#  'thầy rất tận tình và đi dạy rất đúng giờ .',
#  'dễ bị áp lực .',
#  'đang dạy thầy wzjwz208 đi qua nước ngoài giữa chừng , thầy wzjwz209 dạy thay .',
#  'môn học còn dễ cần nâng độ khó lên nữa .',
#  'có thể cho sinh viên đi thăm quan nhiều công ty xem quy mô và cách làm việc , để giúp hiểu rõ hơn vê ngành mình đang học .',
#  'hài lòng về tất cả .',
#  'nhiệt tình , vui vẻ .',
#  'thấy nhiệt tình trong việc trao đổi giúp đỡ về học tập .',
#  'phong cách giảng bài của thầy rất gần gũi với sinh viên !',
#  'giảng dạy kết hợp các hoạt động giải trí có hiệu quả .',
#  'cần tạo các buổi seminar để sinh viên có thể hiểu sâu thêm về các vấn đề trong chuyên ngành nhưng không có trong môn học .',
#  'tiết học thoải mái .',
#  'thầy nhiệt tình , quan tâm tới sinh viên .',
#  'giảng dạy nhiệt tình , hướng dẫn chi tiết đến lúc sinh viên hiểu !',
#  'chưa có nhiều tiết làm bài tập , chữa bài tập trên lớp .',
#  'tài liệu được bổ sung nhiều và đầy đủ trên moodle .',
#  'giảng viên phải nên cho ví dụ cụ thể những phần quan trọng nên nói kỹ có thể lấy ví dụ minh họa tránh việc lập đi lập lại nhiều lần sẽ tạo cảm giác chán cho sinh viên .',
#  'nên biên soạn một tài liệu của chính trường ta .',
#  'không giúp đỡ sinh viên trong những vấn đề xung quanh .',
#  'bài tập đa dạng , cụ thể .',
#  'nội dung giảng viên yêu câu seminar hầu như không có tài liệu tham khảo và rất ít ứng dụng trong thực tế , đề nghị có sự thay đổi trong những năm học tới .',
#  'slide up đầy đủ trước mỗi buổi học .',
#  'nội dung giảng dạy quá nhàm chán , khô khan .',
#  'lượng kiến thức quá nhiều trong một học kỳ .',
#  'thầy chép bảng nhiều .',
#  'thầy tận tình hướng dẫn cách làm , giải quyết những thắc mắc của sinh viên .',
#  'chúc các thầy cô , anh chị làm việc vui vẻ !',
#  'hay , nhiệt tình , dễ hiểu .',
#  'mặc dù nhiệt tình nhưng khi truyền đạt thì lại khó hiểu , sử dụng ngôn từ gây khó khăn cho việc hiểu bài .',
#  'thầy dạy khá hay , cung cấp nhiều thông tin liên quan đến môn học , đưa ra nhiều hướng giải quyết khi sinh viên gặp vấn đề khó khăn với đồ án !',
#  'hy vọng học kỳ sau có thể học được với cô .',
#  'nhiều khi em lên lớp học môn đặc tả hình thức giống như lên lớp học mà không biết mình học cái gì .',
#  'trong khi giảng nói nhỏ quá .',
#  'thực hành khó hiểu .',
#  'thầy rất tận tâm nhiệt tình , quan tâm đến sinh viên , giảng bài dễ hiểu , kiến thức sâu rộng am hiểu cao .',
#  'cô dạy với nhiệt huyết của mình , dù như thế nào , cô vẫn luôn mỉm cười và kiên trì giảng bài cho chúng em đến khi chúng em hiểu .',
#  'cô lên lớp đúng giờ , giảng bài rất dễ hiểu cho sinh viên .',
#  'những thông tin cần thiết như doubledot thời gian dealine , cách nộp bài thường không dặn lớp thực hành thứ hai .',
#  'thầy nhiệt tình , dễ chịu .',
#  'giảng viên chưa đi sâu vào bản chất của vấn đề , em chỉ học thôi mà không biết bản chất của nó là gì nó có ứng dụng gì sau này cho chuyên nghành của em .',
#  'đặc biệt hơn là thầy đã bỏ rất nhiều công sức trong việc ra bài tập và chấm điểm một cách rõ ràng và minh bạch .',
#  'cô rất nhiệt tình và tận dụng tốt thời gian .',
#  'giảng viên tận tâm , nhiệt huyết trong giảng dạy .',
#  'thầy nhiệt tình , gần gũi .',
#  'giảng viên tận tâm , giảng dễ hiểu , dễ tiếp thu .',
#  'tạo ra sự cạnh tranh trong mỗi buổi thực hành .',
#  'bài tập và có code tham khảo .',
#  'cần nâng cấp hệ thống wifi , vì khi vào phòng thực hành , sinh viên không thể truy cập internet , buộc phải xin phép ra ngoài để làm bài .',
#  'tài liệu không chi tiết lắm .',
#  'tận tâm , nhiệt tình , vui tính , dễ gần với sinh viên .',
#  'thầy dạy rất hay và nhiệt tình .',
#  'thầy dạy không đúng giờ , không hướng dẫn sinh viên thực hành .',
#  'giúp đỡ học sinh quá ít .',
#  'cô dạy buồn ngủ quá .',
#  'nên kinh mong nội dung môn học được giảm tải cho phù hợp hơn với đặc thù của một trường công nghệ thông tin .',
#  'thầy tận tình vui tính .',
#  'cô lại kiểu khó tính nữa .',
#  'tạo hứng thú cho sinh viên .',
#  'cô giảng hay cuốn hút và truyền đạt dễ hiểu .',
#  'có hứng thú học .',
#  'ôn tập đúng theo thầy nhưng không biết cuối kỳ được mấy điểm .',
#  'giảng viên hướng dẫn cụ thể , chi tiết .',
#  'giáo trình quá ít và nội dung không khác nhau là mấy .',
#  'giáo viên nghỉ dạy liên tục , cuối học kỳ lại tăng học bù , những tiết học bù đó đã ảnh hưởng đến những đồ án , và trễ deadline .',
#  'giáo viên lúc dạy lúc không , không dạy cũng không thông báo , sinh viên tốn thời gian , công sức , tiền bạc rồi ngồi đợi và đi về .',
#  'cần có một phòng máy tốt hơn , hiện đại hơn .',
#  'thầy nên cho làm bài tập tương tự nhau nhiều hơn một vài bài để tránh tình trạng quên hoặc các dạng tựa nhau nhưng hơi khác cách làm .',
#  'không ngờ môn này lại chán đến như vậy , không học được gì từ môn này , thầy dạy chán kinh khủng , hay đi trễ từ 30 - 45 phút , không nhiệt tình .',
#  'giảng viên đánh giá sai điểm và năng lực của học sinh .',
#  'không đáp ứng được đề cương môn học đề ra .',
#  'thầy nên hướng dẫn thực hành nhiều hơn .',
#  'giảng viên thân thiện , quan tâm tới sinh viên .',
#  'môn lập trình hướng đối tượng nên cập nhật thêm những nội dung mới , dễ hiểu và giảng giải cụ thể hơn .',
#  'giáo viên nhiệt tình , tâm huyết , khả năng truyền đạt tốt .',
#  'thầy dạy rất tốt và nhiệt tình .',
#  'cô nói hơi nhỏ , nếu lớp ồn sẽ khó nghe .',
#  'bài tập cô đưa ra nhiều , và khó tìm hiểu , với kiến thực hiện tại của sinh viên thì khó có thể tìm hiểu và làm tốt bài tập cô ra .',
#  'bài tập và hoạt động nhóm còn ít .',
#  'giảng viên rất nhiệt tình , phương pháp giảng dạy hay , sinh viên nắm bắt kiến thức ngay trên lớp .',
#  'cô hướng dẫn thực hành khá đầy đủ .',
#  'được học nhiều kinh nghiệm từ thầy wzjwz163 .',
#  'kiến thức của thầy rất tốt , bảo đảm giờ lên lớp .',
#  'hiện tại em chưa thấy tác dụng gì nhiều khi học môn này .',
#  'cải thiện lại cơ sở vật chất máy chiếu trong phòng học .',
#  'dạy không phù hợp với cách học của em .',
#  'giải thích nội dung mới rõ ràng .',
#  'lớp học quá đông !',
#  'môn căn bản mà thầy không dạy cho sinh viên kỹ , gây không hiểu , mất căn bản .',
#  'giảng viên chưa cho bài tập về nhà để sinh viên làm nên cho 5 bài mỗi chương , không cần chữa chỉ cần đáp án .',
#  'mà hiện tại trường ta chưa có , đây là thiệt thòi lớn đối với tụi em .',
#  'tôi cảm thấy giảng viên dạy rất tốt .',
#  'không biết thầy nào dạy chính thức , mà học thường nghỉ không thông báo trước để sinh viên đứng chờ sắp hết tiết rồi tự về nhiều lần .',
#  'cần có sự tương tác giữa giảng viên và sinh viên nhiều hơn .',
#  'giảng viên thân thiện nhiệt tình cởi mở .',
#  'giáo viên có mời các công ty về trình bày , giúp sinh viên cập nhật kiến thức thực tiễn .',
#  'coi lại thái độ giảng viên thực hành .',
#  'giảng viên nhiệt tình , giải nhiều bài tập .',
#  'bài giảng của thầy rất nhiệt tình .',
#  'môn học chưa thực tiễn , chưa thu hút sinh viên .',
#  'dạy hơi nhanh !',
#  'ít làm bài tập .',
#  'giảng bài kém thu hút , vị trí đứng giảng không hợp lý , ôn tập cuối kỳ còn chưa tập trung vào vấn đề .',
#  'giảng viên nhiệt tình , bài giảng thu hút .',
#  'nhờ thầy và giảng viên lý thuyết , em đã hiểu rõ về môn này rất nhiều !',
#  'môn này khá trừu tượng nên mong thầy có nhiều liên tưởng tới thực tiễn hơn để chúng em có thể hiểu .',
#  'cần thêm nhiều tài liệu cho sinh viên .',
#  'bài tập trên lớp .',
#  'tăng số tiết dạy lên để sinh viên có nhiều cơ hội hỏi đáp thắc mắc về môn học .',
#  'thầy nhiệt tình dễ hiểu .',
#  'thực hành và lý thuyết nên dạy song song .',
#  'giảng viên dạy nhanh .',
#  'bài tập trên lớp nên được giới thiệu ngay từ đầu tiết học để học sinh không tốn thời gian đọc đề cũng như có thể suy nghĩ cách giải cùng lúc với việc nghe giảng .',
#  'giảng viên cho bài tập hay .',
#  'cập nhật bài tập mới .',
#  'lên lớp ai làm việc người ấy , thầy không có giảng gì thêm .',
#  'tận tâm , nhiệt tình , quan tâm đến sinh viên .',
#  'phản hồi giải đáp thắc mắc cho sinh viên .',
#  'dạy quá nhanh .',
#  'mong ban thiết bị sớm khắc phục ạ !',
#  'môn này cần làm đề tài để áp dụng lý thuyết vào thực tiễn mà trên lớp chỉ học một đống lý thuyết và hiếm ai nhớ đa số khá buồn ngủ khi lên lớp .',
#  'giảng viên nên đổi mới phương pháp giảng dạy , tránh thô cứng , không hấp dẫn sinh viên .',
#  'nhiệt tình , tạo cách chủ động cho học sinh tiếp cận với môn học và tham gia các chương trình phong trào liên quan để nâng cao kỹ năng .',
#  'cô dạy rất tận tình , dễ hiểu .',
#  'không đáp ứng được nhu cầu của sinh viên .',
#  'thầy rất nhiệt tình với chúng em và điều này làm em rất hài lòng .',
#  'cách giảng dạy của thầy rất hay và có phần dễ hiễu .',
#  'nhiệt tình , dễ thương .',
#  'không hướng dẫn đồ án .',
#  'em xin đề nghị nhà trường nên bổ sung tài liệu về môn học và cập nhật nội dung .',
#  'chép bài rất nhiều , lãng phí thời gian nghe giảng .',
#  'em không học thầy wzjwz178 kỳ này , giáo viên thực hành có 2 người nên có lẽ daa nhầm .',
#  'đề thi môn dài sinh viên làm không đủ thời gian .',
#  'cho làm nhiều bài test .',
#  'theo em thì nên thi phòng máy nào có visual 2013 trở lên .',
#  'cần thêm nhiều tài liệu cho môn học .',
#  'thầy giảng dạy tốt .',
#  'mong thầy có thể hướng dẫn cách cụ thể nhất cho những bài khó .',
#  'thầy cần cho bài tập và hướng dẫn nhiều hơn .',
#  'giáo viên lên lớp đúng giờ , giảng bài sôi động .',
#  'em thấy thầy chỉ giảng cho có .',
#  'cần xác định rõ mục đích môn học và cho sinh viên đề cương chi tiết môn học trước khi bắt đầu .',
#  'thầy nói chuyện với sinh viên rất tự nhiên , chia sẻ kinh nghiệm thực tế .',
#  'dạy theo sát chương trình .',
#  'cung cấp thêm trang thiết bị phục vụ nhu cầu môn học .',
#  'đề nghị nâng cấp phòng lab khoa mạng .',
#  'thầy giảng hay và tâm huyết , bài giảng có tính thực tiễn cao .',
#  'đi dạy đúng giờ .',
#  'thầy cung cấp nhiều kiến thức mới , thầy dạy tận tâm và nhiệt tình !',
#  'có tăng thêm nhiều ví dụ để minh họa cho lý thuyết vì có nhiều phần lý thuyết rất trừu tượng .',
#  'các yêu cầu về đồ án môn học nên đươc đưa ra chính xác trước khi sinh viên bắt đầu thực hiện chia nhóm và làm đồ án .',
#  'dạy dễ hiểu dễ tiếp thu , tập trung vài kiến thức trọng tâm .',
#  'dạy chưa được kỹ lắm , điểm nên thoáng hơn .',
#  'chưa chuẩn bị kỹ bài giảng để có thể trả lời các thắc mắc của sinh viên trên lớp .',
#  'cô khá tận tâm cho học sinh .',
#  'cần cải cách lại nội dung các bài thực hành , một số kiến nội dung trong bài thực hành đã trở nên lỗi thời .',
#  'giảng viên có khả năng truyền đạt kiến thức tốt .',
#  'cho làm nhiều bài tập .',
#  'nghiên cứu khoa học .',
#  'giáo viên dạy rất tận tâm , nhiệt tình .',
#  'thầy cô hướng dẫn đồ án hệ thống thông tin cần có thêm một vài buổi gặp mặt với sinh viên và đưa ra lịch cố định trên trường để sinh viên thắc mắc có thể lên hỏi trực tiếp !',
#  'chỉ thông báo trên lớp sẽ khó tránh sai sót .',
#  'cô viết ở góc bảng gần chổ bụt giảng khiến nhiều khi khó quan sát được ạ .',
#  'đề nghị lắp thêm quạt .',
#  'dạy kỹ .',
#  'bài tập cần đa dạng hơn .',
#  'nói rất nhỏ .',
#  'có lúc làm bài sai giáo viên nói làm hơi tự ái .',
#  'không sửa các bài tập thực hành .',
#  'em chưa hiểu rõ cách thức chấm điểm bài kiểm tra thực hành .',
#  'làm bài tập nhiều mặc dù không hiểu lắm .',
#  'thi thoảng nghỉ học không thông báo trên daa .',
#  'thầy dạy dễ hiểu , tiết học dễ hiểu , sôi nổi .',
#  'thầy giảng dạy nhiệt tình , truyền cảm .',
#  'giảng dạy rất chi tiết , dễ hiểu và dễ tiếp thu .',
#  'truyền đạt những kiến thức tốt .',
#  'cô vui tính .',
#  'nếu có thì chỉ hướng dẫn bằng lý thuyết mà không làm bài tập mẫu cho sinh viên .',
#  'cô chưa có nhiều kênh bài tập cho sinh viên .',
#  'bạn nào khá thì có thể áp dụng công thức vào bài tập cả lớp chưa đến 30% còn thực sự hiểu môn học thì rất ít người hiểu .',
#  'thầy dạy hơi nhanh .',
#  'ít hướng dẫn sinh viên trong giờ thực hành .',
#  'không thực hành được buổi nào .',
#  'thầy dạy phần lý thuyết hay , nắm bắt được khả năng của sinh viên .',
#  'ví dụ đề tài của em là doubledot các nguyên lý cơ bản , bao gồm 7 nguyên tắc của bohm ( 1983 ) .',
#  'giáo viên nhiệt tình , dạy dễ hiểu , tận tình với sinh viên .',
#  'tân tâm , nhiệt tình trong lớp lẫn bên ngoài .',
#  'thầy giảng dạy tận tâm nhiệt tình .',
#  'thầy vui tính , giảng bài dễ hiểu , nhiệt tình .',
#  'thầy giáo dạy nhiệt tình .',
#  'dạy dễ hiểu , gần gũi sinh viên .',
#  'cô dạy rất nhiệt tình và tài liệu của cô rất cụ thể dễ hiểu , cô hướng dẫn rất tận tình .',
#  'mong thầy cố gắng trong các học kỳ sau .',
#  'cần đưa ra nhiều ví dụ minh họa hơn .',
#  'giảng viên hoà đồng , vui vẻ , chỉ giảng tận tình sinh viên ham học hỏi .',
#  'giảng viên không dạy một tiết thực hành nào .',
#  'không !',
#  'nên có sự thống nhất giữa các giảng viên bộ môn trong đề cương giảng dạy .',
#  'có những phần kiến thức chỉ một nửa lớp được học nhưng giảng viên nghĩ là cả lớp đã học rồi nên chỉ overview , những sinh viên còn lại khó nắm được .',
#  'máy tính cập nhật nhanh hơn .',
#  'vui , hòa đồng , nhiệt tình .',
#  'có giúp đỡ sinh viên học tập nghiên cứu .',
#  'giảng viên tận tâm , nhiệt tình , ham học hỏi .',
#  'tuy nhiên cô nên cân nhắc lại về số lượng yêu cầu đối với sinh viên để sinh viên không bị khớp vì quá nhiều dẫn đến làm qua loa cho có , như vậy thì kết quả lại không tốt .',
#  'cô rất tận tâm , rất ok , em rất thích cách dạy và học của cô ( mặc dù hơi nhanh tí ) .',
#  'mong thầy và nhà trường xem xét lại những điều em vừa nói .',
#  'thầy tận tâm , nhiệt tình , tạo động lực cho sinh viên .',
#  'thầy giáo tận tình , dạy kỹ , thường đưa ra câu hỏi để xem xét mức độ hiểu biết của sinh viên .',
#  'cần tăng cương trao đổi giữa sinh viên và giáo viên .',
#  'nói chung là nghe không bao giờ nghe rõ được .',
#  'cách truyền đạt của giáo viên chưa có sức hút đối với sinh viên nhiều cho lắm .',
#  'cô giáo thân thiện dễ gần , thực hành nhiều .',
#  'chưa tiếp thu trọn vẹn .',
#  'cần cải tiến trang thiết thực hành .',
#  'giảng kỹ hơn .',
#  'còn hơi kéo thời gian .',
#  'có nhiều bài tập về nhà cơ bản lẫn nâng cao và giảng viên sửa bài đủ .',
#  'thầy rất hiền và kiên trì giảng dạy cho lớp mặc dù môn học này đối với em không được hứng thú lắm .',
#  'đôi lúc giảng bài hơi nhanh .',
#  'có một số buổi không đi dạy .',
#  'thầy nhiệt tình và dạy dễ hiểu .',
#  'có kiến thức nền tảng này , sinh viên có thể học thêm bất kỳ công nghệ cụ thể nào đó dễ dàng , cũng như tiếp thu thay đổi công nghệ mới nhanh chóng .',
#  'cấu trúc đề cương của thầy chưa rõ ràng , lý thuyết chưa được trình bày rõ trong các buổi học .',
#  'tài liệu hỗ trợ toàn tiếng anh rất khó học .',
#  'chưa nhận được gì từ môn học này .',
#  'giảng viên không hề giảng dạy , chỉ đưa đề cương rồi thôi .',
#  'bài tập mỗi tuần đều có và đầy đủ .',
#  'em xin cảm ơn .',
#  'thầy cần phải cho sinh viên biết được học môn này có tác dụng gì và làm được gì khi học xong .',
#  'đề nghị tăng thời gian thưc hành .',
#  'không được làm những chuyện riêng trong lúc dạy thực hành .',
#  'hỗ trợ thêm giáo trình không phải slide cho sinh viên .',
#  'cô wzjwz259 rất vui và nhiệt tình .',
#  'giáo viện nhiệt tình , tận tâm .',
#  'kiến thức được giảng viên trình bày rõ ràng , dễ hiểu cho sinh viên .',
#  'cần thêm nhiều kit để thực hành .',
#  'dạy khó hiểu quá nhanh .',
#  'luôn gần gũi , tham khảo ý kiến sinh viên và thống nhất cũng sinh viên .',
#  'sắp xếp lịch học bù chưa hợp lý .',
#  'nhà trường nên đưa môn học này vào thời khóa biểu bắt buộc ở học kỳ 1 của các sinh viên năm nhất nhằm giúp các em nắm biết được mình nên học gì , mình có nên chuyển đổi ngành hay không .',
#  'thời gian thực hành cần nhiều hơn .',
#  'giảng viên rất nhiệt tình trong giảng dạy .',
#  'slide chuẩn bị chưa tốt .',
#  'thầy hay đòi hỏi sinh viên những điều hơi quá cao .',
#  'cô giảng hướng dẫn nhiệt tình .',
#  'chúng em đã gặp khó khắn với khổ giấy nhỏ , mô hình thì lớn và phức tạp .',
#  'giảng quá nhiều không đánh vào trọng tâm .',
#  'em không muốn nói gì nhưng mong thầy xem lại cách đánh giá sinh viên để công bằng hơn , cái sinh viên không biết không phải chỉ ở cúp tiết mà còn ở cách giảng dạy , truyền đạt ở giảng viên , ví dụ như cô wzjwz324 , rất dễ hiểu , tận tâm .',
#  'cô có nhiều hình thức giảng dạy hay .',
#  'hơi khó .',
#  'thầy đi trễ .',
#  'giảng tốt .',
#  'nói mở rộng nhiều vấn đề về môn học .',
#  'cần tăng cường nội dung nghe và nói để sinh viên giao tiếp tốt hơn bằng tiếng anh .',
#  'giảng viên tạo điều kiện làm nhiều bài tập .',
#  'hỗ trợ thêm về các thiết bị dạy và học .',
#  'ít giải bài tập trên lớp .',
#  'chia sẻ .',
#  'bám sát nội dung chính .',
#  'cần thêm các đoạn code cho các giải thuật bổ sung các phương pháp để giải quyết các bài toán liệt kê .',
#  'thông tin đầy đủ về bài tập và các nguồn tham khảo .',
#  'cô tận tâm , nhiệt tình , phương pháp dạy dễ hiểu .',
#  'thầy giảng rất dễ hiểu và thú vị , thu hút .',
#  'hướng dẫn chi tiết về cách thực hành .',
#  'giảng viên chỉ cho đồ án và giải đáp các yêu cầu đồ án , không cung cấp tài liệu hay hướng dẫn cơ bản , sinh viên tự tìm hiểu với lý do là hệ tài năng nên cần tự xoay sở .',
#  'môn học toàn kiến thức mới mẻ , giảng viên nên giảng chi tiết hơn .',
#  'đến khi cuối kỳ , chỉ cần sinh viên mắc một sai sót nhỏ thì sẽ rớt môn .',
#  'cần thay đổi cách dạy và nội dung học của phần thực hành , các bài thực hành hiện tại của môn mạng máy tính chưa đảm bảo hiệu quả .',
#  'thầy dạy hay , tận tình góp ý từng bài .',
#  'cơ sở vật chất , phỏng máy không đủ phích cắm cho dụng cụ thực hành và số lượng sinh viên , máy còn tiềm ẩn nhiều virus .',
#  'trên lớp lý thuyết giảng viên yêu cầu sinh viên phải thực hiện đồ án theo những gì mình hướng dẫn , những nhóm sinh viên bổ sung thêm những liên hệ thực tiễn đều bị cho là sai , không phù hợp với đồ án .',
#  'thầy giảng bài hay và hiệu quả !',
#  'giảng viên nhiệt tình vui vẻ .',
#  'phòng học nên có rèm che sáng để khi chiếu slide được nhìn rõ hơn .',
#  'chương trình dạy lý thuyết và thực hành nên khớp với nhau hơn , tránh tình trạng thực hành trước khi học lý thuyết .',
#  'thầy giảng dạy nhiệt tình , dễ hiểu .',
#  'mong giảng viên ngày càng chấn chỉnh việc dạy học để các khoá sau được hiểu tốt hơn .',
#  'thầy dạy rất có tâm , và giảng cho sinh viên rất nhiều thứ !',
#  'nội dung khảo sat quá dài , nhiều mục lặp đi lặp lại , nhiều bạn khảo sát mà không cần đọc , toàn tích chàn .',
#  'dạy tốt và rất nhiệt tình chỉ dạy hoc sinh .',
#  'nhiệt tình , tân tâm .',
#  'nhưng học mới thấy kiến thức thầy dạy rất hay , bám sát thực tế , thầy dạy rất nhiệt tình , vui vẻ , khác với mọi người nói .',
#  'bài tập rất hay .',
#  'thầy cô cần cho nhiều dạng bài tập sát với đề thi hơn .',
#  'thầy giảng hay nhưng nên tự tin hơn , nói to hơn để học sinh hiểu bài một cách rõ ràng hơn .',
#  'mong thầy vui tính , gần gũi với sinh viên hơn .',
#  'giáo viên vui tính , hòa đồng , nhiệt tình .',
#  'cung cấp kiến thức trọng tâm .',
#  'cố gắng truyền đạt một cách tốt nhất để sinh viên được hiểu .',
#  'giọng của giảng viên nhỏ dù đã sử dụng micro .',
#  'dù phương pháp học tập này khá hiệu quả nhưng vẫn có chút nào đó nghi ngờ từ phần thuyết trình của các bạn , liệu các kiến thức đó có chuẩn xác và cập nhật chưa .',
#  'giáo viên có phong cách giảng dạy nghiêm túc .',
#  'cô rất vui tính nà , không khí lớp lúc nào cũng vui hết , cô dạy rất hay , dễ hiểu !',
#  'giảng viên giảng dạy rất tốt , thường xuyên cung cấp thêm nhiều kiến thức .',
#  'thầy luôn nhiệt tình , có những chia sẻ rất gần gũi với sinh viên .',
#  'có khả năng truyền đạt tốt .',
#  'thậm chí còn không có bài nào khó bằng các bài trong nội dung của lớp chuyên tin ở các trường cấp 3 .',
#  'thầy dạy tận tụy và tâm huyết .',
#  'thầy nên có cách dạy mới cho môn học này để được kết quả tốt cho tất cả mọi người thay vì để rớt rất nhiều người !',
#  'lịch thi thực hành cần được thông báo sớm tới sinh viên và phù hợp với thời gian môn học .',
#  'cô nên giảng kỹ và chi tiết từng bài vì nhiều bài đa số các bạn chưa hiểu thì cô lại giảng nhanh để chuyển qua bài khác .',
#  'dạy tốt đúng trọng tâm những gì cần biết .',
#  'nhiệt tình , lên lớp đúng giờ , dạy dễ hiểu .',
#  'nếu em buồn ngủ , dù lên lớp em vẫn sẽ ngủ , mà ngủ ở trên lớp thì đau lưng và tê chân lắm .',
#  'cơ mà em học môn này em hiểu colonlove .',
#  'thiếu kinh nghiệm truyền đạt .',
#  'bài giảng thú vị .',
#  'em nghĩ nội dung thực hành nên gần với đồ án hơn .',
#  'thầy nhiệt huyết và giảng bao quát đề cập đến nhiều khía cạnh của bài học vấn đề .',
#  'giảng viên giảng bài kỹ .',
#  'hệ thống đồ án chấm điểm theo mức độ hoàn thành của sinh viên , tạo sự ganh đua không hề nhẹ với những nhóm làm chung đồ án , kích thích sáng tạo không ngừng tìm hiểu xây dựng thêm chức năng mới cho đồ án nếu muốn được điểm cao .',
#  'nhiệt tình , tâm huyết .',
#  'ít chú trọng phần ngữ pháp .',
#  'giảng viên còn chưa tận tâm , phong cách giảng dạy chưa thu hút được sinh viên .',
#  'giảng rất dễ hiểu , hướng dẫn làm thực hành tốt .',
#  'thầy dạy rất nhiệt tình , khi dạy thầy luôn đi tới từng sinh viên để hướng dẫn .',
#  'giảng viên nhiệt tình trong giảng dạy và chấm điểm .',
#  'cách truyền đạt kiến thức đối với em là rất hiệu quả , trao đổi bài với sinh viên , cô rất nhiệt tình !',
#  'giảng dạy hay , dễ hiểu , tận tình .',
#  'kiến thức rộng , kinh nghiệm thực tế nhiều , truyền cảm hứng cho sinh viên .',
#  'cách dạy sáng tạo .',
#  'giảng bài dễ tiếp thu .',
#  'em rất hài lòng với cô .',
#  'thầy dạy dễ hiểu , sinh động .',
#  'cô chưa nắm bắt được thực trạng học của sinh viên .',
#  'ảnh hưởng đến tiến độ học tập và quỹ thời gian của sinh viên ( do học bù ) .',
#  'cô giảng bài dễ hiểu .',
#  'điều em hài lòng nhất đó là thầy đi rất đúng giờ và không dạy quá nhanh .',
#  'nên có giáo trình thống nhất cho tất cả các lớp và học kỳ học .',
#  'em nghĩ cần có các bài tập lớn để nâng cao khả năng lập trình của các sinh viên .',
#  'rất nhiệt tình với sinh viên .',
#  'giảng viên có phương pháp giảng dạy hay , cập nhật , phù hợp với sinh viên .',
#  'giảng dạy tốt và có tâm .',
#  'dạy lý thuyết hơi nhiều .',
#  'giảng viên chấm bài quy chụp theo kết quả .',
#  'thời lượng môn học quá dài , sinh viên cảm thấy mệt mỏi .',
#  'giảng viên vui tính dễ tương tác với sinh viên .',
#  'nhiệt tình hay giúp đỡ sinh viên khi không biết , cho nhiều bài tập .',
#  'thầy cho điểm phần nào còn theo cảm tính , chưa được công bằng .',
#  'thầy giảng dạy rất nhiệt tình .',
#  'thầy nhiệt tình , bài giảng phong phú đa dạng .',
#  'không có gì đặc biệt .',
#  'mỗi tháng chỉ gặp giảng viên một lần rất khó cho việc học hỏi , hướng dẫn từ giáo viên .',
#  'thầy nên chuẩn bị riêng một slide cho mình để giảng dạy , không nên lấy slide của người khác rồi đến khi sơ sót , thầy lại lấy cái lý do " đây không là slide của tôi " , " cái này tôi cũng không rõ nữa " .',
#  'thầy cho làm các bài tập tại lớp trong khi sinh viên chưa biết gì về vấn đề đó .',
#  'đôi khi đi quá sâu vào một vấn đề bên lề .',
#  'giảng viên dạy tận tâm , nhiệt tình , dễ hiểu .',
#  'cô thật nhiệt tình .',
#  'phòng thực hành tốt .',
#  'nói chuyện lan man , không liên quan đến môn học quá nhiều .',
#  'giảng viên rất tận tâm .',
#  'phân bổ hợp lý thời gian học và nên cho xem nhiều video hơn là nghe .',
#  'thầy bận nhiều nên cũng nghỉ nhiều , hi vọng thầy có thể sắp xếp thời gian .',
#  'giáo viên sử dụng giờ trên lớp hiệu quả .',
#  'giáo viên tận tình , dạy truyền đạt tốt .',
#  'giảng viên dạy tốt , nhiệt tình .',
#  'giảng viên tạo cảm hứng cho sinh viên học tập .',
#  'chán .',
#  'thầy nhiệt tình , tận tâm giúp đỡ sinh viên .',
#  'dạy quá chậm , quá cặn kẽ .',
#  'thầy wzjwz174 ít cho bài tập về nhà .',
#  'thầy đôi khi nói hơi khó hiểu .',
#  'giảng viên tận tâm , nhiệt tình , hỗ trợ giải đáp thắc mắc môn học cho sinh viên .',
#  'nên đi sâu vào vấn đề , giúp sinh viên hiểu tốt môn học , và nên có những ứng dụng cụ thể mà môn học đem lại .',
#  'làm bài tập .',
#  'cứ ngỡ được 10 điểm là chắc chắn rồi .',
#  'thầy yêu cầu quá cao đối với một sinh viên có thể tiếp thu mọi kỹ năng cần truyền đạt vào một đồ án .',
#  'thêm phòng thiết bị để thực hành .',
#  'dễ hiểu đầy đủ .',
#  'điểm .',
#  'giáo viên tốt bụng , vui tính .',
#  'slide quá khó hiểu , nhiều chỗ không giải thích rõ ràng , đặc biệt là các bài hướng dẫn thực hành .',
#  'nói rõ mục tiêu cũng như các bước làm của lab , khối lượng bài tập vừa phải .',
#  'giải đáp kịp thời những thắc mắc cho sinh viên .',
#  'giảng viên nhiệt tình , phương pháp dạy dễ tiếp cận , dễ hiểu .',
#  'phòng học cần lắp thêm quạt và ổ cắm vì sinh viên phải sử dụng laptop để làm bài tập , cần có thêm màn che cửa sổ để có thể theo dõi bài giảng trên slide tốt hơn .',
#  'bài tập không cho ví dụ về nhà để xem lại .',
#  'giảng viên thiếu rất nhiều hoạt động để việc học bớt nhàm chán khi quá bám sát bài học .',
#  'thầy dạy dễ hiểu , rất hài lòng .',
#  'micro và các thiết bị âm thanh , máy chiếu cần nâng cấp .',
#  'cách giảng bài dễ hiểu , hay .',
#  'đầy đủ kiến thức .',
#  'chất lượng phòng máy rất tệ .',
#  'thầy giảng ngắn gọn , đầy đủ .',
#  'tốt giỏi chu đáo .',
#  'tuy có phần chém gió kinh điển nhưng kiến thức , hiểu biết rộng , đặc biệt về công nghệ .',
#  'chờ học sinh gửi email mới show được slide to lên , giảng cho qua loa không hỏi học sinh có hiểu gì hay không ?',
#  'tạo niềm vui cho bọn em tuy lý thuyết bọn em rất đuối sức .',
#  'nhiệt tình , truyền cảm hứng .',
#  'thầy hài hước , giọng truyền cảm .',
#  'thầy dạy rất nhiệt tình , tâm huyết , dễ hiểu .',
#  'không hiểu cách chấm bài thi của thầy .',
#  'tiết học chưa được thu hút .',
#  'giảng viên nên thay đổi phương pháp giảng dạy để tương tác nhiều hơn với sinh viên .',
#  'cần vào thẳng nội dung .',
#  'thầy đẹp trai , dạy dễ hiểu , hay trò chuyện thực tiễn với học sinh .',
#  'cô dạy trên lớp và thực hành tận tâm .',
#  'em rất hài lòng về thầy .',
#  'thầy quá bảo thủ , thầy luôn cho rằng ý kiến của thầy là đúng nhất , ngoài ra mọi ý kiến khác đều sai .',
#  'thầy wzjwz252 giảng bài rất thu hút , kiến thức thầy rất rộng , luôn giải đáp thắc mắc cho sinh viên .',
#  'giảng viên rất hòa đồng vui vẻ , nhiệt tình trong giảng dạy .',
#  'giảng viên tận tâm , tạo điều kiện cho học sinh làm bài tập .',
#  'cần giải bài tập nhiều hơn .',
#  'kiến thức thực tiễn của thầy rộng , giảng dạy vui vẻ .',
#  'cô cũng không cung cấp hay giải thích gì đáp án của bài thi .',
#  'thầy rất nhiệt tình , nói rất nhiều đến khản giọng mà sức truyền tải không bằng thầy wzjwz159 .',
#  'kiến thức giảng dạy môn tiếng anh hầu như không giúp ích nhiều cho sinh viên trong việc tìm hiểu các tài liệu chuyên ngành .',
#  'thấy rất hiền , rất chi là hơi trẻ con .',
#  'giảng dạy hay , dễ hiểu , cuốn hút sinh viên .',
#  'cách tìm kiếm chúng ở đâu , khai thác chúng ở đâu chứ không phải là phải nhớ mấy cái phương thức hay các hàm rồi viết lên giấy vào đề thi cuối kỳ .',
#  'giảng hơi nhanh , chưa kỹ lắm .',
#  'những phần trọng tâm bài tập thì cũng không nói được " đây là phần quan trọng có trong đề thi các em cần chú ý " .',
#  'nghe , nói luyện tập cao .',
#  'giáo viên giảng hay dễ hiểu .',
#  'sử dụng phần mềm crack .',
#  'nhiều khi dạy quá thời gian .',
#  'tuy dạy chậm giúp học sinh dễ hiêu tuy nhiên nhiều bài khó thì sẽ khiến sinh viên dễ chán .',
#  'thầy vui tính , thương sinh viên , dạy dễ hiểu .',
#  'thầy bằng nhiệt tình tận tụy với sinh viên trong việc hướng dẫn đồ án .',
#  'dạy dễ hiểu , thân thiện .',
#  'có các phần ôn tập không liên tới bài kiểm tra .',
#  'không nên tổ chức thực hành hình thức 2 .',
#  'sự thân thiện và tận tình đối với học viên .',
#  'thầy giảng bài nhiệt tình , gần gũi với sinh viên , nội dung không hiểu có thể hỏi ngay thầy tại lớp .',
#  'giảng viên cần nắm vững xem sinh viên có hiểu được bài hay không và đưa ra phương án để sinh viên nắm vững kiến thức .',
#  'thầy thiện nhiệt tình .',
#  'truyền đạt thực tiễn vấn đề .',
#  'giáo viên rất nhiệt tình và tâm huyết đối với sinh viên .',
#  'âm thanh thầy giảng hơi nhỏ , khó khăn trong việc nghe giảng .',
#  'nên thay đổi hình thức khảo sát với môn học này thì môn học này không có lên lớp và chỉ có đến hạn thì báo cáo với giảng viên .',
#  'sinh viên hỏi , nhận câu trả lời cũng như không hỏi .',
#  'thầy dạy khá nhiệt tình , vui tính .',
#  'em nghĩ chỉ nên bắt buộc các bài tập có dạng căn bản , còn bài tập tương tự thì chỉ khuyến khích sinh viên làm thêm .',
#  'thầy dạy rất hay ạ !',
#  'không thống nhất trước về hình thức thi và làm bài tập , đến những tuần cuối cùng mới công bố .',
#  'nhằm giảm thời lượng giảng dạy cũng như sự thú vị khi học môn toán .',
#  'giảng viên dạy nhiệt tình , dễ hiểu .',
#  'em mong cô cũng như toàn thể các giảng viên hãy xem xét lại việc điểm danh vì đại học dù sao cũng là tự học chứ không phải như là phổ thông nữa .',
#  'cô cực kỳ nhiệt huyết , cô rất dễ thương colonlove cô yêu học trò của mình , cô cực kỳ khách quan , phong cách làm việc của cô rất giống người nước ngoài , em thích cô .',
#  'giảng viên nhiệt tình , tận tâm với công việc , slide dễ hiểu , hoạt động học tập sôi nổi .',
#  'chú ý giữ sức khỏe , nhất là cổ họng colonsmile .',
#  'thầy tận tâm , nhiệt tình .',
#  'máy ở phòng thực hành quá tệ .',
#  'thầy rất dễ thương .',
#  'giảng viên nhiệt tình , thân thiện .',
#  'thầy truyền đạt rất tận tình , dễ hiểu lượng bài tập , nội dung thi hợp lý , vừa sức với sinh viên .',
#  'giảng viên nên đến đúng giờ hơn và cho nhiều bài tập hơn .',
#  'em thấy những nội dung như vậy rất mơ hồ , có tính áp đặt suy nghĩ cho người học .',
#  'cần nâng cấp máy tính trong phòng thực hành , nhiều kit de2 bị lỗi cần sửa chữa hoặc thay mới .',
#  'em thấy môn này nhiều lý thuyết không đáp ứng đủ trong việc làm đồ án .',
#  'tạo điều kiện cho sinh viên làm việc nhóm .',
#  'phương pháp dạy chưa hay .',
#  'hay bị về trễ colonsad .',
#  'cần dạy chi tiết hơn .',
#  'cô giảng rất nhiệt tình .',
#  'dạy rất chi tiết và đầy đủ những kiến thức quan trọng .',
#  'đề thi thực hành cần nêu yêu cầu cụ thể , rõ ràng hơn .',
#  'giọng của giảng viên rất khó nghe nên không thể nghe giảng hết những điều thầy nói .',
#  'giảng dạy hay , nhiệt tình .',
#  'giảng viên biết cách truyền đạt , giảng rất hay và dễ hiểu .',
#  'dạy hơi nhiều , và hơi nhanh .',
#  'nên tạo không khí thoải mái cho tiết học để sinh viên dễ hiểu bài và thêm yêu thích môn học của giảng viên .',
#  'giảng dạy tận tâm .',
#  'cả năm toàn học vòng lặp " if " " for " " while " đến bữa cuối mới lơ mơ học được struct với tạo file header mà ra đề 5 điểm trong phần đó .',
#  'gần gũi , thân thiện với sinh viên , khả năng truyền đạt kiến thức tốt .',
#  'quá dễ dẫn đến buồn ngủ .',
#  'giảng viên không có tính hài hước .',
#  'vui tính , nhiệt tình .',
#  'thầy vui tính , giảng bài hay , đưa nhiều thông tin thực tế vào bài giảng .',
#  'thẩy wzjwz311 rất vui và nhiệt tình .',
#  'giáo viên giảng dạy lôi cuốn .',
#  'nhiệt tình , dễ gần , truyền đạt tận tâm .',
#  'phương pháp truyền đạt của giảng viên chưa hiệu quả lắm .',
#  'giáo viên chưa tạo được không khí vui vẻ trong lớp học .',
#  'thầy giúp em biết mạch số là gì .',
#  'có lúc thầy lạc đề .',
#  'thầy dạy hơi chậm .',
#  'lần được học thầy , thấm nhiều thứ quá .',
#  'nhiều phần trong slide bài giảng của giảng viên không chính xác .',
#  'môn học cần phân chia hợp lý giữa các phần , phần nào khó cần nhiều thời gian để học nó , phần nào đã học thì chỉ ra những điểm đặc biệt cũng như thời gian học phần đó rút ngắn lại để các phần chưa học khác sẽ có thời gian nhiều hơn .',
#  'thực hành đúng tiêu chí môn học , đi từ dễ đến khó cho sinh viên học tập từng bước dễ hiểu , giảng viên tích cực giải đáp thắc mắc và hỗ trợ sinh viên trong giờ thực hành .',
#  'dạy dễ hiểu , sâu rộng .',
#  'thầy dạy nhiệt tình , vui vẻ .',
#  'thầy cực kỳ tâm lý , vui tính , dạy nhiệt tình và tận tụy với học trò .',
#  'thầy luôn chủ động tạo tranh luận và kiểm tra bài tập đầu giờ để sinh viên dễ dàng nắm bắt kiến thức .',
#  'nội dung tiết học còn lan man , cảm tưởng như thầy đang dạy về tiếng anh chuyên ngành , chứ không đào sâu về kỹ thuật .',
#  'nên tự tin hơn trong việc giảng dạy .',
#  'giảng viên có cập nhật thông tin mới nhất về tình hình thực tế .',
#  'giáo viên rất nhiệt tình đối với sinh viên .',
#  'cảm thấy hứng thú khi lên lớp .',
#  'cùng một kiến thức nhưng cách truyền đạt của thầy dễ hiểu hơn , phù hợp với đại đa số sinh viên và tất nhiên là hữu dụng cho các môn khác chứ không hề lan man , thiếu trọng tâm như các giảng viên toán khác .',
#  'giảng viên chưa bám sát được sinh viên .',
#  'nhiều lúc thầy vẫn nói lý thuyết nhiều gây nhàm chán .',
#  'phần kiểm tra , thi cử đối với môn này nên đề cao tính tư duy logic của người học cũng như khả năng áp dụng kiến thức đã học vào thực tế thực nghiệm bằng cách chủ yếu đánh giá cao phần thực hành , viết code , làm project .',
#  'do môn còn mới nên nhiều vấn đề trục trặc trong quá trình thực hành thầy vẫn chưa giải quyết được , nhưng vẫn rất ủng hộ thầy .',
#  'luôn đảm bảo giờ giấc trong tiết học .',
#  'phòng lab chán lắm , hư hỏng hết cả .',
#  'nội dung môn học còn khô , cứng !',
#  'cô nói hơi nhỏ nên hơi buồn ngủ .',
#  'có lúc dạy khó hiểu .',
#  'thầy cho bài tập lạ , đa dạng .',
#  'sau khi đã học xong môn nhập môn điện tử , em thiết nghĩ môn học này cần có thêm những phần học về thực tế , để sinh viên chúng em có thêm động lực khi học những phần lý thuyết đôi khi " khô khan " và " xa lạ " đồng thời sẽ tạo được sự đam mê với bộ môn điện tử nói chung ngay từ những ngày đầu học " nhập môn " .',
#  'giáo viên vui tính , tích cực .',
#  'thầy dạy nghiêm túc .',
#  'cơ sở dữ liệu năm nay đã kết hợp với thiết kế cơ sở dữ liệu rồi , kiến thức nhiều mà thi có phần trắc nghiệm nữa thì đánh giá kiến thức học được chưa đảm bảo cho lắm ạ .',
#  'nội dung có liên hệ nhiều với thực tế .',
#  'nhiệt tình , luôn luôn giúp học sinh hiểu vấn đề cặn kẽ .',
#  'ra đề thì phải có đáp án , để sinh viên tập dần thói quen đọc code .',
#  'em nghĩ là cần thêm bài tập trên lớp và giải ngay trên lớp .',
#  'môn học chỉ nên thuyết trình tìm hiểu về egov không làm đồ án .',
#  'giảng viên có nhiều phương pháp giảng hay .',
#  'thực hành hình thức 2 khó có thể tham gia học thường xuyên lắm ạ !',
#  'cô giảng rất hay , rất nhiệt tình khi giảng dạy , rất vui tính .',
#  'giáo viên luôn chia sẻ những ứng dụng của kiến thức đã học với thực tiễn , chia sẻ khá nhiều kinh nghiệm thực tế vô cùng bổ ích với sinh viên .',
#  'thầy dạy nhiệt tình , rất chu đáo .',
#  'thầy dạy rất nhiệt tình với sinh viên .',
#  'em thấy rất hài lòng về môn học này , nên em không có ý kiến gì khác cả .',
#  'bàn ghế còn bụi .',
#  'cô vui tính , dạy tốt .',
#  'nhiệt tình , giỏi hay giúp đỡ sinh viên và cho nhiều bài tập .',
#  'kể chuyện hay .',
#  'tôi đã thấy giảng viên chỉ nhìn qua chưa đầy 30 giây và cho điểm 9 ngay lập tức .',
#  'phòng thực hành nên nâng cấp máy tính .',
#  'thầy ít khi nhắc lại về phần đã dạy hôm trước .',
#  'thầy nên tham gia thực hành cùng sinh viên , không phải là chỉ ngồi một chỗ , tụi em tự mày mò làm xong rồi thầy mới xuống chấm điểm .',
#  'mong muốn giảng viên nào cũng áp dụng như vậy thì quá tốt .',
#  'giảng viên cần chuẩn bị giáo án trước khi đến lớp , giảng viên diễn đạt không tốt cần phải học cách diễn đạt cho sinh viên dễ hiểu .',
#  'cần học môn lập trình trực quan trước .',
#  'cách truyền đạt kiến thức kém hiệu quả , cô dạy giống như là không dạy , chỉ đọc chữ trong slide rồi cho sinh viên làm bài tập .',
#  'làm tốn thời gian truyền đạt , dẫn đến hứng thú lên lớp nghe giảng bị hạn chế .',
#  'thầy luôn tạo cơ hội để sinh viên có thể được thực hành .',
#  'thêm phần anh văn chuyên ngành vào nội dung học .',
#  'cảm ơn cô và chúc cô nghỉ đẻ vui vẻ , mẹ tròn con vuông !',
#  'thầy dạy tốt , giảng dễ hiểu .',
#  'mở rộng kiến thức nâng cao cho sinh viên .',
#  'chưa có thời gian cho sinh viên ngẫm nghĩ điều mình mới học mà đã qua nội dung khác để theo kịp chương trình .',
#  'dạy dễ hiểu .',
#  'thầy vui vẻ , thoải mái .',
#  'thầy tận tâm , dạy dễ hiểu , vui tính , lớp học thoải mái dễ tiếp thu .',
#  'em thích học môn này với cô wzjwz157 .',
#  'cô tận tình hướng dẫn chỉ bảo .',
#  'cập nhật điểm thi giữa kỳ chậm , nên sinh viên không biết mức độ phấn đấu như thế nào !',
#  'giảng dạy tận tâm , nhiệt tình , dễ hiểu .',
#  'đôi khi trong giờ học kể vài chuyện về đời để đỡ chán =) .',
#  'thầy không vui tính .',
#  'giảng nhiều phần nâng cao làm sinh viên bối rối .',
#  'thầy dạy vui vẻ .',
#  'cô dạy dễ hiểu , hỗ trợ tốt cho các bạn .',
#  'thời gian nộp bài tại lớp hơi ngắn .',
#  'cần có sách học hay , chi tiết , hiệu quả colonsmilesmile .',
#  'phương pháp giảng dạy còn khó hiểu .',
#  'tận tình chu đáo .',
#  'nội dung lý thuyết và thực hành của môn học không có bất kỳ liên hệ gì với nhau nội dung lý thuyết không phù hợp với môn học và không tạo được sự quan tâm và mong muốn của sinh viên về kiến thức quản trị mạng như mong đợi .',
#  'cần có khả năng truyền đạt tốt hơn !',
#  'giảng viên dạy có hiệu quả cao , mang tính thực tiễn .',
#  'giáo viên truyền đạt kiến thức đầy đủ , dễ hiểu , nhiệt tình giảng dạy .',
#  'em xin lỗi nhưng đó là sự thật !',
#  'cô tận tâm , hỗ trợ nhiệt tình .',
#  'không có giáo trình .',
#  'phương pháp tư duy cho sinh viên , để sinh viên tự giải quyết các vấn đề .',
#  'giảng dạy dễ hiểu , linh động trong nhiều bài tập .',
#  'giảng viên giảng dạy tận tình , vui vẻ giúp học viên nhận thức được nhiều kiến thức .',
#  'cải thiện chất lượng phòng máy thực hành .',
#  'nếu được chọn , cô luôn là lựa chọn hàng đầu cho các môn kinh tế .',
#  'cần thêm bài tập và rèn luyện kỹ năng giao tiếp .',
#  'nhiệt tình giảng dạy .',
#  'thoải mái về thời gian .',
#  'em còn chưa thấy mặt thầy nữa , hoặc có nhưng quên rồi colondoublesurprise .',
#  'các nội dung môn học thầy triển khai không đúng theo khung , mới vào mà thầy dạy servlet thì rất khó hiểu , sinh viên có góp ý qua thầy chủ nhiệm nhưng vẫn không thay đổi .',
#  'mọi việc điều được sinh viên tự học , tự tìm hiểu thông qua các trang mạng , thông qua việc email trực tiếp với giảng viên .',
#  'slide bài giảng còn lẫn lộn anh việt , phần tiếng việt thì giảng viên lại dùng google dịch nên đọc không hiểu .',
#  'cách truyền đạt tốt , tận tâm .',
#  'cô rất nhiệt tình và thân thiện với sinh viên .',
#  'giảng viên tận tâm với việc dạy học , tạo cảm hứng học tập cho sinh viên .',
#  'cần cho nhiều thời gian để sinh viên có đủ thời gian hoàn thành đồ án môn học .',
#  'thầy rất vui tính , truyền tải thông tin tuyệt vời .',
#  'đôi lúc hỏi một số câu hỏi rất mơ hồ khiến sinh viên không biết đang được hỏi về khía cạnh nào , cũ hay mới ( chương trước hay chương hiện tại ) .',
#  'hy vọng thầy sẽ cải tiến làm cho hoạt động sôi nổi hơn .',
#  'quá nhàm chán , không nâng cao được kiến thức .',
#  'thầy dạy khá nhiệt tình vui tính .',
#  'thầy khá nhiệt huyết và gần gủi với sinh viên .',
#  'bài tập khắt khe .',
#  'theo thời khóa biểu hiện nay thì học thực hành trước nên sinh viên lúc thực hành chưa hiểu vấn đề nên khó khăn trong việc làm bài .',
#  'cô nên tăng tốc độ giải bài hơn .',
#  'tài liệu tiếng anh gây khó khăn cho ôn thi .',
#  'giảng dạy tận tình , vui vẻ .',
#  'giảng viên dạy có tâm huyết , kỹ càng với sinh viên , nhiệt tình giúp đỡ .',
#  'khả năng truyền đạt kiến thức không cao .',
#  'cần nâng cao chất lượng trang thiết bị .',
#  'giảng viên vui tính , thân thiện .',
#  'đầu tư các thiết bị cho sinh viên mượn , như điện thoại android , windows phone .',
#  'thầy dạy tốt và tâm huyết .',
#  'việc phân chia nhóm không hợp lý dẫn tới chất lượng học tập không tốt .',
#  'thầy nhiệt tình , vui vẻ .',
#  'tận tâm nhiệt tình , giảng giải cho sinh viên chưa hiểu tỉ mỉ .',
#  'phần máy tính không hỗ trợ cho việc học nhiều , chỉ làm sinh viên phân tán .',
#  'sự nhiệt tình , tâm huyết .',
#  'đó là tiền của họ , họ muốn dùng thì tùy họ , người khác nghèo không phải lỗi của họ , chưa kể tiền thuế họ đóng góp cho nước cũng đủ để gọi là xây dựng rồi .',
#  'các dạng bài tập rõ ràng , tài liệu cung cấp đầy đủ .',
#  'giảng viên dạy tận tình , cung cấp đầy đủ kiến thức cho sinh viên .',
#  'cần tăng thời gian học .',
#  'nên tổ chức thêm những buổi hội thảo liên quan đến nội dung môn học .',
#  'dạy đúng trọng tâm .',
#  'đề nghị thầy share slide giảng dạy trên lớp .',
#  'nên trang bị trang thiết bị cho phòng thực hành và phòng lab để sinh viên có thể thực hành và học trực tiếp trên thiết bị thật .',
#  'thầy giảng dạy rất nhiệt tình và vui tính .',
#  'nên cải tiến hệ thống chấm điểm online , update bài tập cho tất cả học sinh làm rồi có bảng xếp hạng , như bên codefun của miền bắc .',
#  'bài giảng thực tế .',
#  'kiến thức thầy dạy rất hay và bổ ích .',
#  'hạn chế dạy bằng slide .',
#  'nói sâu về vấn đề khó .',
#  'thầy lên lớp không đúng giờ giấc , thường xuyên đi trễ .',
#  'chất lượng phòng máy kém .',
#  'phong cách giảng dạy rất hay .',
#  'giáo viên giảng dạy sử dụng nhiều ví dụ thực tiễn .',
#  'cần tuân thủ đúng và đủ giờ .',
#  'thầy rất nhiệt tình và năng động , học thầy có thêm nhiều kiến thức mới không chỉ gói gọn trong nội dung môn học .',
#  'thầy giảng bài kỹ , dễ hiểu !',
#  'nhiệt tình giảng dạy , giải đáp thắc mắc rất chi tiết , cung cấp đầy đủ kiến thức cần thiết để kiểm tra .',
#  'thầy giảng nhanh và cách truyền đạt hơi khó hiểu , đưa ra khá ít ví dụ để sinh viên có thể hiểu bài rõ hơn .',
#  'các giảng dạy của giảng viên còn khó hiểu , rối rắm .',
#  'điện thoại không liên lạc được .',
#  'chưa học nhiều với thầy nên chưa có ý kiến gì về thầy .',
#  'nội dung thực hành nên thay đổi doubledot mỗi tuần thực hành các phần lý thuyết trên lớp và giảng viên hướng dẫn làm đồ án cuối kỳ .',
#  'giảng viên tăng cường giải đề của các năm .',
#  'thiếu thiết bị thật để thực hành .',
#  'nhiệt tình giúp đỡ sinh viên .',
#  'giảng bài rất dễ hiểu .',
#  'thực sự em vẫn chưa hiểu ngoài việc để làm bài tập thì wireshark được dùng để làm việc gì khác .',
#  'em nghĩ cơ sở vật chất vẫn còn yếu kém , ngồi xa không thể nhìn rõ được slide bài giảng của cô giáo , phòng học rất nóng .',
#  'thầy giải nhiều bài tập cho sinh viên giúp sinh viên củng cố kiến thức sau khi học lý thuyết .',
#  'cô rất vui vẻ , nhiệt tình , tâm huyết .',
#  'cần có các thiết bị di động thật để sinh viên thực hành khi cần thiết , vì các chương trình mô phỏng trên máy tính là không đầy đủ .',
#  'thầy dạy dễ hiểu , code mẫu đầy đủ .',
#  'điều em hài lòng nhất đó là thầy với tốc độ phù hợp và rất dễ hiễu .',
#  'nên thống nhất lại nội dung môn học so với cách thi của phòng đào tạo .',
#  'thầy dạy hay , nhiệt tình , không bao chê bai sinh viên dù mặc dù không tốt mà hướng sinh viên đến suy nghĩ tích cực hơn , cố gắng hơn .',
#  'giảng dạy nhiệt tình , quan tâm tới sinh viên .',
#  'cần tăng chú ý về kỹ năng cần thiết trong toeic như nghe , đọc .',
#  'kính mong giảng viên có thể cho thêm nhiều bài tập nhằm giúp sinh viên luyện tập , nắm bắt nội dung môn học và vận dụng nó hiệu quả hơn , giúp ích cho việc học các môn sau này .',
#  'cần chú trọng hơn vấn đề học thực hành phòng máy không đáp ứng yêu cầu doubledot không có trình biên dịch giáo viên thực hành không sử dụng hiệu quả giờ thực hành .',
#  'thầy wzjwz239 nói chuyện cọc lốc , không hiểu vấn đề gì hỏi thầy thì thầy lại như quát vào mặt , tạt nước lạnh , … nói chuyện xưng hô mày - tao ( có lúc thì xưng tớ - cậu nhưng lời nói đầy ẩn ý ) , hay nói móc và tìm cách bắt bẻ sinh viên .',
#  'thầy có hướng dẫn đồ án rất tận tình , luôn giải đáp các câu hỏi và thắc mắc của sinh viên về đồ án rất nhanh .',
#  'giúp sinh viên cảm thấy thoải mái trong giờ học .',
#  'cô giảng dạy tận tình .',
#  'hơi khó tính ạ .',
#  'kiến thức nhiều , khó tiếp thu , phân loại chưa rõ .',
#  'thầy nên cho thêm bài tập về nhà .',
#  'những điều này nghe tưởng chừng không liên quan đến môn học , nhưng lại giúp cho sinh viên phần nào có định hướng được công việc tương lai của mình .',
#  'em học ở phòng mà bên cạnh là công trình đang thi công , khá là ồn ào , vì thế khi học đến phần nghe , em không thể nghe được gì , và bài nghe bị gián đoạn .',
#  'thầy không sửa bài tập , trên lớp thầy chỉ giảng lý thuyết theo em như thế là ít có hiệu quả .',
#  'thầy ít quan tâm .',
#  'giảng dạy tích cực , dễ hiểu .',
#  'không dùng điểm để đánh giá , nó làm sinh viên không dám thực hiện .',
#  'dạy hay , dễ hiểu , tận tình .',
#  'không khí lớp học thì không được sôi nổi .',
#  'bài tập thực hành mỗi tuần hơi khó , mong rằng ở mỗi bài tập giảng viên có thể cung cấp bài giải kỹ càng để sinh viên có thể nghiên cứu và hiểu được cách làm .',
#  'thầy rất thoáng và thoải mái .',
#  'thầy cần có tương tác với sinh viên qua mail hay moodle vì có đôi lúc có thắc mắc nhưng thầy không phản hồi .',
#  'kiến thức đơn giản .',
#  'phần lý thuyết lặp lại nên chán , không thu hút .',
#  'thầy dạy rất hay và rất nhiệt tình .',
#  'giảng viên giảng dạy theo đúng thời gian môn học .',
#  'thầy rất dễ gần .',
#  'khi sinh viên hỏi phải có câu trả lời chính xác không được bỏ qua những câu hỏi của sinh viên .',
#  'chấm điểm dựa trên mức độ thấu hiểu bài , hay đưa ra lời khuyên hữu ích .',
#  'luôn nhiệt tình trong giảng dạy .',
#  'thầy vui vẻ .',
#  'giảng bài kỹ càng , dễ hiểu .',
#  'cần tăng thời gian thực hành nói lên .',
#  'cô giảng dạy rất nhiệt tình và dễ hiểu .',
#  'giảng dạy tốt .',
#  'nhiệt tình , cô dễ thương =) .',
#  'giảng viên dạy truyền cảm hứng , sử dụng thời gian hợp lý .',
#  'giảng viên dạy tận tâm nhiệt tình .',
#  'thì có thể lướt nhanh hơn vì phần này khá dễ .',
#  'giảng viên có chuyên môn rất tốt , kiến thức rộng , giải đáp được mọi thắc mắc của sinh viên .',
#  'giảng viên hiền lành , nhiệt tình giúp đỡ khá nhiều cho sinh viên khi sinh viên không hiểu bài .',
#  'giảng viên rất tận tình !',
#  'thầy rất nhiệt tình , năng nổ .',
#  'truyền đạt có cảm hứng , hướng dẫn sinh viên học tập thế nào sau khi ra trường để xin việc .',
#  'học thoải mái , ít áp lực .',
#  'cô dễ thương và giảng bài tận tình .',
#  'cô dạy rất tốt , nhiều bài tập .',
#  'thầy giảng dạy nhiệt tình dễ hiểu , sửa bài tập cẩn thận .',
#  'giảng viên rất đảm bảo giờ lên lớp .',
#  'thầy là giảng viên dạy toán hay nhất trường .',
#  'môn học này thật sự rất khó và chương trình học hơi nặng , lúc trước môn này dược chia ra làm 2 môn là cấu trúc dữ liệu 1 và cấu trúc dữ liệu 2 , năm nay lại gộp thành một nên sinh viên khó tải nổi kiến thức .',
#  'cần kết nối được mạng trong phòng lab .',
#  'nhiệt tình , phương pháp giảng dạy rất hiệu quả cách truyền đạt rất dễ hiểu và dễ tiếp thu biết cách truyền cảm hứng và tạo động lực học tập cho sinh viên .',
#  'luyện nghe nhiều hơn .',
#  'giảng viên giảng dạy rất truyền cảm , tạo cảm giác ham học và hệ thống bài tập dồi dào phong phú .',
#  'thầy có cách giảng bài rất hay và dễ hiểu .',
#  'thầy dạy bằng slide bài giảng hơi nhanh .',
#  'cách dạy của cô hay , thú vị , tạo động lực .',
#  'thầy dạy vui vẻ , không có áp lực quá khắt khe .',
#  'giải thích cặn kẽ đi sâu hơn nữa .',
#  'cho bài tập nhiều em rất thích colonsmile .',
#  'giảng viên vui vẻ nhiệt tình .',
#  'giảng viên nhiệt tình , phương pháp giảng dạy dễ hiểu .',
#  'giảng viên rất tâm huyết và nhiệt tình , giảng bài dễ hiểu .',
#  'thầy wzjwz127 dạy rất nhiệt tình .',
#  'cô nhiệt tình và đưa ra bài giảng hợp lý , dễ hiểu , có thể vận dụng làm bài .',
#  'giảng viên dạy nhiệt tình , truyền đạt kiến dễ hiểu .',
#  'thời gian học tập luôn thiếu sót , giảng viên chưa nhiệt tình giảng dạy .',
#  'rất thích được học cô .',
#  'tiếp cận với sinh viên một cách thân thiện , phương pháp dạy khoa học , dễ tiếp thu , dễ hiểu .',
#  'chữ viết nhỏ .',
#  'thường xuyên cho nghỉ mà không thông báo .',
#  'dạy hơi cao so với năng lực .',
#  'giáo viên nhiệt tình , tận tâm giúp đỡ sinh viên .',
#  'thích thầy chia sẻ kinh nghiệm .',
#  'quá khó tính , giờ cao su , giảng dạy lan man không hiệu quả .',
#  'giảng viên giảng không hay , đã vậy còn không nhiệt tình , không vui vẻ , không tạo cơ hội cho sinh viên hỏi về bài giảng .',
#  'thầy dạy không có sức hút , nhàm chán , gây buồn ngủ cho sinh viên .',
#  'thầy thật sự là một giảng viên dạy học rất có tâm .',
#  'thầy dạy nhiệt tình , rất hăng hái .',
#  'giọng cô êm êm , dễ buồn ngủ .',
#  'truyền đạt nhiều kinh nghiệm tốt cho sinh viên .',
#  'khi phản ánh kết quả bài tập không đúng thì cô lại lơ , cười rồi bỏ đi , không có một đáp án cụ thể .',
#  'thầy khá hài hước , nói những việc thực tế về ngành it , rất thiết thực .',
#  'thầy wzjwz177 rất gần gũi với sinh viên , thầy phát âm tiếng anh cũng rất dễ nghe .',
#  'phòng học ồn do cạnh khu xây dựng .',
#  'giảng bài dễ tiếp thu nhiệt tình .',
#  'lớp đã nghỉ 4 tuần liên tiếp chưa tính một vài ngày nghỉ khác .',
#  'em mong phần thực hành được hỗ trợ nhiều hơn nữa từ phía giảng viên .',
#  'giảng bài khó hiểu .',
#  'cô dạy rất nhiệt tình , cung cấp thông tin đầy đủ nhưng vẫn tạo điều kiện cho sinh viên tìm hiểu thêm .',
#  'thầy rất nhiệt tình với học sinh .',
#  'dễ học dễ hiểu .',
#  'hình như em đăng ký thầy dạy mà thầy dạy mấy buổi người khác dạy mấy buổi thì phải .',
#  'chưa giảng dạy nhiều về bài tập , cũng như hướng dẫn sinh viên hướng giải quyết nó .',
#  'thầy rất tận tình , luôn luôn giúp đỡ , hỗ trợ sinh viên .',
#  'thầy giảng rất hay và dễ hiểu , phong cách dạy độc đáo .',
#  'thầy wzjwz237 rất vui và nhiệt tình .',
#  'nên đưa môn wzjwz129 vào giảng dạy ngay sau môn wzjwz130 và trước khi học các môn chuyên ngành .',
#  'chất lượng tốt giáo viên nhiệt tình .',
#  'giảng viên dạy rất nhiệt tình .',
#  'thầy dạy sát theo slide nhưng một số kiến thức bài tập lại khó hơn nhiều .',
#  'trao dồi thêm về kỹ năng speaking và listening .',
#  'ít bài tập .',
#  'cô dạy có tâm huyết với học sinh , truyền đạt tốt , dễ hiểu .',
#  'đảm bảo giời lên lớp .',
#  'ngiêm túc , cứng rắn về vấn đề tự học .',
#  'em mail bổ sung bài thực hành giáo viên không hồi đáp , mail xin sửa điểm giảng viên không reply đồng ý xem xét hay không đồng ý .',
#  'thời gian cô up slide lên module còn chậm .',
#  'thầy đưa ra những demo thực tế , giúp sinh viên dễ hiểu .',
#  'nope .',
#  'thầy cho khá nhiều bài tập đa dạng .',
#  'các phần tiếng việt trong slide được ghi một cách khó hiểu và không rõ ràng , nhiều chỗ trong slide bài giảng có vẻ như được dịch bằng google dịch từ năm 2009 .',
#  'cô quan tâm đến sinh viên và truyền đạt kiến thức rất bổ ích .',
#  'không thực tế .',
#  'tiết học của thầy rất vui .',
#  'học trong phòng chất lượng cao hơn , phòng học hiện tại không có máy lạnh .',
#  'giảng viên chưa truyền đạt tốt , dạy còn chán , không có sự thu hút trong cách dạy lắm .',
#  'hướng dẫn rất tận tình , trình bày hướng dẫn rất đẹp , có phong cách , thể hiện một thái độ rất nghiêm túc trong công việc giảng dạy .',
#  'giảng bài dễ hiểu , dễ vận dụng .',
#  'thầy vui tính dạy dễ hiểu và cung cấp nhiều thông tin hữu ích cho sinh viên .',
#  'thầy quá chuyên nghiệp .',
#  'cô giảng có hơi khó hiểu .',
#  'tạo bầu không khí thoải mái cho sinh viên .',
#  'em rất hài lòng về phương pháp giảng dạy của thầy .',
#  'dạy nhiệt tình , theo sát môn học .',
#  'vì tính cô kỹ nên đôi lúc nói quá nhiều về một vấn đề ( lặp đi lặp lại ) làm mất thời gian trên lớp và sử dụng giờ học không hiệu quả .',
#  'mong giáo viên có thể giải đáp nhiều bài tập cho sinh viên hơn trên lớp .',
#  'đầu tư thêm nhiều công cụ dạy học .',
#  'giảng viên rất đúng giờ .',
#  'cách giảng dễ hiểu .',
#  'thang điểm đưa ra đầu khóa học không rõ ràng , nhất quán so với thang điểm cuối khóa .',
#  'thầy hứa sẽ up điểm giữa kỳ sớm mà điểm giữa kỳ thì tới giờ này vẫn chưa có ?',
#  'thực hành nhiều .',
#  'nhiệt tình với sinh viên , tư tưởng thoải mái .',
#  'cho sinh viên chép bài để nhớ kiến thức hơn , rèn luyện nhiều bài tập , dạy nhiệt tình .',
#  'nhiều hoạt động .',
#  'giảng viên áp dụng mô hình scrum để làm project là tốt nhưng không thành công .',
#  'hay kể các chuyện liên quan đến thực tiễn giúp bọn em tiếp thu nhanh hơn và cũng có hứng thú trong quá trình học .',
#  'đây là điều gây bức xúc với sinh viên .',
#  'khó hiểu ạ .',
#  'ân cần , tận tụy .',
#  'máy chiếu chưa rõ nét cho toàn thẻ sinh viên trong phòng .',
#  'cô nhiệt tình , sẵn sàng giảng lại các kiến thức mà sinh viên chưa nắm được khi học lý thuyết .',
#  'nâng cao trang thiết bị phòng học .',
#  'giảng viên nhiệt tình , hết mình truyền đạt kiến thức .',
#  'cô có thể giảng phần lý thuyết kỹ hơn được không ạ .',
#  'thầy nên share lại slide cho sinh viên !',
#  'nhiều tâm huyết với nghề .',
#  'dạy tốt , tận tình .',
#  'thầy rất nhiệt tình trong việc trả lời các câu hỏi phụ của sinh viên .',
#  'hiện tại em không nhớ nổi mặt của thầy fraction cô như nào nữa colondoublesurprise .',
#  'phòng thực hành cần nâng cấp và bổ sung thêm thiết bị để mọi người đều có điều kiện thực hành thực tế nhiều hơn .',
#  'giảng viên nên trao đổi với sinh viên nhiều hơn , giao bài tập và giải thích những thắc mắc của sinh viên về môn học .',
#  'cô thân thiện với học sinh , truyền cảm hứng , động lực tốt .',
#  'thầy kiểm tra quá nhiều .',
#  'thầy rất khắt khe trong việc dùng từ chuyên ngành .',
#  'thầy dạy rất tốt .',
#  'những gì được học nó nhằm mục đích gì ?',
#  'cần cung cấp thêm tài liệu học tập môn học này .',
#  'cách dạy của thầy rất nhàm chán , không có nhiều hoạt động thực tế , bài tập thầy cho chỉ áp sát lý thuyết mà chưa thực tế .',
#  'nên dành nhiều thời gian cho bài tập và hướng dẫn cụ thể phương pháp giải hơn .',
#  'đôi khi học sinh nào bận muốn về trước thầy vẫn cho .',
#  'nhiều lúc lớp chỉ có hai người đi học .',
#  'có thể chia nhóm ra làm thực hành !',
#  'thầy wzjwz83 rất nhiệt huyết trong việc giảng dạy .',
#  'thầy vui quá đi hi hi .',
#  'giảng viên nhiệt tình , chắt lọc nội dung cũng như mở rộng nhiều kiến thức về bộ môn .',
#  'thầy giảng rất hay , rất tận tâm với sinh viên .',
#  'em mong có sự thống nhất giữa thầy cô trong quá trình giảng dạy môn này .',
#  'chưa ổn .',
#  'giảng viên tận tâm , dạy tốt .',
#  'sử dụng giờ học hiệu quả .',
#  'cách nói chưa lôi cuốn .',
#  'thầy không đảm bảo giờ lên lớp , nếu có nghỉ thầy cũng không thông báo trước rất vô lý .',
#  'nhiệt tình truyền đạt kiến thức cho sinh viên .',
#  'lý thuyết và thực hành nên đi đôi với nhau .',
#  'thân .',
#  'thầy dạy quá tệ .',
#  'không có nhiều bài tập để làm thêm .',
#  'phòng học quá sáng , màn chiếu bị mờ rất khó nhìn , xin ban quản lý lắp rèm để sinh viên và giảng viên thuận tiện trong việc học tập và giảng dạy .',
#  'giáo viên quá tốt .',
#  'cần cân bằng việc giảng dạy giữa sinh viên yếu và khá trở lên .',
#  'nhiệt tình , giảng dễ hiểu , dễ thương .',
#  'giảng viên dạy rất dễ hiểu .',
#  'tài liệu cung cấp thiếu .',
#  'thầy nên đánh giá kỹ hoạt động trên lớp của từng thành viên trong nhóm , ai đóng góp nhiều , nghiêm túc .',
#  'giáo viên lên lớp muộn , nghe điện thoại trong lúc lên lớp thường xuyên , nghỉ dạy không thông báo .',
#  'đề nghị nên cho bài tập về nhà .',
#  'mong thầy giảng giải và cho bài tập từng bước nhiều hơn .',
#  'thầy cho đề thực hành cũng khá hay , nhưng mà thật thì em toàn code mấy bài đó trên notepad rồi nộp , không test gì cả , nhưng được cái là đồ án 10 thì điểm thực hành cũng 10 luôn .',
#  'khó hiểu , không sinh động .',
#  'chỉ dạy nhiệt tình .',
#  'giáo viên truyền đạt những vẫn đê sâu .',
#  'chưa cung cấp cách nhìn sâu hơn về môn học vào thực tế hiện nay , chỉ mới mang tính trừu tượng .',
#  'giảng viên dạy dễ hiểu , và đầy đủ nội dung .',
#  'không hướng dẫn kỹ .',
#  'nhiệt tình , chi tiết .',
#  'thầy cho chép bài ít thôi , tập trung sửa bài được không ạ .',
#  'khả năng truyền đạt chưa đi vào lòng người cho lắm !',
#  'thầy rất nhiệt tình , dạy rất kỹ , thầy cũng rất vui tính .',
#  'giảng viên nhiệt tình , vui vẻ , giờ học vui .',
#  'cô dạy không hấp dẫn , tuy hay nhưng không kích thích được sinh viên hoạt động .',
#  'thưa , không có ạ .',
#  'kiến thức môn học mang lại tương đối đầy đủ và thực tế giúp sinh viên nắm rõ phương pháp và cách thức để học tập các môn chuyên ngành sau này .',
#  'cách giảng dạy , tạo không khí sôi nổi trong lớp .',
#  'trình bày bài giảng một cách khoa học và hợp lý .',
#  'tuy nhiên , giờ trên lớp thầy chưa thực sự sử dụng hiệu quả lắm khi thiếu tương tác với sinh viên trong lớp để nắm tình hình học viên của mình .',
#  'thầy dễ thương , nhiệt tình , dạy dễ hiểu .',
#  'nên cho thời gian học nhiều hơn 2 tiết .',
#  'cô vui tính , hiền , khá nhiệt tình và gần gũi với sinh viên colonsmilesmile .',
#  'những gì quan trọng cần nắm bắt và tìm hiểu thêm .',
#  'cá nhân em thấy đôi khi nhìn thầy em cảm thấy hơi sợ sợ .',
#  'rèn luyện được kỹ năng giao tiếp , mạnh dạng đứng trước lớp nói tiếng anh .',
#  'thầy hướng dẫn thực hành hay .',
#  'cập nhật kiến thức thực tế .',
#  'giảng viên nhiệt tình , luôn luôn đến lớp đúng giờ .',
#  'chỉ có vấn đề thầy dạy hơi nhanh .',
#  'giảng viên truyền đạt còn chưa tốt .',
#  'tình trạng nghỉ không thông báo cho sinh viên để sinh viên đứng đợi giảng viên gần hết giờ rồi ra về nhiều lần .',
#  'cô giảng dạy chi tiết trong quá trình học .',
#  'kiến thức chưa có trọng tâm .',
#  'tiết học vui vẻ , thoải mái .',
#  'chưa tương tác nhiều với sinh viên .',
#  'thân thiện , nhiệt tình .',
#  'yêu cầu quá cao đối với một sinh viên , mặc dù chỉ là một đồ án nhưng không nhất thiết phải quá chi tiết về mọi khía cạnh cụ thể .',
#  'cô hướng dẫn phương pháp học tập hiệu quả .',
#  'thầy cần hoạt động trao đổi nhiều hơn với sinh viên .',
#  'thầy dạy rất dễ hiểu , đúng trọng tâm bài học .',
#  'cho quá nhiều bài tập , chỉ nên cho bài tập ví dụ điển hình .',
#  'giúp em hiểu ra được nhiều cái hay .',
#  'thầy giảng rất hay , dễ hiểu .',
#  'giảng viên giảng bài hơi nhàm chán , gây cảm giác buồn ngủ , có nhiều chỗ hơi lan man .',
#  'giáo viên giạy theo cách quá thụ động , tạo sự nhàm chán cho sinh viên !',
#  'thầy rất tận tâm nhưng không có kỹ năng sư phạm .',
#  'nội dung hơi nhiều nên giảm bớt lại .',
#  'thầy chỉ dạy rất tận tình , luôn hỏi học sinh phần nào chưa hiểu và giảng lại rất kỹ , những bài giảng của thầy rất hay .',
#  'mong thầy giải bài tập trên lớp .',
#  'do thời gian mỗi buổi học khá ngắn nên giảng viên cần tập trung vào những chủ đề quan trọng , phần còn lại nên để sinh viên tự tìm hiểu .',
#  'giáo viên rất tận tâm nhiệt tình .',
#  'mong rằng những môn có thực hành , giáo viên nên mở chat box và forum cho sinh viên dễ trao đổi với nhau , cũng như nhanh chóng nhận được lời giải đáp thắc mắc từ giáo viên .',
#  'cô dạy quá hay rồi .',
#  'thêm hệ thống ổ điện ngầm dưới nền nhà để tiện cho việc sinh viên có thể cắm laptop phục vụ học tập .',
#  'chất lượng môn học phù hợp .',
#  'cô dạy rất nhiệt tình và rất kiên nhẫn với sinh viên .',
#  'có sai nhận sai và sửa đổi khắc phục .',
#  'thầy dễ tính , dạy dễ hiểu , thầy dạy hay .',
#  'giáo viên dễ gần , tận tâm .',
#  'thầy rất vui tính dạy dễ hiểu .',
#  'không có hoạt động giảng dạy nào không hài lòng .',
#  'lên vừa cho học lý thuyết vừa cho thực hành .',
#  'môn học với kiến thức không quá nặng .',
#  'nội dung thực hành đã cũ , không được đổi mới và không sát với thực tế .',
#  'các code ví dụ không được chiếu hết trên slide .',
#  'chỉ dạy tận tâm .',
#  'thầy dạy nhiệt tình , chia sẻ những kiến thức bổ ích .',
#  'thầy dạy rất nhiệt tình , dễ hiểu , tận tâm .',
#  'giảng hơi ít .',
#  'em mong môn này có thể áp dụng nhiều hơn trong những đồ án .',
#  'giải ví dụ , bài tập nhiều hơn .',
#  'thành thật mà nói thì sau khi học buổi đầu xong thì em không muốn học thêm buổi thứ hai .',
#  'đề nghị thầy xem lại việc chấm chéo đồ án và báo cáo chéo đồ án .',
#  'bài dạy phụ thuộc nhiều vào slide , cách truyền đạt chưa thực sự phù hợp với cá nhân .',
#  'có slide bài giảng tiếng anh giúp nâng cao trình độ đọc hiểu tài liệu chuyên ngành và nâng cao kiến thức cho sinh viên .',
#  'học đúng giờ nhưng ra về thì sớm hơn quy định .',
#  'chuyên nghiệp .',
#  'giảng viên thoải mái , hòa đồng .',
#  'thầy dạy rất tốt !',
#  'cách truyền đạt kiến thức của thầy đối với em thì em cảm thấy không phù hợp lắm , em cần phải rất rất tập trung và hỏi đi hỏi lại nhiều lần mới có thể nắm bắt kiến thức .',
#  'thầy cho nghỉ hơi nhiều .',
#  'giảng viên nên cung cấp tài liệu học tập cho sinh viên !',
#  'thầy dạy nhiêt tình , kỹ càng !',
#  'thầy dạy hay , nhiều kiến thức mở rộng , được học trên slide tiếng anh .',
#  'thầy dạy tốt không phụ thuộc nặng vào chương trình .',
#  'slide bao nhiêu thầy đọc lại bấy nhiêu , cực kỳ khó hiểu và buồn ngủ .',
#  'cải tiến trang thiết bị phòng thực hành .',
#  'giảng viên nên dạy đúng giờ hơn hạn chế cho sinh viên về sớm .',
#  'em hi vọng trong các tiết học thầy có thể đi sâu vào kiến thức chuyên môn và giảm bớt thời lượng của hoạt động liên hệ thực tế .',
#  'chân thành cảm ơn thầy .',
#  'không có ý kiến nhiều .',
#  'không có .',
#  'cách chấm điểm của giảng viên không đánh giá đúng năng lực của sinh viên .',
#  'em không có ý kiến về mục này ạ .',
#  'thời gian và cách thức thầy dạy .',
#  'giảng quá khó hiểu .',
#  'các thiết bị âm thanh cần được đảm bảo hơn .',
#  'nên phát hành giáo trình chuẩn cho môn học .',
#  'dưới đây là hình thầy cung cấp toàn bộ tài liệu trong quá trình học .',
#  'lịch thực hành không được thông báo .',
#  'thầy dạy rất tốt , nhiệt tình và rất dễ hiểu .',
#  'lắp quạt phù hợp vì phòng có 2 dãy quạt 2 bên nhưng ngồi ở dãy giữa vẫn nóng , cần có màn che cửa sổ và có ổ cắm điện .',
#  'lên lớp toàn cho làm paper .',
#  'kiến thức được đưa vào ứng dụng nhiều bài toán .',
#  'giảng viên làm rất tốt trong việc giảng dạy bộ môn thực hành .',
#  'cô wzjwz253 nhiệt tình , giảng bài kỹ .',
#  'thầy wzjwz199 rất nhiệt tình trong quá trình giảng dạy .',
#  'sau kỳ thi giữa kỳ cấu trúc dữ liệu lý thuyết ( chủ yếu là thi về thuật toán sắp xếp ) thì thầy mới cho làm bài tập về các thuật toán sắp xếp .',
#  'giảng viên nhiệt tình , gần gũi với sinh viên .',
#  'có nghĩ 2 buổi không hề báo trước .',
#  'them nhiều tài liệu và video hướng dẫn .',
#  'giảng viên nên cho số lượng bài tập vừa phải , giải chậm và sâu ở mỗi dạng toán đặc biệt là những dạng toán khó .',
#  'cần có nhiều buổi thực hành trên thiết bị thật hoặc giảng viên nên đem thiết bị thật làm vài bày mẫu trên lớp .',
#  'môn học nên tập trung vào chuyên sâu các mục , nên có biên soạn giáo trình mới , chuyên sâu hơn .',
#  'thầy dạy dễ hiểu , rất hay .',
#  'thời khóa biểu phân chia không hợp lý , chưa học lý thuyết đã phải học thực hành .',
#  'cung cấp nhiều bài tập cho sinh viên tham khảo .',
#  'thầy cô dạy chưa sâu vào bài học .',
#  'nói nhỏ , rất khó nghe .',
#  'thầy hầu như không giải đáp thắc mắc của sinh viên khi bài tập mắc lỗi hoặc có nhưng rất hời hợt .',
#  'chưa thực sự tận dụng tốt thời gian và chưa mở rộng vấn đề .',
#  'công bằng .',
#  'thầy giảng rất kỹ và dễ hiểu , cho rất nhiều bài tập giúp sinh viên ứng dụng và nhớ được những gì đã học .',
#  'cô dạy dễ hiểu , vui vẻ với sinh viên , cung cấp đầy đủ kiến thức cần thiết .',
#  'bài giảng hơi khó hiểu .',
#  'nên muốn nhà trường tăng thêm thời gian học lý thuyết của môn này .',
#  'thường xuyên tổ chức thảo luận , thực hành nói .',
#  'giảng viên dạy có phần hơi nhanh .',
#  'giúp chúng em học tập tốt hơn .',
#  'thầy dạy hay tận tình .',
#  'thầy dạy rất hay , chi tiết .',
#  'tận tụy với sinh viên .',
#  'thầy rất nhiệt tình và có kiến thức sâu rộng , cung cấp nhiều kiến thức hay .',
#  'hầu như trong cả năm học , giảng viên chỉ đi dạy đúng thời khoá biểu chỉ từ 2 đến 3 ngày , còn lại giảng viên lại tự ý dời lịch học sang ngày thứ 7 mà không hỏi ý kiến của sinh viên , vì vào ngày thứ 7 có rất nhiều sinh viên có lịch học môn khác .',
#  'cần thêm nhiêu bài tập thực tế .',
#  'không tập trung vào giảng kiến thức cho học sinh hiểu .',
#  'thật sự rất thất vọng về việc dạy thực hành của thầy !',
#  'góp ý doubledot thầy nên có cách tiếp cận khác để cân bằng giữa vấn đề ngoại ngữ và kiến thức chuyên ngành .',
#  'thầy dạy lý thuyết được .',
#  'thầy dạy nhanh , hay !',
#  'nên cho nhiều bài tập hơn .',
#  'giảng viên nhiệt tình , quan tâm đến học sinh .',
#  'môn học có 5 lab mà chỉ học 2 lab là thi cuối kỳ , thầy nên lên lớp đủ số buổi quy định .',
#  'slide hơi khó hiểu .',
#  'giáo viên thực hành cần quan tâm , chỉ dẫn sinh viên tận tình hơn .',
#  'giảng viên lên lớp đầy đủ .',
#  'giảng viên nhiệt tình , hỗ trợ sinh viên tốt .',
#  'giảng viên hay cho nghỉ học mà không báo trước .',
#  'trang thiết bị còn hỏng hóc nhiều , thường xuyên trục trặc trong giờ học .',
#  'hiểu tâm lý học sinh nên mọi người trong lớp đều chú ý giảng bài .',
#  'phòng wzjwz325 thiết bị âm thanh hay xảy ra trục trặc làm gián đoạn buổi học .',
#  'vui tính , thân thiện .',
#  'nhiệt tình , năng nổ .',
#  'không có sự thoải mái khi học tập .',
#  'giảng viên dạy tận tâm , nhiệt tình , lên lớp đúng giờ .',
#  'mong cô cung cấp nhiều tài liệu có hướng dẫn giải cụ thể các dạng toán để đáp ứng nhu cầu tự học .',
#  'giảng viên nhiệt tình , vui vẻ , hoà đồng , gần gũi giúp sinh viên khá nhiều trong việc tiếp thu kiến thức .',
#  'mong nhà trường xem xét lại để có sự nhất quán trong công tác dạy và chấm thi .',
#  'truyền đật kiến thức tốt , dễ hiểu .',
#  'tài liệu thực hành nên nêu rõ mục tiêu cũng như kiến thức cần đạt được sau bài thực hành .',
#  'và giảng dạy khó hiểu .',
#  'ít quan sát sinh viên thực hành .',
#  'có một bạn trong phòng của em học thầy ở học kỳ trước hâm mộ thầy !',
#  'bài tập cuối kỳ làm quá nhiều .',
#  'cô dạy có tâm , post tài liệu và bài tập lên moodle rất đầy đủ .',
#  ...]

# %%
with open("./Data/train/sentiments.txt", "r", encoding = "utf8") as f:
    labels = [int(label.strip()) for label in f.readlines()]
len(labels)
# Out:
# 11426

# %%
def build_dataset(base_directory, save_path):
    sentences_file = base_directory + "/sents.txt"
    sentiments_file = base_directory + "/sentiments.txt"
    
    with open(sentences_file, "r", encoding = "utf8") as f1:
        sentences = [sentence.strip() for sentence in f1.readlines()]
    
    with open(sentiments_file, "r", encoding = "utf8") as f2:
        sentiments = [int(sentiment.strip()) for sentiment in f2.readlines()]
    
    sentences = punctuation_removal(sentences)
    sentences = word_segmentation(sentences)
    sentences = name_removal(sentences)
    
    df = pd.DataFrame()
    df["sentences"] = sentences
    df['sentiments'] = sentiments
    df.to_csv(save_path, index = False, sep = "|")
    return df

# %%
train_dir = "./Data/train"
train_save_path = "./Data/processed/train.csv"

validation_dir = "./Data/dev"
validation_save_path = "./Data/processed/validation.csv"

test_dir = "./Data/dev"
test_save_path = "./Data/processed/test.csv"


train_df = build_dataset(train_dir, save_path  = train_save_path)
validation_df = build_dataset(validation_dir, save_path  = validation_save_path)
test_df = build_dataset(test_dir, save_path  = test_save_path)

# %%
df['sentences']
# Out:
# 0                                  slide giáo_trình đầy_đủ
# 1               nhiệt_tình giảng_dạy gần_gũi với sinh_viên
# 2                       đi học đầy_đủ full điểm chuyên cần
# 3        chưa áp_dụng công_nghệ_thông_tin và các thiết_...
# 4        thầy giảng bài hay có nhiều bài_tập ví_dụ ngay...
#                                ...
# 11421    chỉ vì môn game mà em học hai lần mà không qua...
# 11422                                   em cảm_ơn cô nhiều
# 11423                               giao bài_tập quá nhiều
# 11424                     giáo_viên dạy dễ hiểu nhiệt_tình
# 11425    gói gọn doubledot hay tận_tình phù_hợp với mọi...
# Name: sentences, Length: 11426, dtype: object
